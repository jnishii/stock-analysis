# %% [markdown]
# # EPS analysis

# %% [markdown]
# ## import modules and difine basic modules & functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import yahoo_fin.stock_info as si

# private module
import mystock_info as mi

# %%
import importlib
importlib.reload(mi)
# Out:
# <module 'mystock_info' from '/home/jovyan/yahoo_fin/mystock_info.py'>

# %% [markdown]
# ## Get stock info of your favorite

# %% [markdown]
# ### Find Tickers with high EPS beat ratio

# %%
# pd.set_option('display.max_rows', df.shape[0]+1)
tickers_nasdaq = si.tickers_nasdaq()
ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
# Out:
# invalid ticker name AADR
# invalid ticker name AAXJ
# Tickers list of which beat ratio >= 95% within last 40 quarters
# (data with more than 20 quarter EPSs)
# Empty DataFrame
# Columns: [beat ratio, beat, count]
# Index: []

# %% [markdown]
# ## analyze tech companies

# %%
fangam=["FB","AAPL","NFLX","GOOG","AMZN","MSFT"]

###
ant=["ADBE","NVDA","TSLA"]
saas=["CRWD","OKTA","ZS","TTD","TWLO"]
ecommerce=["SHOP","ETSY","FIVN"]

fintech=["SQ","DOCU", "PYPL"]
media=["TWTR","PINS"]
techs=["U","ZM","FVRR","ABNB","ROKU"]
eauto=["F","GM","MGA"]

growth1=ant+saas+ecommerce
growth2=fintech+media+techs+eauto

# %%
df_eps = pd.DataFrame()
df_psr = pd.DataFrame()

for i in [fangam, growth1, growth2]:
    mi.plot_eps(i)
    
mi.search_good_eps(fangam+growth1+growth2, last=20)
df_res = mi.plot_financials(fangam+growth1+growth2, table=True)
# Out:
# ntick: 6, nrow: 2, ncol: 4
# ntick: 11, nrow: 3, ncol: 4
# ntick: 13, nrow: 4, ncol: 4
# Tickers list of which beat ratio >= 80% within last 20 quarters
# (data with more than 4 quarter EPSs)
#                                         beat ratio  beat  count
# ticker companyshortname
# AAPL   Apple Inc.                       100.000000    20     20
# FIVN   Five9, Inc.                      100.000000    20     20
# ZM     Zoom Video Communications, Inc.  100.000000     9      9
# TTD    The Trade Desk, Inc.             100.000000    19     19
# OKTA   Okta, Inc.                       100.000000    17     17
# MSFT   Microsoft Corporation            100.000000    20     20
# GM     General Motors Company           100.000000    20     20
# ZS     Zscaler, Inc.                    100.000000    13     13
# CRWD   CrowdStrike Holdings, Inc.       100.000000     9      9
# PYPL   PayPal Holdings, Inc.             95.000000    19     20
# ADBE   Adobe Inc.                        95.000000    19     20
# NVDA   NVIDIA Corporation                95.000000    19     20
# SHOP   Shopify Inc.                      95.000000    19     20
# SQ     Square, Inc.                      95.000000    19     20
# DOCU   DocuSign, Inc.                    92.307692    12     13
# TWLO   Twilio Inc.                       90.000000    18     20
# FVRR   Fiverr International Ltd.         87.500000     7      8
# ROKU   Roku, Inc.                        86.666667    13     15
# TWTR   Twitter, Inc.                     85.000000    17     20
# MGA    Magna International Inc.          80.000000    16     20
# PSR sorted list (<function today at 0x7faf2a63b820>)
# info      Market Cap  Previous Close  1y Target Est  Price/Sales (ttm)  \
# Ticker
# CRWD    5.951900e+10          257.84         269.75              59.57
# SHOP    1.911750e+11         1555.10        1515.09              55.44
# ZS      3.244400e+10          233.03         240.62              53.90
# TTD     4.070700e+10           82.68          69.71              45.47
# OKTA    3.833900e+10          248.30         277.91              42.43
# FVRR    9.269000e+09          244.81         258.88              41.44
# DOCU    5.939000e+10          302.04         281.17              36.55
# U       3.038700e+10          100.78         123.05              36.16
# TWLO    6.804200e+10          387.48         464.88              34.25
# ZM      1.097240e+11          367.54         415.48              33.46
# ROKU    6.200900e+10          459.37         450.50              30.52
# PINS    5.026100e+10           74.29          84.31              26.37
# ABNB    8.849100e+10          141.58         172.50              25.85
# FIVN    1.333300e+10          195.65         206.63              25.56
# NVDA    4.860150e+11          192.08         757.31              25.24
# ADBE    2.958060e+11          618.28         618.99              20.56
# PYPL    3.547450e+11          300.48         317.76              15.51
# TSLA    6.405200e+11          644.78         655.12              15.30
# MSFT    2.156000e+12          286.54         298.92              12.82
# ETSY    2.579400e+10          199.48         226.83              12.59
# TWTR    5.583700e+10           68.33          62.17              12.54
# FB      1.058000e+12          367.81         386.47              11.21
# SQ      1.177630e+11          251.73         276.70               8.94
# NFLX    2.298400e+11          518.91         613.68               8.33
# GOOG    1.817000e+12         2735.93        2625.00               8.25
# AAPL    2.419000e+12          146.77         159.34               7.43
# AMZN    1.831000e+12         3626.39        4241.33               4.37
# MGA     2.470900e+10           81.03         109.94               0.72
# GM      8.049800e+10           55.00          72.14               0.66
# F       5.532400e+10           13.79          14.98               0.43
#
# info    PE Ratio (TTM)  Price/Book (mrq)                Earnings Date
# Ticker
# CRWD               NaN             70.06  Aug 31, 2021 - Sep 06, 2021
# SHOP            120.27             20.92  Oct 27, 2021 - Nov 01, 2021
# ZS                 NaN             63.80  Sep 07, 2021 - Sep 13, 2021
# TTD             175.33             37.51  Aug 04, 2021 - Aug 09, 2021
# OKTA               NaN             48.64  Aug 25, 2021 - Aug 30, 2021
# FVRR               NaN             27.32                 Aug 05, 2021
# DOCU               NaN            244.05  Sep 01, 2021 - Sep 06, 2021
# U                  NaN             15.05                 Aug 10, 2021
# TWLO               NaN              6.57                 Jul 29, 2021
# ZM              127.41             25.95  Aug 30, 2021 - Sep 03, 2021
# ROKU            537.72             25.38  Aug 03, 2021 - Aug 09, 2021
# PINS               NaN             20.91                 Jul 29, 2021
# ABNB               NaN             27.58                 May 13, 2021
# FIVN               NaN             81.98  Oct 27, 2021 - Nov 01, 2021
# NVDA             92.21             25.89                 Aug 18, 2021
# ADBE             53.81             21.38                 Sep 21, 2021
# PYPL             68.82             18.24                 Jul 28, 2021
# TSLA            342.14             25.33  Oct 19, 2021 - Oct 25, 2021
# MSFT             35.56             15.16  Oct 25, 2021 - Oct 29, 2021
# ETSY             57.64             37.63                 Aug 04, 2021
# TWTR            148.85              7.22                 Oct 26, 2021
# FB               31.98              7.93  Oct 27, 2021 - Nov 01, 2021
# SQ              361.69             50.81                 Aug 05, 2021
# NFLX             53.81             16.58  Oct 18, 2021 - Oct 22, 2021
# GOOG             28.94              7.67                          NaN
# AAPL             32.59             34.97  Oct 27, 2021 - Nov 01, 2021
# AMZN             69.07             17.71                 Jul 29, 2021
# MGA              22.14              2.11                 Aug 06, 2021
# GM                8.96              1.61                 Aug 04, 2021
# F                13.94              1.64  Oct 26, 2021 - Nov 01, 2021

# %% [markdown]
# ## FANGAMのみ大きく出してみる

# %%
mi.plot_eps(fangam,largefig=True)
mi.search_good_eps(fangam, last=200)
# Out:
# ntick: 6, nrow: 6, ncol: 1
# Tickers list of which beat ratio >= 80% within last 200 quarters
# (data with more than 4 quarter EPSs)
#                               beat ratio  beat  count
# ticker companyshortname
# AAPL   Apple Inc.              87.878788    87     99
# MSFT   Microsoft Corporation   87.878788    87     99
# FB     Facebook, Inc.          83.783784    31     37
# NFLX   Netflix, Inc.           80.263158    61     76
#    ticker       companyshortname startdatetime startdatetimetype  epsestimate  \
# 1      FB         Facebook, Inc.    2021-07-28               TNS         3.03
# 2      FB         Facebook, Inc.    2021-04-28               TNS         2.37
# 3      FB         Facebook, Inc.    2021-01-27               TNS         3.22
# 4      FB         Facebook, Inc.    2020-10-29               TNS         1.91
# 5      FB         Facebook, Inc.    2020-07-30               TNS         1.39
# ..    ...                    ...           ...               ...          ...
# 95   MSFT  Microsoft Corporation    1998-01-21               TNS         0.10
# 96   MSFT  Microsoft Corporation    1997-10-20               TNS         0.09
# 97   MSFT  Microsoft Corporation    1997-07-17               TNS         0.10
# 98   MSFT  Microsoft Corporation    1997-04-17               TNS         0.08
# 99   MSFT  Microsoft Corporation    1997-01-17               TNS         0.06
#
#     epsactual  epssurprisepct timeZoneShortName  gmtOffsetMilliSeconds  \
# 1        3.61           18.98               EDT                      0
# 2        3.30           39.42               EDT                      0
# 3        3.88           20.61               EDT                      0
# 4        2.71           42.18               EDT                      0
# 5        1.80           29.59               EDT                      0
# ..        ...             ...               ...                    ...
# 95       0.11            3.85               EDT                      0
# 96       0.09            2.53               EDT                      0
# 97       0.10            0.83               EDT                      0
# 98       0.10           25.21               EDT                      0
# 99       0.07           12.47               EDT                      0
#
#    quoteType
# 1     EQUITY
# 2     EQUITY
# 3     EQUITY
# 4     EQUITY
# 5     EQUITY
# ..       ...
# 95    EQUITY
# 96    EQUITY
# 97    EQUITY
# 98    EQUITY
# 99    EQUITY
#
# [432 rows x 10 columns]

# %% [markdown]
# ## Health

# %%
tickers_health = [
    "A",
    "AMGN",
    "ANTM",
    "BMY",
    "BNTX",
    "BIIB",
    "DHR",
    "MRNA",
    "PGNY",
    "PFE",
    "RPRX",
    "VEEV",
    "INOV"
]

# %%
# EPS history
mi.plot_eps(tickers_health,last=20)
#mi.search_good_eps(tickers_health)
df_res=mi.plot_financials(tickers_health,table=True)
# Out:
# ntick: 13, nrow: 4, ncol: 4
# PSR sorted list (<function today at 0x7faf2a63b820>)
# info      Market Cap  Previous Close  1y Target Est  Price/Sales (ttm)  \
# Ticker
# MRNA    1.402620e+11          328.50         184.92              51.33
# VEEV    5.078400e+10          326.43         333.14              32.52
# BNTX    7.570500e+10          284.00         200.87              30.25
# PGNY    4.819000e+09           53.36          66.33              12.49
# RPRX    2.339200e+10           39.20          52.71              10.66
# INOV    5.737000e+09           36.95          36.00               8.31
# A       4.595900e+10          149.95         148.94               7.90
# DHR     2.090870e+11          290.60         292.32               7.83
# AMGN    1.403350e+11          244.68         254.96               5.58
# PFE     2.432200e+11           42.10          42.97               5.24
# BIIB    4.980400e+10          333.96         404.41               4.26
# BMY     1.534630e+11           67.49          75.37               3.58
# ANTM    9.263300e+10          382.63         427.00               0.72
#
# info    PE Ratio (TTM)  Price/Book (mrq)                Earnings Date
# Ticker
# MRNA            234.13             36.50                 Aug 05, 2021
# VEEV            131.26             20.75  Aug 25, 2021 - Aug 30, 2021
# BNTX             57.23             30.05                 Aug 09, 2021
# PGNY               NaN             25.87  Aug 03, 2021 - Aug 09, 2021
# RPRX               NaN               NaN                 May 11, 2021
# INOV            169.59              7.86  Oct 26, 2021 - Nov 01, 2021
# A                50.66              9.55                 Aug 17, 2021
# DHR              38.96              5.29  Oct 20, 2021 - Oct 25, 2021
# AMGN             20.23             15.05                 Aug 03, 2021
# PFE              22.01              3.54  Oct 25, 2021 - Oct 29, 2021
# BIIB             26.73              4.63  Oct 19, 2021 - Oct 25, 2021
# BMY                NaN              4.08                 Jul 28, 2021
# ANTM             22.48              2.65                 Oct 20, 2021
