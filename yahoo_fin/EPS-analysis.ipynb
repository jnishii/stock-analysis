# %% [markdown]
# # EPS analysis

# %% [markdown]
# ## import modules and difine basic modules & functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import yahoo_fin.stock_info as si

# private module
import mystock_info as mi

# %%
import importlib
importlib.reload(mi)
# Out:
# <module 'mystock_info' from '/home/jovyan/yahoo_fin/mystock_info.py'>

# %% [markdown]
# ## Tech companies

# %%
fangam=["FB","AAPL","NFLX","GOOG","AMZN","MSFT"]

###
ant=["ADBE","NVDA","TSLA"]
saas=["CRWD","OKTA","ZS","TTD","TWLO"]
ecommerce=["SHOP","ETSY","FIVN"]

fintech=["SQ","DOCU", "PYPL"]
media=["TWTR","PINS"]
techs=["U","ZM","FVRR","ABNB","ROKU"]
eauto=["F","GM","MGA"]

growth1=ant+saas+ecommerce
growth2=fintech+media+techs+eauto

# %%
E12 = ["FB", "AAPL", "GOOG", "AMZN", "MSFT"] #Billions
E11 = ["NFLX", "TSLA","ADBE", "NVDA","PYPL", "SHOP", "SQ", "ZM"] # over 100 million
E10_5 = ( # Over 50 million
    ["ABNB", "GM", "F"] 
    + ["CRWD", "TWLO","TWTR"]
    + [ "DOCU"]
)
E10_1 = ["ROKU", "PLTR","OKTA", "EPAM","U", "MGA","ZS", "ETSY","FIVN", "PINS"] # over 10 million

E9 = ["FVRR","FSLY", "TTD"] # over 1 million

LIST=E12+E11+E10_5+E10_1+E9
###

# %% [markdown]
# ### PSR distribution and Market Cap

# %%
import importlib
importlib.reload(mi)
df=mi.show_valuation(LIST, table=False, key="Cap")
df["Market Cap"]
# Out:
# The top 5 CAP stocks (2021-08-15)
# <style type="text/css">
# #T_fc927_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fc927_row0_col2, #T_fc927_row1_col2, #T_fc927_row2_col1, #T_fc927_row3_col2, #T_fc927_row4_col2 {
#   background-color: #fda37b;
# }
# #T_fc927_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
# }
# #T_fc927_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 50.8%, transparent 50.8%);
# }
# #T_fc927_row0_col5, #T_fc927_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_fc927_row0_col6, #T_fc927_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_fc927_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 59.1%, transparent 59.1%);
# }
# #T_fc927_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 50.1%, transparent 50.1%);
# }
# #T_fc927_row1_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_fc927_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 63.0%, transparent 63.0%);
# }
# #T_fc927_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
# }
# #T_fc927_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
# }
# #T_fc927_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
# }
# #T_fc927_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
# }
# #T_fc927_row2_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_fc927_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 64.1%, transparent 64.1%);
# }
# #T_fc927_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 52.3%, transparent 52.3%);
# }
# #T_fc927_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 20.3%, transparent 20.3%);
# }
# #T_fc927_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
# }
# #T_fc927_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_fc927_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
# }
# #T_fc927_row3_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_fc927_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 28.9%, transparent 28.9%);
# }
# #T_fc927_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 37.8%, transparent 37.8%);
# }
# #T_fc927_row3_col6, #T_fc927_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
# }
# #T_fc927_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 44.2%, transparent 44.2%);
# }
# #T_fc927_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 22.3%, transparent 22.3%);
# }
# #T_fc927_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fc927_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
# }
# #T_fc927_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 47.0%, transparent 47.0%);
# }
# #T_fc927_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 19.4%, transparent 19.4%);
# }
# #T_fc927_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
# }
# #T_fc927_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
# }
# </style>
# <table id="T_fc927_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fc927_level0_row0" class="row_heading level0 row0" >AAPL</th>
#       <td id="T_fc927_row0_col0" class="data row0 col0" >$2.46e+12</td>
#       <td id="T_fc927_row0_col1" class="data row0 col1" >$148.9</td>
#       <td id="T_fc927_row0_col2" class="data row0 col2" >$159.3</td>
#       <td id="T_fc927_row0_col3" class="data row0 col3" >7.1</td>
#       <td id="T_fc927_row0_col4" class="data row0 col4" >29.2</td>
#       <td id="T_fc927_row0_col5" class="data row0 col5" >38.4</td>
#       <td id="T_fc927_row0_col6" class="data row0 col6" >127.1%</td>
#       <td id="T_fc927_row0_col7" class="data row0 col7" >36.4%</td>
#       <td id="T_fc927_row0_col8" class="data row0 col8" >30.1%</td>
#       <td id="T_fc927_row0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/AAPL">Y</a></td>
#       <td id="T_fc927_row0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/AAPL">a</a></td>
#       <td id="T_fc927_row0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=AAPL">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_fc927_level0_row1" class="row_heading level0 row1" >MSFT</th>
#       <td id="T_fc927_row1_col0" class="data row1 col0" >$2.19e+12</td>
#       <td id="T_fc927_row1_col1" class="data row1 col1" >$289.8</td>
#       <td id="T_fc927_row1_col2" class="data row1 col2" >$298.9</td>
#       <td id="T_fc927_row1_col3" class="data row1 col3" >13.0</td>
#       <td id="T_fc927_row1_col4" class="data row1 col4" >36.2</td>
#       <td id="T_fc927_row1_col5" class="data row1 col5" >15.4</td>
#       <td id="T_fc927_row1_col6" class="data row1 col6" >47.1%</td>
#       <td id="T_fc927_row1_col7" class="data row1 col7" >21.3%</td>
#       <td id="T_fc927_row1_col8" class="data row1 col8" >45.7%</td>
#       <td id="T_fc927_row1_col9" class="data row1 col9" ><a href="https://finance.yahoo.com/quote/MSFT">Y</a></td>
#       <td id="T_fc927_row1_col10" class="data row1 col10" ><a href="https://seekingalpha.com/symbol/MSFT">a</a></td>
#       <td id="T_fc927_row1_col11" class="data row1 col11" ><a href="https://jp.tradingview.com/chart/?symbol=MSFT">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_fc927_level0_row2" class="row_heading level0 row2" >GOOG</th>
#       <td id="T_fc927_row2_col0" class="data row2 col0" >$1.84e+12</td>
#       <td id="T_fc927_row2_col1" class="data row2 col1" >$2,767.8</td>
#       <td id="T_fc927_row2_col2" class="data row2 col2" >$2,625.0</td>
#       <td id="T_fc927_row2_col3" class="data row2 col3" >8.3</td>
#       <td id="T_fc927_row2_col4" class="data row2 col4" >30.0</td>
#       <td id="T_fc927_row2_col5" cla
# ticker
# AAPL    2.464000e+12
# MSFT    2.188000e+12
# GOOG    1.837000e+12
# AMZN    1.668000e+12
# FB      1.025000e+12
# TSLA    7.158300e+11
# NVDA    4.994210e+11
# PYPL    3.230280e+11
# ADBE    3.036840e+11
# NFLX    2.286540e+11
# SHOP    1.860530e+11
# SQ      1.238240e+11
# ZM      1.068590e+11
# ABNB    9.172100e+10
# GM      7.843600e+10
# TWLO    6.508800e+10
# DOCU    5.794400e+10
# CRWD    5.578100e+10
# F       5.504800e+10
# TWTR    5.214800e+10
# PLTR    4.863300e+10
# ROKU    4.858200e+10
# TTD     3.962000e+10
# OKTA    3.639700e+10
# PINS    3.613100e+10
# U       3.550300e+10
# EPAM    3.461100e+10
# ZS      3.365500e+10
# MGA     2.573800e+10
# ETSY    2.410800e+10
# FIVN    1.293300e+10
# FVRR    6.185000e+09
# FSLY    4.983000e+09
# Name: Market Cap, dtype: float64

# %%
df.head()
# Out:
# info      Market Cap  Previous Close  1y Target Est  Price/Sales (ttm)  \
# ticker
# AAPL    2.464000e+12          148.89         159.34               7.10
# MSFT    2.188000e+12          289.81         298.92              13.01
# GOOG    1.837000e+12         2767.79        2625.00               8.34
# AMZN    1.668000e+12         3303.50        4241.33               3.76
# FB      1.025000e+12          362.65         386.47               9.78
#
# info    PE Ratio (TTM)  Price/Book (mrq)  Quarterly Revenue Growth (yoy)  \
# ticker
# AAPL             29.18             38.39                            36.4
# MSFT             36.17             15.41                            21.3
# GOOG             30.02              7.78                            61.6
# AMZN             57.39             14.52                            27.2
# FB               27.00              7.43                            55.6
#
# info    Profit Margin  Operating Margin (ttm)
# ticker
# AAPL            25.00                   28.79
# MSFT            36.45                   41.60
# GOOG            28.57                   28.45
# AMZN             6.64                    6.68
# FB              37.18                   42.52

# %% [markdown]
# ### EPS history

# %%
# import importlib
# importlib.reload(mi)

#for i in [fangam, growth1, growth2]:
for i in [E12,E11,E10_5,E10_1,E9]:
    
    mi.plot_eps_history(i)
# Out:
# ntick: 5, nrow: 2, ncol: 4
# ntick: 7, nrow: 2, ncol: 4
# ntick: 7, nrow: 2, ncol: 4
# ntick: 9, nrow: 3, ncol: 4
# ntick: 3, nrow: 1, ncol: 4

# %%
import importlib
importlib.reload(mi)
#mi.show_beat_ratio(LIST, last=20)
for i in [E12,E11,E10_5,E10_1,E9]:
    df_res = mi.show_valuation(i, hist=False, table=True)
# Out:
# <class 'pandas.io.formats.style.Styler'>
# PSR sorted list (2021-08-14)
# <style  type="text/css" >
# #T_b7249432_fcd7_11eb_b939_5d973c492258row0_col0{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row0_col2,#T_b7249432_fcd7_11eb_b939_5d973c492258row1_col2,#T_b7249432_fcd7_11eb_b939_5d973c492258row2_col1,#T_b7249432_fcd7_11eb_b939_5d973c492258row3_col2,#T_b7249432_fcd7_11eb_b939_5d973c492258row4_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row0_col3,#T_b7249432_fcd7_11eb_b939_5d973c492258row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 62.4%, transparent 62.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 62.4%, transparent 62.4%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row1_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 75.3%, transparent 75.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 75.3%, transparent 75.3%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 46.7%, transparent 46.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 46.7%, transparent 46.7%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row1_col6,#T_b7249432_fcd7_11eb_b939_5d973c492258row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row2_col0{
#             background-color:  #549fcd;
#             color:  #000000;
#             background-color:  #549fcd;
#             color:  #000000;
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.4%, transparent 64.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.4%, transparent 64.4%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 52.1%, transparent 52.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 52.1%, transparent 52.1%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.3%, transparent 20.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.3%, transparent 20.3%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row3_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 50.4%, transparent 50.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 50.4%, transparent 50.4%);
#         }#T_b7249432_fcd7_11eb_b939_5d973c492258row3_col6,#T_b7249432_fcd7_11eb_b939_5d973c492258row4_col4{
#             width:  10em;
#              height:  80%;
#             b
# <class 'pandas.io.formats.style.Styler'>
# PSR sorted list (2021-08-14)
# <style  type="text/css" >
# #T_b76aa6de_fcd7_11eb_b939_5d973c492258row0_col0{
#             background-color:  #dceaf6;
#             color:  #000000;
#             background-color:  #dceaf6;
#             color:  #000000;
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row0_col2,#T_b76aa6de_fcd7_11eb_b939_5d973c492258row1_col2,#T_b76aa6de_fcd7_11eb_b939_5d973c492258row2_col2,#T_b76aa6de_fcd7_11eb_b939_5d973c492258row3_col1,#T_b76aa6de_fcd7_11eb_b939_5d973c492258row4_col1,#T_b76aa6de_fcd7_11eb_b939_5d973c492258row5_col2,#T_b76aa6de_fcd7_11eb_b939_5d973c492258row6_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row0_col3,#T_b76aa6de_fcd7_11eb_b939_5d973c492258row6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 20.4%, transparent 20.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 20.4%, transparent 20.4%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.5%, transparent 40.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.5%, transparent 40.5%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 73.7%, transparent 73.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 73.7%, transparent 73.7%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 29.6%, transparent 29.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 29.6%, transparent 29.6%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 23.2%, transparent 23.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 23.2%, transparent 23.2%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row1_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 67.2%, transparent 67.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 67.2%, transparent 67.2%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 32.9%, transparent 32.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 32.9%, transparent 32.9%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 55.4%, transparent 55.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 55.4%, transparent 55.4%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 75.9%, transparent 75.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 75.9%, transparent 75.9%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 88.9%, transparent 88.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 88.9%, transparent 88.9%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row2_col0{
#             background-color:  #3c8cc3;
#             color:  #000000;
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 53.0%, transparent 53.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 53.0%, transparent 53.0%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.9%, transparent 24.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.9%, transparent 24.9%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 57.7%, transparent 57.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 57.7%, transparent 57.7%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 74.1%, transparent 74.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 74.1%, transparent 74.1%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 43.8%, transparent 43.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 43.8%, transparent 43.8%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 58.8%, transparent 58.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 58.8%, transparent 58.8%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row3_col0{
#             background-color:  #afd1e7;
#             color:  #000000;
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 43.2%, transparent 43.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 43.2%, transparent 43.2%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 14.5%, transparent 14.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 14.5%, transparent 14.5%);
#         }#T_b76aa6de_fcd7_11eb_b939_5d973c492258row3_col5{
#             width:  10em;
#              height:  80%;
#             b
# <class 'pandas.io.formats.style.Styler'>
# PSR sorted list (2021-08-14)
# <style  type="text/css" >
# #T_b7b632d4_fcd7_11eb_b939_5d973c492258row0_col0{
#             background-color:  #e6f0f9;
#             color:  #000000;
#             background-color:  #e6f0f9;
#             color:  #000000;
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row0_col2,#T_b7b632d4_fcd7_11eb_b939_5d973c492258row1_col1,#T_b7b632d4_fcd7_11eb_b939_5d973c492258row2_col2,#T_b7b632d4_fcd7_11eb_b939_5d973c492258row3_col2,#T_b7b632d4_fcd7_11eb_b939_5d973c492258row4_col1,#T_b7b632d4_fcd7_11eb_b939_5d973c492258row5_col2,#T_b7b632d4_fcd7_11eb_b939_5d973c492258row6_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row0_col3,#T_b7b632d4_fcd7_11eb_b939_5d973c492258row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 27.4%, transparent 27.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 27.4%, transparent 27.4%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.2%, #e68f8f 47.2%, #e68f8f 74.4%, transparent 74.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 47.2%, #e68f8f 47.2%, #e68f8f 74.4%, transparent 74.4%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.9%, #f4d18b 0.9%, #f4d18b 94.5%, transparent 94.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.9%, #f4d18b 0.9%, #f4d18b 94.5%, transparent 94.5%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 67.6%, transparent 67.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 67.6%, transparent 67.6%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row1_col0{
#             background-color:  #d1e2f3;
#             color:  #000000;
#             background-color:  #d1e2f3;
#             color:  #000000;
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 66.2%, transparent 66.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 66.2%, transparent 66.2%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 74.4%, transparent 74.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 74.4%, transparent 74.4%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.9%, #f4d18b 0.9%, #f4d18b 78.2%, transparent 78.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.9%, #f4d18b 0.9%, #f4d18b 78.2%, transparent 78.2%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 38.2%, transparent 38.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 38.2%, transparent 38.2%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row2_col0{
#             background-color:  #add0e6;
#             color:  #000000;
#             background-color:  #add0e6;
#             color:  #000000;
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 52.3%, transparent 52.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 52.3%, transparent 52.3%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 2.5%, transparent 2.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 2.5%, transparent 2.5%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.8%, #e68f8f 60.8%, #e68f8f 74.4%, transparent 74.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 60.8%, #e68f8f 60.8%, #e68f8f 74.4%, transparent 74.4%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.9%, #f4d18b 0.9%, #f4d18b 90.3%, transparent 90.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.9%, #f4d18b 0.9%, #f4d18b 90.3%, transparent 90.3%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 3.3%, transparent 3.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 3.3%, transparent 3.3%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row3_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 48.9%, transparent 48.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 48.9%, transparent 48.9%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 12.1%, transparent 12.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 12.1%, transparent 12.1%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.9%, #f4d18b 0.9%, #f4d18b 8.1%, transparent 8.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.9%, #f4d18b 0.9%, #f4d18b 8.1%, transparent 8.1%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 21.2%, transparent 21.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 21.2%, transparent 21.2%);
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row4_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_b7b632d4_fcd7_11eb_b939_5d973c492258row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 21.0%, transparent 21.0%);
# <class 'pandas.io.formats.style.Styler'>
# PSR sorted list (2021-08-14)
# <style  type="text/css" >
# #T_b7ff65bc_fcd7_11eb_b939_5d973c492258row0_col0{
#             background-color:  #58a1cf;
#             color:  #000000;
#             background-color:  #58a1cf;
#             color:  #000000;
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row0_col2,#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row1_col2,#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row2_col2,#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row3_col2,#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row4_col2,#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row5_col2,#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row6_col1,#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row7_col2,#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row8_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row0_col3,#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 73.0%, transparent 73.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 73.0%, transparent 73.0%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.2%, #e68f8f 2.2%, #e68f8f 38.8%, transparent 38.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 2.2%, #e68f8f 2.2%, #e68f8f 38.8%, transparent 38.8%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 54.0%, transparent 54.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 54.0%, transparent 54.0%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 52.3%, transparent 52.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 52.3%, transparent 52.3%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row1_col0{
#             background-color:  #4a98c9;
#             color:  #000000;
#             background-color:  #4a98c9;
#             color:  #000000;
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 81.9%, transparent 81.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 81.9%, transparent 81.9%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 23.3%, #e68f8f 23.3%, #e68f8f 38.8%, transparent 38.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 23.3%, #e68f8f 23.3%, #e68f8f 38.8%, transparent 38.8%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 35.7%, transparent 35.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 35.7%, transparent 35.7%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 4.3%, transparent 4.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 4.3%, transparent 4.3%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row2_col0{
#             background-color:  #3d8dc4;
#             color:  #000000;
#             background-color:  #3d8dc4;
#             color:  #000000;
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 72.9%, transparent 72.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 72.9%, transparent 72.9%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.5%, transparent 51.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.5%, transparent 51.5%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 38.8%, transparent 38.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 38.8%, transparent 38.8%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 33.8%, transparent 33.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 33.8%, transparent 33.8%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 26.8%, transparent 26.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 26.8%, transparent 26.8%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row3_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 44.9%, transparent 44.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 44.9%, transparent 44.9%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 23.6%, #e68f8f 23.6%, #e68f8f 38.8%, transparent 38.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 23.6%, #e68f8f 23.6%, #e68f8f 38.8%, transparent 38.8%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 39.9%, transparent 39.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 39.9%, transparent 39.9%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 21.5%, transparent 21.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 21.5%, transparent 21.5%);
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row4_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_b7ff65bc_fcd7_11eb_b939_5d973c492258row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 38.6%, transparent 38.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90
# <class 'pandas.io.formats.style.Styler'>
# PSR sorted list (2021-08-14)
# <style  type="text/css" >
# #T_b879174a_fcd7_11eb_b939_5d973c492258row0_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row0_col2,#T_b879174a_fcd7_11eb_b939_5d973c492258row1_col2,#T_b879174a_fcd7_11eb_b939_5d973c492258row2_col1{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row0_col3,#T_b879174a_fcd7_11eb_b939_5d973c492258row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.2%, #e68f8f 19.2%, #e68f8f 43.3%, transparent 43.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.2%, #e68f8f 19.2%, #e68f8f 43.3%, transparent 43.3%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.1%, #7eb8ef 14.1%, #7eb8ef 32.1%, transparent 32.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.1%, #7eb8ef 14.1%, #7eb8ef 32.1%, transparent 32.1%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row1_col0{
#             background-color:  #8abfdd;
#             color:  #000000;
#             background-color:  #8abfdd;
#             color:  #000000;
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.4%, transparent 64.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.4%, transparent 64.4%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 26.6%, transparent 26.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 26.6%, transparent 26.6%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 43.3%, transparent 43.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 43.3%, transparent 43.3%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 23.3%, transparent 23.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 23.3%, transparent 23.3%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 14.1%, transparent 14.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 14.1%, transparent 14.1%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row2_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.7%, transparent 19.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.7%, transparent 19.7%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 21.9%, transparent 21.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 21.9%, transparent 21.9%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.3%, #bcde93 43.3%, #bcde93 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.3%, #bcde93 43.3%, #bcde93 100.0%, transparent 100.0%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 80.6%, transparent 80.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 80.6%, transparent 80.6%);
#         }#T_b879174a_fcd7_11eb_b939_5d973c492258row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 83.5%, transparent 83.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 83.5%, transparent 83.5%);
#         }</style><table id="T_b879174a_fcd7_11eb_b939_5d973c492258" ><thead>    <tr>        <th class="index_name level0" >info</th>        <th class="col_heading level0 col0" >Market Cap</th>        <th class="col_heading level0 col1" >Previous Close</th>        <th class="col_heading level0 col2" >1y Target Est</th>        <th class="col_heading level0 col3" >Price/Sales (ttm)</th>        <th class="col_heading level0 col4" >PE Ratio (TTM)</th>        <th class="col_heading level0 col5" >Price/Book (mrq)</th>        <th class="col_heading level0 col6" >Return on Equity (ttm)</th>        <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>        <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>        <th class="col_heading level0 col9" >Y!</th>        <th class="col_heading level0 col10" >alpha</th>        <th class="col_heading level0 col11" >TS</th>    </tr>    <tr>        <th class="index_name level0" >ticker</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b879174a_fcd7_11eb_b939_5d973c492258level0_row0" class="row_heading level0 row0" >FVRR</th>
#                         <td id="T_b879174a_fcd7_11eb_b939_5d973c492258row0_col0" class="data row0 col0" >$6.17e+09</td>
#                         <td id="T_b879174a_fcd7_11eb_b939_5d973c492258row0_col1" class="data row0 col1" >$171.8</td>
#                         <td id="T_b879174a_fcd7_11eb_b939_5d973c492258row0_col2" class="data row0 col2" >

# %%
import importlib
importlib.reload(mi)
df_res = mi.show_valuation(LIST, hist=False, table=True)
df_res = mi.show_valuation(LIST, hist=False, table=True, key="QRG")
# Out:
# PSR sorted list (2021-08-15)
# <style type="text/css">
# #T_511d6_row0_col0, #T_511d6_row30_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_511d6_row0_col1, #T_511d6_row1_col2, #T_511d6_row2_col2, #T_511d6_row3_col2, #T_511d6_row4_col1, #T_511d6_row5_col1, #T_511d6_row6_col1, #T_511d6_row7_col1, #T_511d6_row8_col2, #T_511d6_row9_col2, #T_511d6_row10_col2, #T_511d6_row11_col2, #T_511d6_row12_col2, #T_511d6_row13_col2, #T_511d6_row14_col1, #T_511d6_row15_col2, #T_511d6_row16_col1, #T_511d6_row17_col2, #T_511d6_row18_col2, #T_511d6_row19_col2, #T_511d6_row20_col2, #T_511d6_row21_col1, #T_511d6_row22_col1, #T_511d6_row23_col2, #T_511d6_row24_col2, #T_511d6_row25_col1, #T_511d6_row26_col2, #T_511d6_row27_col2, #T_511d6_row28_col2, #T_511d6_row29_col2, #T_511d6_row30_col2, #T_511d6_row31_col2, #T_511d6_row32_col2 {
#   background-color: #fda37b;
# }
# #T_511d6_row0_col3, #T_511d6_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_511d6_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 27.8%, transparent 27.8%);
# }
# #T_511d6_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 16.4%, #e68f8f 16.4%, #e68f8f 41.5%, transparent 41.5%);
# }
# #T_511d6_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 31.1%, transparent 31.1%);
# }
# #T_511d6_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 59.0%, transparent 59.0%);
# }
# #T_511d6_row1_col0, #T_511d6_row7_col0, #T_511d6_row32_col0 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_511d6_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 99.9%, transparent 99.9%);
# }
# #T_511d6_row1_col5, #T_511d6_row18_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 27.6%, transparent 27.6%);
# }
# #T_511d6_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 32.6%, #e68f8f 32.6%, #e68f8f 41.5%, transparent 41.5%);
# }
# #T_511d6_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 36.6%, transparent 36.6%);
# }
# #T_511d6_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 72.2%, transparent 72.2%);
# }
# #T_511d6_row2_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_511d6_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 86.4%, transparent 86.4%);
# }
# #T_511d6_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 20.1%, transparent 20.1%);
# }
# #T_511d6_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 7.7%, transparent 7.7%);
# }
# #T_511d6_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 56.8%, transparent 56.8%);
# }
# #T_511d6_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 29.6%, transparent 29.6%);
# }
# #T_511d6_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #7eb8ef 14.1%, #7eb8ef 34.1%, transparent 34.1%);
# }
# #T_511d6_row3_col0, #T_511d6_row4_col0, #T_511d6_row5_col0, #T_511d6_row17_col0, #T_511d6_row22_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_511d6_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 72.0%, transparent 72.0%);
# }
# #T_511d6_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 19.4%, transparent 19.4%);
# }
# #T_511d6_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.9%, #e68f8f 14.9%, #e68f8f 41.5%, transparent 41.5%);
# }
# #T_511d6_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 19.5%, transparent 19.5%);
# }
# #T_511d6_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 37.1%, transparent 37.1%);
# }
# #T_511d6_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 68.5%, transparent 68.5%);
# }
# #T_511d6_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 40.9%, transparent 40.9%);
# }
# #T_511d6_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 13.8%, transparent 13.8%);
# }
# #T_511d6_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 53.9%, transparent 53.9%);
# }
# #T_511d6_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 52.7%, transparent 52.7%);
# }
# #T_511d6_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 61.1%, transparent 61.1%);
# }
# #T_511d6_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 68.3%, transparent 68.3%);
# }
# #T_511d6_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 7.4%, transparent 7.4%);
# }
# #T_511d6_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 24.5%, #e68f8f 24.5%, #e68f8f 41.5%, transparent 41.5%);
# }
# #T_511d6_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 25.3%, transparent 25.3%);
# }
# #T_511d6_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 1.7%, #e68f8f 1.7%, #e68f8f 14.1%, transparent 14.1%);
# }
# #T_511d6_row6_col0, #T_511d6_row15_col0, #T_511d6_row21_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_511d6_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 65.5%, transparent 65.5%);
# }
# #T_511d6_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 9.8%, transparent 9.8%);
# }
# #T_511d6_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 41.5%, transparent 41.5%);
# }
# #T_511d6_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 25.7%, transparent 25.7%);
# }
# #T_511d6_row6_col8, #T_511d6_row27_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #7eb8ef 14.1%, #7eb8ef 21.6%, transparent 21.6%);
# }
# #T_511d6_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 63.8%, transparent 63.8%);
# }
# #T_511d6_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 17.1%, #e68f8f 17.1%, #e68f8f 41.5%, transparent 41.5%);
# }
# #T_511d6_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 30.3%, transparent 30.3%);
# }
# #T_511d6_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 46.9%, transparent 46.9%);
# }
# #T_511d6_row8_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_511d6_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 58.3%, transparent 58.3%);
# }
# #T_511d6_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 32.6%, transparent 32.6%);
# }
# #T_511d6_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 10.6%, transparent 10.6%);
# }
# #T_511d6_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 57.3%, transparent 57.3%);
# }
# #T_511d6_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_511d6_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 90.5%, transparent 90.5%);
# }
# #T_511d6_row9_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_511d6_row9_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 51.6%, tr
# QRG sorted list (2021-08-15)
# <style type="text/css">
# #T_d5aca_row0_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_d5aca_row0_col2, #T_d5aca_row1_col2, #T_d5aca_row2_col2, #T_d5aca_row3_col2, #T_d5aca_row4_col2, #T_d5aca_row5_col1, #T_d5aca_row6_col1, #T_d5aca_row7_col2, #T_d5aca_row8_col2, #T_d5aca_row9_col1, #T_d5aca_row10_col2, #T_d5aca_row11_col2, #T_d5aca_row12_col1, #T_d5aca_row13_col2, #T_d5aca_row14_col1, #T_d5aca_row15_col1, #T_d5aca_row16_col2, #T_d5aca_row17_col2, #T_d5aca_row18_col1, #T_d5aca_row19_col1, #T_d5aca_row20_col2, #T_d5aca_row21_col1, #T_d5aca_row22_col2, #T_d5aca_row23_col2, #T_d5aca_row24_col2, #T_d5aca_row25_col2, #T_d5aca_row26_col2, #T_d5aca_row27_col1, #T_d5aca_row28_col2, #T_d5aca_row29_col2, #T_d5aca_row30_col2, #T_d5aca_row31_col2, #T_d5aca_row32_col2 {
#   background-color: #fda37b;
# }
# #T_d5aca_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 58.3%, transparent 58.3%);
# }
# #T_d5aca_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 32.6%, transparent 32.6%);
# }
# #T_d5aca_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 10.6%, transparent 10.6%);
# }
# #T_d5aca_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 57.3%, transparent 57.3%);
# }
# #T_d5aca_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_d5aca_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 90.5%, transparent 90.5%);
# }
# #T_d5aca_row1_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_d5aca_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 13.9%, transparent 13.9%);
# }
# #T_d5aca_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 63.8%, transparent 63.8%);
# }
# #T_d5aca_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
# }
# #T_d5aca_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 52.8%, transparent 52.8%);
# }
# #T_d5aca_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 74.9%, transparent 74.9%);
# }
# #T_d5aca_row1_col8, #T_d5aca_row18_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #7eb8ef 14.1%, #7eb8ef 21.6%, transparent 21.6%);
# }
# #T_d5aca_row2_col0, #T_d5aca_row5_col0, #T_d5aca_row19_col0, #T_d5aca_row21_col0, #T_d5aca_row23_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_d5aca_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 28.8%, transparent 28.8%);
# }
# #T_d5aca_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 58.4%, transparent 58.4%);
# }
# #T_d5aca_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 6.0%, transparent 6.0%);
# }
# #T_d5aca_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 44.9%, transparent 44.9%);
# }
# #T_d5aca_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 65.3%, transparent 65.3%);
# }
# #T_d5aca_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 38.5%, transparent 38.5%);
# }
# #T_d5aca_row3_col0, #T_d5aca_row14_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_d5aca_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 1.2%, transparent 1.2%);
# }
# #T_d5aca_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 3.1%, transparent 3.1%);
# }
# #T_d5aca_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 0.9%, transparent 0.9%);
# }
# #T_d5aca_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 50.3%, transparent 50.3%);
# }
# #T_d5aca_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 57.7%, transparent 57.7%);
# }
# #T_d5aca_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #7eb8ef 14.1%, #7eb8ef 32.7%, transparent 32.7%);
# }
# #T_d5aca_row4_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_d5aca_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 1.0%, transparent 1.0%);
# }
# #T_d5aca_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 1.6%, transparent 1.6%);
# }
# #T_d5aca_row4_col5, #T_d5aca_row22_col3, #T_d5aca_row22_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 0.7%, transparent 0.7%);
# }
# #T_d5aca_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 53.0%, transparent 53.0%);
# }
# #T_d5aca_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 54.1%, transparent 54.1%);
# }
# #T_d5aca_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 41.1%, transparent 41.1%);
# }
# #T_d5aca_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 68.5%, transparent 68.5%);
# }
# #T_d5aca_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 40.9%, transparent 40.9%);
# }
# #T_d5aca_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 13.8%, transparent 13.8%);
# }
# #T_d5aca_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 53.9%, transparent 53.9%);
# }
# #T_d5aca_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 52.7%, transparent 52.7%);
# }
# #T_d5aca_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 61.1%, transparent 61.1%);
# }
# #T_d5aca_row6_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_d5aca_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 30.6%, transparent 30.6%);
# }
# #T_d5aca_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_d5aca_row6_col5, #T_d5aca_row32_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 12.0%, transparent 12.0%);
# }
# #T_d5aca_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 47.2%, transparent 47.2%);
# }
# #T_d5aca_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 51.3%, transparent 51.3%);
# }
# #T_d5aca_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 45.5%, transparent 45.5%);
# }
# #T_d5aca_row7_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_d5aca_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 46.4%, transparent 46.4%);
# }
# #T_d5aca_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 24.9%, transparent 24.9%);
# }
# #T_d5aca_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 11.2%, transparent 11.2%);
# }
# #T_d5aca_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 56.9%, transparent 56.9%);
# }
# #T_d5aca_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 43.8%, transparent 43.8%);
# }
# #T_d5aca_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 64.6%, transparent 64.6%);
# }
# #T_d5aca_row8_col0, #T_d5aca_row9_col0, #T_d5aca_row18_col0 {
#   background-color:

# %% [markdown]
# ### FANGAMのみ大きく出してみる

# %%
mi.plot_eps(fangam,largefig=True)
mi.search_good_eps(fangam, last=200)

# %% [markdown]
# ## Health

# %%
H_E11 = [
    "PFE",
    "DHR",
    "MRNA",
    "BMY",
    "AMGN",
    "BNTX",
]
H_E10 = [
    "ANTM",
    "VEEV",
    "BIIB",
    "A",
    "RPRX",
]
H_E9 = [
    "INOV",
    "PGNY",
    "INMD",
    "DOCS"
]
health = H_E11 + H_E10 + H_E9

# %%
# import importlib
# importlib.reload(mi)
# EPS history
mi.plot_eps_history(health,last=20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_70/1936969341.py in <module>
#       2 # importlib.reload(mi)
#       3 # EPS history
# ----> 4 mi.plot_eps_history(health,last=20)
#
# NameError: name 'health' is not defined

# %%
import importlib
importlib.reload(mi)

df_res=mi.show_valuation(health,table=True)
#df_cap=mi.show_valuation(health,table=True,hist=False,key="Cap")
# Out:
# PSR sorted list (2021-08-15)
# <style type="text/css">
# #T_fe512_row0_col0 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_fe512_row0_col2, #T_fe512_row1_col1, #T_fe512_row2_col1, #T_fe512_row3_col1, #T_fe512_row4_col2, #T_fe512_row5_col2, #T_fe512_row6_col1, #T_fe512_row7_col1, #T_fe512_row8_col1, #T_fe512_row9_col2, #T_fe512_row10_col1, #T_fe512_row11_col2, #T_fe512_row12_col2, #T_fe512_row13_col2, #T_fe512_row14_col1 {
#   background-color: #fda37b;
# }
# #T_fe512_row0_col3, #T_fe512_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_fe512_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 72.7%, transparent 72.7%);
# }
# #T_fe512_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 85.4%, transparent 85.4%);
# }
# #T_fe512_row0_col6, #T_fe512_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 21.3%, transparent 21.3%);
# }
# #T_fe512_row0_col7, #T_fe512_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.4%, transparent 0.4%);
# }
# #T_fe512_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 81.3%, transparent 81.3%);
# }
# #T_fe512_row1_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_fe512_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 71.5%, transparent 71.5%);
# }
# #T_fe512_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 26.4%, transparent 26.4%);
# }
# #T_fe512_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 57.8%, transparent 57.8%);
# }
# #T_fe512_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 50.8%, transparent 50.8%);
# }
# #T_fe512_row1_col8, #T_fe512_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 100.0%, transparent 100.0%);
# }
# #T_fe512_row2_col0, #T_fe512_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fe512_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 56.9%, transparent 56.9%);
# }
# #T_fe512_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 20.7%, transparent 20.7%);
# }
# #T_fe512_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 87.0%, transparent 87.0%);
# }
# #T_fe512_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 34.9%, transparent 34.9%);
# }
# #T_fe512_row2_col7, #T_fe512_row10_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.7%, transparent 0.7%);
# }
# #T_fe512_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 72.6%, transparent 72.6%);
# }
# #T_fe512_row3_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_fe512_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 36.9%, transparent 36.9%);
# }
# #T_fe512_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 11.7%, transparent 11.7%);
# }
# #T_fe512_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 70.4%, transparent 70.4%);
# }
# #T_fe512_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 100.0%, transparent 100.0%);
# }
# #T_fe512_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 100.0%, transparent 100.0%);
# }
# #T_fe512_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 7.1%, transparent 7.1%);
# }
# #T_fe512_row4_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_fe512_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 34.4%, transparent 34.4%);
# }
# #T_fe512_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 22.2%, transparent 22.2%);
# }
# #T_fe512_row4_col7, #T_fe512_row6_col7, #T_fe512_row12_col7, #T_fe512_row13_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.3%, transparent 0.3%);
# }
# #T_fe512_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 33.5%, transparent 33.5%);
# }
# #T_fe512_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 34.1%, transparent 34.1%);
# }
# #T_fe512_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.6%, transparent 0.6%);
# }
# #T_fe512_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #7eb8ef 7.1%, #7eb8ef 16.9%, transparent 16.9%);
# }
# #T_fe512_row6_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_fe512_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 27.2%, transparent 27.2%);
# }
# #T_fe512_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_fe512_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 34.5%, transparent 34.5%);
# }
# #T_fe512_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 11.4%, transparent 11.4%);
# }
# #T_fe512_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 44.0%, transparent 44.0%);
# }
# #T_fe512_row7_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_fe512_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 26.7%, transparent 26.7%);
# }
# #T_fe512_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 24.0%, transparent 24.0%);
# }
# #T_fe512_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 24.2%, transparent 24.2%);
# }
# #T_fe512_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 17.7%, transparent 17.7%);
# }
# #T_fe512_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.5%, transparent 0.5%);
# }
# #T_fe512_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 53.1%, transparent 53.1%);
# }
# #T_fe512_row8_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_fe512_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 26.4%, transparent 26.4%);
# }
# #T_fe512_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 35.0%, transparent 35.0%);
# }
# #T_fe512_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 42.6%, transparent 42.6%);
# }
# #T_fe512_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 43.8%, transparent 43.8%);
# }
# #T_fe512_row9_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_fe512_row9_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 16.4%, transparent 16.4%);
# }
# #T_fe512_row9_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 13.5%, transparent 13.5%);
# }
# #T_fe512_row9_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 68.1%, transparent 68.1%);
# }
# #T_fe512_row9_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 49.8%, transparent 49.

# %%
#import pandas as pd
import importlib
importlib.reload(mi)
pd.__version__
# Out:
# '1.3.1'

# %% [markdown]
# ## Get stock info of your favorite

# %% [markdown]
# ### Find Tickers with high EPS beat ratio

# %%
# pd.set_option('display.max_rows', df.shape[0]+1)
tickers_nasdaq = si.tickers_nasdaq()
ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_36/4042142324.py in <module>
#       1 # pd.set_option('display.max_rows', df.shape[0]+1)
#       2 tickers_nasdaq = si.tickers_nasdaq()
# ----> 3 ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
#
# AttributeError: module 'mystock_info' has no attribute 'search_good_eps'

# %%
# !pip  install pandas==1.3.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas==1.3.1
#   Downloading pandas-1.3.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 310 kB/s eta 0:00:01    |███████████▏                    | 4.1 MB 4.5 MB/s eta 0:00:02     |███████████████████████▉        | 8.8 MB 4.5 MB/s eta 0:00:01     |███████████████████████████▊    | 10.2 MB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (2021.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.1) (1.16.0)
# Installing collected packages: pandas
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastquant 0.1.6.1 requires pandas==1.1.5, but you have pandas 1.3.1 which is incompatible.
# Successfully installed pandas-1.3.1
# WARNING: You are using pip version 21.2.2; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
