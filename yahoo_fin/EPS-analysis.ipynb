# %% [markdown]
# # EPS analysis

# %% [markdown]
# ## import modules and difine basic modules & functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import yahoo_fin.stock_info as si

# private module
import mystock_info as mi

# %%
import importlib
importlib.reload(mi)
# Out:
# <module 'mystock_info' from '/home/jovyan/yahoo_fin/mystock_info.py'>

# %% [markdown]
# ## Tech companies

# %%
fangam=["FB","AAPL","NFLX","GOOG","AMZN","MSFT"]

###
ant=["ADBE","NVDA","TSLA"]
saas=["CRWD","OKTA","ZS","TTD","TWLO"]
ecommerce=["SHOP","ETSY","FIVN"]

fintech=["SQ","DOCU", "PYPL"]
media=["TWTR","PINS"]
techs=["U","ZM","FVRR","ABNB","ROKU"]
eauto=["F","GM","MGA"]

growth1=ant+saas+ecommerce
growth2=fintech+media+techs+eauto

# %%
E12 = ["FB", "AAPL", "GOOG", "AMZN", "MSFT"] # Trillion
E11 = ["NFLX", "TSLA","ADBE", "NVDA","PYPL", "SHOP", "SQ"] # over 100 Billion
E10_5 = ( # Over 50 Billion
    ["ABNB","SNOW", "ZM"]  #, "GM", "F"
    + ["CRWD", "TWLO","TWTR"]
    + [ "DOCU", "PLTR"]
)
E10_1 = ["ROKU", "OKTA", "DDOG", "EPAM","TTD","U", "MGA","ZS", "ETSY","FIVN", "PINS","MDB", "HUBS"] # over 10 Billion

E9 = ["FVRR"] # over 1 Billion

LIST=E12+E11+E10_5+E10_1+E9
SLIST=E11+E10_5+E10_1+E9

###

# %% [markdown]
# ### PSR distribution and Market Cap

# %%
import importlib
importlib.reload(mi)
df=mi.show_valuation(LIST, table=False, key="Cap")
#df["Market Cap"].sort_values(ascending=False)
# Out:
# The top 5 CAP stocks (2021-09-04)
# <style  type="text/css" >
# #T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow0_col2,#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow1_col2,#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow2_col2,#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow3_col2,#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow4_col2{
#             background-color:  #fda37b;
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 49.9%, transparent 49.9%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow0_col5,#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow0_col6,#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 59.1%, transparent 59.1%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 50.1%, transparent 50.1%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 61.7%, transparent 61.7%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.9%, transparent 64.9%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 51.8%, transparent 51.8%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.5%, transparent 20.5%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow3_col0{
#             background-color:  #77b5d9;
#             color:  #000000;
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 29.5%, transparent 29.5%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 38.6%, transparent 38.6%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow3_col6,#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 44.2%, transparent 44.2%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 22.3%, transparent 22.3%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow4_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 46.1%, transparent 46.1%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
#         }#T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
#         }</style><table id="T_4a922ff2_0d6a_11ec_a7cd_872f12bb360b" ><thead>    <tr>        <th class="index_name level0" >info</th>        <th class="col_heading level0 col0" >Market Cap</th>        <th class="col_heading level0 col1" >Previous Close</th>        <th class="col_heading level0 col2" >1y Target Est</th>        <th class="col_heading level0 col3" >Price/Sales (ttm)</th>        <th class="col_heading level0 col4" >PE Ratio (TTM)</th>        <th class="col_heading level0 col5" >Price/Book (mrq)</th>        <th class="col_heading level0 col6" >Return on Equity (ttm)</th>        <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>        <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>        <th class="col_heading level0 col9" >Y!</th>        <th class="col_heading level0 col10" >alpha</th>        <th class="col_heading level0 col11" >TS</th>    </tr>    <tr>        <th class="index_name level0" >ticker</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4a922ff2_0d6a_11ec_a7cd_872f12bb360blevel0_row0" class="row_heading level0 row0" >AAPL</th>
#                         <td id="T_4a922ff2_0d6a_11ec_a7cd_872f12bb360brow0_col0" class="data row0 col0" >$2.55e+12</td>

# %%
df.head()
# Out:
# info      Market Cap  Previous Close  1y Target Est  Price/Sales (ttm)  \
# ticker
# AAPL    2.464000e+12          148.89         159.34               7.10
# MSFT    2.188000e+12          289.81         298.92              13.01
# GOOG    1.837000e+12         2767.79        2625.00               8.34
# AMZN    1.668000e+12         3303.50        4241.33               3.76
# FB      1.025000e+12          362.65         386.47               9.78
#
# info    PE Ratio (TTM)  Price/Book (mrq)  Return on Equity (ttm)  \
# ticker
# AAPL             29.18             38.39                  127.13
# MSFT             36.17             15.41                   47.08
# GOOG             30.02              7.78                   28.29
# AMZN             57.39             14.52                   31.23
# FB               27.00              7.43                   31.33
#
# info    Quarterly Revenue Growth (yoy)  Operating Cash Flow Margin(ttm)  \
# ticker
# AAPL                              36.4                         0.300755
# MSFT                              21.3                         0.456541
# GOOG                              61.6                         0.367095
# AMZN                              27.2                         0.133815
# FB                                55.6                         0.471037
#
# info                                        Y!  \
# ticker
# AAPL    Y#https://finance.yahoo.com/quote/AAPL
# MSFT    Y#https://finance.yahoo.com/quote/MSFT
# GOOG    Y#https://finance.yahoo.com/quote/GOOG
# AMZN    Y#https://finance.yahoo.com/quote/AMZN
# FB        Y#https://finance.yahoo.com/quote/FB
#
# info                                     alpha  \
# ticker
# AAPL    a#https://seekingalpha.com/symbol/AAPL
# MSFT    a#https://seekingalpha.com/symbol/MSFT
# GOOG    a#https://seekingalpha.com/symbol/GOOG
# AMZN    a#https://seekingalpha.com/symbol/AMZN
# FB        a#https://seekingalpha.com/symbol/FB
#
# info                                                  TS
# ticker
# AAPL    TS#https://jp.tradingview.com/chart/?symbol=AAPL
# MSFT    TS#https://jp.tradingview.com/chart/?symbol=MSFT
# GOOG    TS#https://jp.tradingview.com/chart/?symbol=GOOG
# AMZN    TS#https://jp.tradingview.com/chart/?symbol=AMZN
# FB        TS#https://jp.tradingview.com/chart/?symbol=FB

# %% [markdown]
# ### EPS history

# %%
import importlib
importlib.reload(mi)

#for i in [fangam, growth1, growth2]:
for i in [E12,E11,E10_5,E10_1,E9]:
    
    mi.plot_eps_history(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_76/1546579379.py in <module>
#       5 for i in [E12,E11,E10_5,E10_1,E9]:
#       6
# ----> 7     mi.plot_eps_history(i)
#
# ~/yahoo_fin/mystock_info.py in plot_eps_history(tickers, clear_cache, last, largefig, verbose)
#     267         df_ticker=df_ticker.tail(min(last, len(df_ticker)))
#     268
# --> 269         _plot_fig(df_ticker, ax, target =["epsactual", "epsestimate"],
#     270         title=df_ticker["ticker"][0],ylabel="EPS")
#     271
#
# ~/yahoo_fin/mystock_info.py in _plot_fig(df, ax, target, title, ylabel, xticklabels, axhline)
#     216     axhline (float) : draw horizontal line at given values
#     217     """
# --> 218     sns.lineplot(ax=ax, data=df[target], marker="o")
#     219     ax.axhline(linewidth=1, linestyle="-")
#     220     axhline != None and ax.axhline(y=axhline,linewidth=1, linestyle="--", color="red")
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     699         return ax
#     700
# --> 701     p._attach(ax)
#     702
#     703     p.plot(ax, kwargs)
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py in _attach(self, obj, allowed_types, log_scale)
#    1125             # its mapping, meaning that it won't handle unshared axes well either.
#    1126             for ax in ax_list:
# -> 1127                 axis = getattr(ax, f"{var}axis")
#    1128                 seed_data = self.plot_data[var]
#    1129                 if var_type == "categorical":
#
# AttributeError: 'numpy.ndarray' object has no attribute 'xaxis'

# %%
mi.plot_eps_history(E9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_76/1573492137.py in <module>
# ----> 1 mi.plot_eps_history(E9)
#
# ~/yahoo_fin/mystock_info.py in plot_eps_history(tickers, clear_cache, last, largefig, verbose)
#     267         df_ticker=df_ticker.tail(min(last, len(df_ticker)))
#     268
# --> 269         _plot_fig(df_ticker, ax, target =["epsactual", "epsestimate"],
#     270         title=df_ticker["ticker"][0],ylabel="EPS")
#     271
#
# ~/yahoo_fin/mystock_info.py in _plot_fig(df, ax, target, title, ylabel, xticklabels, axhline)
#     216     axhline (float) : draw horizontal line at given values
#     217     """
# --> 218     sns.lineplot(ax=ax, data=df[target], marker="o")
#     219     ax.axhline(linewidth=1, linestyle="-")
#     220     axhline != None and ax.axhline(y=axhline,linewidth=1, linestyle="--", color="red")
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     699         return ax
#     700
# --> 701     p._attach(ax)
#     702
#     703     p.plot(ax, kwargs)
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py in _attach(self, obj, allowed_types, log_scale)
#    1125             # its mapping, meaning that it won't handle unshared axes well either.
#    1126             for ax in ax_list:
# -> 1127                 axis = getattr(ax, f"{var}axis")
#    1128                 seed_data = self.plot_data[var]
#    1129                 if var_type == "categorical":
#
# AttributeError: 'numpy.ndarray' object has no attribute 'xaxis'

# %%
import importlib
importlib.reload(mi)
#mi.show_beat_ratio(LIST, last=20)
for i in [E12,E11,E10_5,E10_1,E9]:
    df_res = mi.show_valuation(i, hist=False, table=True)
# Out:
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow0_col2,#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow1_col2,#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow2_col2,#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow3_col2,#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow4_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow0_col3,#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 61.7%, transparent 61.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 61.7%, transparent 61.7%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 46.1%, transparent 46.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 46.1%, transparent 46.1%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow1_col6,#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #519ccc;
#             color:  #000000;
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.9%, transparent 64.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.9%, transparent 64.9%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 51.8%, transparent 51.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 51.8%, transparent 51.8%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.5%, transparent 20.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.5%, transparent 20.5%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow3_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 49.9%, transparent 49.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 49.9%, transparent 49.9%);
#         }#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow3_col6,#T_df5ddfb2_0d6c_11ec_a7cd_872f12bb360brow4_col4{
#             width:  10em;
#              height:  80%;
#             b
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #e1edf8;
#             color:  #000000;
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow0_col2,#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow1_col1,#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow2_col1,#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow3_col1,#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow4_col2,#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow5_col2,#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow6_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow0_col3,#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 20.6%, transparent 20.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 20.6%, transparent 20.6%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 41.7%, transparent 41.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 41.7%, transparent 41.7%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 73.7%, transparent 73.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 73.7%, transparent 73.7%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 39.6%, transparent 39.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 39.6%, transparent 39.6%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 23.2%, transparent 23.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 23.2%, transparent 23.2%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #2676b8;
#             color:  #000000;
#             background-color:  #2676b8;
#             color:  #000000;
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 52.0%, transparent 52.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 52.0%, transparent 52.0%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 21.2%, transparent 21.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 21.2%, transparent 21.2%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 58.7%, transparent 58.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 58.7%, transparent 58.7%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 89.5%, transparent 89.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 89.5%, transparent 89.5%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 47.7%, transparent 47.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 47.7%, transparent 47.7%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 60.1%, transparent 60.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 60.1%, transparent 60.1%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #b0d2e7;
#             color:  #000000;
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 44.1%, transparent 44.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 44.1%, transparent 44.1%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 14.9%, transparent 14.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 14.9%, transparent 14.9%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 50.0%, transparent 50.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 50.0%, transparent 50.0%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow2_col6,#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 15.8%, transparent 15.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 15.8%, transparent 15.8%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 80.8%, transparent 80.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 80.8%, transparent 80.8%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow3_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 35.1%, transparent 35.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 35.1%, transparent 35.1%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 63.4%, transparent 63.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 63.4%, transparent 63.4%);
#         }#T_dfa5dcc2_0d6c_11ec_a7cd_872f12bb360brow3_col6{
#             width
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #0e59a2;
#             color:  #f1f1f1;
#             background-color:  #0e59a2;
#             color:  #f1f1f1;
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow0_col2,#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow1_col2,#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow2_col1,#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow3_col2,#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow4_col2,#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow5_col2,#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow6_col2,#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow7_col2,#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow8_col2,#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow9_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow0_col3,#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 6.5%, transparent 6.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 6.5%, transparent 6.5%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 51.2%, #e68f8f 51.2%, #e68f8f 72.5%, transparent 72.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 51.2%, #e68f8f 51.2%, #e68f8f 72.5%, transparent 72.5%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.9%, transparent 34.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.9%, transparent 34.9%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 3.1%, transparent 3.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 3.1%, transparent 3.1%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #c6dbef;
#             color:  #000000;
#             background-color:  #c6dbef;
#             color:  #000000;
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.7%, transparent 51.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.7%, transparent 51.7%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 24.5%, transparent 24.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 24.5%, transparent 24.5%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.2%, #e68f8f 55.2%, #e68f8f 72.5%, transparent 72.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.2%, #e68f8f 55.2%, #e68f8f 72.5%, transparent 72.5%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 23.3%, transparent 23.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 23.3%, transparent 23.3%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 67.1%, transparent 67.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 67.1%, transparent 67.1%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #f5fafe;
#             color:  #000000;
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 36.3%, transparent 36.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 36.3%, transparent 36.3%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 8.7%, transparent 8.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 8.7%, transparent 8.7%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 72.5%, transparent 72.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 72.5%, transparent 72.5%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 16.4%, transparent 16.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 16.4%, transparent 16.4%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 8.7%, transparent 8.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 8.7%, transparent 8.7%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow3_col0{
#             background-color:  #d3e3f3;
#             color:  #000000;
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 31.2%, transparent 31.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 31.2%, transparent 31.2%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.4%, #e68f8f 35.4%, #e68f8f 72.5%, transparent 72.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.4%, #e68f8f 35.4%, #e68f8f 72.5%, transparent 72.5%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 16.6%, transparent 16.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 16.6%, transparent 16.6%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 40.3%, transparent 40.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 40.3%, transparent 40.3%);
#         }#T_dff5a7e8_0d6c_11ec_a7cd_872f12bb360brow4_col0{
#             background-color:  #bcd7eb;
#             color:
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow0_col1,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow1_col2,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow2_col1,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow3_col2,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow4_col1,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow5_col2,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow6_col1,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow7_col2,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow8_col2,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow9_col2,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow10_col2,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow11_col2,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow12_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow0_col3,#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.9%, #e68f8f 14.9%, #e68f8f 46.7%, transparent 46.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.9%, #e68f8f 14.9%, #e68f8f 46.7%, transparent 46.7%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 47.7%, transparent 47.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 47.7%, transparent 47.7%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 58.3%, transparent 58.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 58.3%, transparent 58.3%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #08468b;
#             color:  #f1f1f1;
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 85.6%, transparent 85.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 85.6%, transparent 85.6%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 60.5%, transparent 60.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 60.5%, transparent 60.5%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.3%, #e68f8f 43.3%, #e68f8f 46.7%, transparent 46.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.3%, #e68f8f 43.3%, #e68f8f 46.7%, transparent 46.7%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 53.4%, transparent 53.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 53.4%, transparent 53.4%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 43.7%, transparent 43.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 43.7%, transparent 43.7%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #4292c6;
#             color:  #000000;
#             background-color:  #4292c6;
#             color:  #000000;
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 71.4%, transparent 71.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 71.4%, transparent 71.4%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.3%, transparent 64.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.3%, transparent 64.3%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 46.7%, transparent 46.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 46.7%, transparent 46.7%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 35.0%, transparent 35.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 35.0%, transparent 35.0%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.0%, #e68f8f 5.0%, #e68f8f 12.6%, transparent 12.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.0%, #e68f8f 5.0%, #e68f8f 12.6%, transparent 12.6%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow3_col0{
#             background-color:  #084d96;
#             color:  #f1f1f1;
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 62.8%, transparent 62.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 62.8%, transparent 62.8%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 8.7%, transparent 8.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 8.7%, transparent 8.7%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.5%, #e68f8f 37.5%, #e68f8f 46.7%, transparent 46.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.5%, #e68f8f 37.5%, #e68f8f 46.7%, transparent 46.7%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 45.9%, transparent 45.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 45.9%, transparent 45.9%);
#         }#T_e04a636e_0d6c_11ec_a7cd_872f12bb360brow3_col8,#T_e04a636e_0d6c_11e
# PSR sorted list (2021-09-04)
# /usr/local/lib/python3.8/dist-packages/pandas/io/formats/style.py:1210: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# /usr/local/lib/python3.8/dist-packages/pandas/io/formats/style.py:1210: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# #T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col3,#T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 100.0%, transparent 100.0%);
#         }#T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#         }#T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 20.9%, transparent 20.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 20.9%, transparent 20.9%);
#         }</style><table id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360b" ><thead>    <tr>        <th class="index_name level0" >info</th>        <th class="col_heading level0 col0" >Market Cap</th>        <th class="col_heading level0 col1" >Previous Close</th>        <th class="col_heading level0 col2" >1y Target Est</th>        <th class="col_heading level0 col3" >Price/Sales (ttm)</th>        <th class="col_heading level0 col4" >PE Ratio (TTM)</th>        <th class="col_heading level0 col5" >Price/Book (mrq)</th>        <th class="col_heading level0 col6" >Return on Equity (ttm)</th>        <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>        <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>        <th class="col_heading level0 col9" >Y!</th>        <th class="col_heading level0 col10" >alpha</th>        <th class="col_heading level0 col11" >TS</th>    </tr>    <tr>        <th class="index_name level0" >ticker</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360blevel0_row0" class="row_heading level0 row0" >FVRR</th>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col0" class="data row0 col0" >$6.59e+09</td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col1" class="data row0 col1" >$183.1</td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col2" class="data row0 col2" >$215.8</td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col3" class="data row0 col3" >26.2</td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col4" class="data row0 col4" >-</td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col5" class="data row0 col5" >19.3</td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col6" class="data row0 col6" >-12.6%</td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col7" class="data row0 col7" >59.7%</td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col8" class="data row0 col8" >12.6%</td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/FVRR">Y</a></td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/FVRR">a</a></td>
#                         <td id="T_e08bff54_0d6c_11ec_a7cd_872f12bb360brow0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=FVRR">TS</a></td>
#             </tr>
#     </tbody></table>

# %%
import importlib
importlib.reload(mi)
#df_res = mi.show_valuation(LIST, hist=False, table=True)
df_res = mi.show_valuation(SLIST, hist=False, table=True, key="PSR")
# Out:
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #e0ecf8;
#             color:  #000000;
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow3_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow4_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow5_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow6_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow7_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow8_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow9_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow10_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow11_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow12_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow13_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow14_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow15_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow16_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow17_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow18_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow19_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow20_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow21_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow22_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow23_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow24_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow25_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow26_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow27_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow28_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col3,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow10_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 6.5%, transparent 6.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 6.5%, transparent 6.5%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.1%, #e68f8f 35.1%, #e68f8f 49.7%, transparent 49.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.1%, #e68f8f 35.1%, #e68f8f 49.7%, transparent 49.7%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.9%, transparent 34.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.9%, transparent 34.9%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #7eb8ef 12.6%, #7eb8ef 15.2%, transparent 15.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #7eb8ef 12.6%, #7eb8ef 15.2%, transparent 15.2%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col0,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col0,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow6_col0{
#             background-color:  #eef5fc;
#             color:  #000000;
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 60.7%, transparent 60.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 60.7%, transparent 60.7%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 27.0%, transparent 27.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 27.0%, transparent 27.0%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.6%, #e68f8f 19.6%, #e68f8f 49.7%, transparent 49.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.6%, #e68f8f 19.6%, #e68f8f 49.7%, transparent 49.7%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 19.9%, transparent 19.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 19.9%, transparent 19.9%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 58.3%, transparent 58.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 58.3%, transparent 58.3%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.9%, transparent 51.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.9%, transparent 51.9%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col5,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow20_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 16.3%, transparent 16.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 16.3%, transparent 16.3%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.5%, #e68f8f 46.5%, #e68f8f 49.7%, transparent 49.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.5%, #e68f8f 46.5%, #e68f8f 49.7%, transparent 49.7%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col7,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow12_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 22.4%, transparent 22.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 22.4%, transparent 22.4%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 43.7%, transparent 43.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 43.7%, transparent 43.7%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow3_col0,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow12_col0{
#             background-color:  #e7f1fa;
#             color:  #000000;
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.7%, transparent 51.7%);
#             wid

# %% [markdown]
# ### FANGAMのみ大きく出してみる

# %%
mi.plot_eps(fangam,largefig=True)
mi.search_good_eps(fangam, last=200)

# %% [markdown]
# ## Health/Bio

# %%
H_E11 = [
    "PFE",
    "DHR",
    "MRNA",
    "BMY",
    "AMGN",
    "BNTX",
]
H_E10 = [
    "ANTM",
    "VEEV",
    "BIIB",
    "A",
    "RPRX",
]
H_E9 = [
    "INOV",
    "PGNY",
    "INMD",
    "DOCS"
]
health = H_E11 + H_E10 + H_E9

# %%
import importlib
importlib.reload(mi)
# EPS history
df_res=mi.plot_eps_history(health,last=20)

# %%
import importlib
importlib.reload(mi)

df_res=mi.show_valuation(health,table=True)
#df_cap=mi.show_valuation(health,table=True,hist=False,key="Cap")
# Out:
# PSR sorted list (2021-08-17)
# <style type="text/css">
# #T_5f99f_row0_col0 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_5f99f_row0_col2, #T_5f99f_row1_col1, #T_5f99f_row2_col1, #T_5f99f_row3_col1, #T_5f99f_row4_col2, #T_5f99f_row5_col2, #T_5f99f_row6_col1, #T_5f99f_row7_col1, #T_5f99f_row8_col1, #T_5f99f_row9_col2, #T_5f99f_row10_col1, #T_5f99f_row11_col2, #T_5f99f_row12_col2, #T_5f99f_row13_col2, #T_5f99f_row14_col1 {
#   background-color: #fda37b;
# }
# #T_5f99f_row0_col3, #T_5f99f_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_5f99f_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 72.7%, transparent 72.7%);
# }
# #T_5f99f_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 85.4%, transparent 85.4%);
# }
# #T_5f99f_row0_col6, #T_5f99f_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 21.3%, transparent 21.3%);
# }
# #T_5f99f_row0_col7, #T_5f99f_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.4%, transparent 0.4%);
# }
# #T_5f99f_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 81.3%, transparent 81.3%);
# }
# #T_5f99f_row1_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_5f99f_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 71.5%, transparent 71.5%);
# }
# #T_5f99f_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 26.4%, transparent 26.4%);
# }
# #T_5f99f_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 57.8%, transparent 57.8%);
# }
# #T_5f99f_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 50.8%, transparent 50.8%);
# }
# #T_5f99f_row1_col8, #T_5f99f_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 100.0%, transparent 100.0%);
# }
# #T_5f99f_row2_col0, #T_5f99f_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5f99f_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 56.9%, transparent 56.9%);
# }
# #T_5f99f_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 20.7%, transparent 20.7%);
# }
# #T_5f99f_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 87.0%, transparent 87.0%);
# }
# #T_5f99f_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 34.9%, transparent 34.9%);
# }
# #T_5f99f_row2_col7, #T_5f99f_row10_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.7%, transparent 0.7%);
# }
# #T_5f99f_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 72.6%, transparent 72.6%);
# }
# #T_5f99f_row3_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_5f99f_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 36.9%, transparent 36.9%);
# }
# #T_5f99f_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 11.7%, transparent 11.7%);
# }
# #T_5f99f_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 70.4%, transparent 70.4%);
# }
# #T_5f99f_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 100.0%, transparent 100.0%);
# }
# #T_5f99f_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 100.0%, transparent 100.0%);
# }
# #T_5f99f_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 7.1%, transparent 7.1%);
# }
# #T_5f99f_row4_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_5f99f_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 34.4%, transparent 34.4%);
# }
# #T_5f99f_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 22.2%, transparent 22.2%);
# }
# #T_5f99f_row4_col7, #T_5f99f_row6_col7, #T_5f99f_row12_col7, #T_5f99f_row13_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.3%, transparent 0.3%);
# }
# #T_5f99f_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 33.5%, transparent 33.5%);
# }
# #T_5f99f_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 34.1%, transparent 34.1%);
# }
# #T_5f99f_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.6%, transparent 0.6%);
# }
# #T_5f99f_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #7eb8ef 7.1%, #7eb8ef 16.9%, transparent 16.9%);
# }
# #T_5f99f_row6_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_5f99f_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 27.2%, transparent 27.2%);
# }
# #T_5f99f_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_5f99f_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 34.5%, transparent 34.5%);
# }
# #T_5f99f_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 11.4%, transparent 11.4%);
# }
# #T_5f99f_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 44.0%, transparent 44.0%);
# }
# #T_5f99f_row7_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_5f99f_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 26.7%, transparent 26.7%);
# }
# #T_5f99f_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 24.0%, transparent 24.0%);
# }
# #T_5f99f_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 24.2%, transparent 24.2%);
# }
# #T_5f99f_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 17.7%, transparent 17.7%);
# }
# #T_5f99f_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.5%, transparent 0.5%);
# }
# #T_5f99f_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 53.1%, transparent 53.1%);
# }
# #T_5f99f_row8_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_5f99f_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 26.4%, transparent 26.4%);
# }
# #T_5f99f_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 35.0%, transparent 35.0%);
# }
# #T_5f99f_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 42.6%, transparent 42.6%);
# }
# #T_5f99f_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 43.8%, transparent 43.8%);
# }
# #T_5f99f_row9_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_5f99f_row9_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 16.4%, transparent 16.4%);
# }
# #T_5f99f_row9_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 13.5%, transparent 13.5%);
# }
# #T_5f99f_row9_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 68.1%, transparent 68.1%);
# }
# #T_5f99f_row9_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 49.8%, transparent 49.

# %% [markdown]
# # VUGとIWFの組入銘柄（570銘柄）の優良銘柄

# %%
GOOD=["ADP","AKAM","AZO","BC","BRO","CRL","CPRT","DHR","EFX","FB","FND","IQV","LPX","MKSI","MMC","MPWR","MSFT","MTD","NVDA","ORLY","ROL","SCCO","SPGI","TPX","TRU"]
df_res = mi.show_valuation(GOOD, hist=True, table=True, key="PSR")
# Out:
# PSR sorted list (2021-08-23)
# <style type="text/css">
# #T_0ff7e_row0_col0 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_0ff7e_row0_col2, #T_0ff7e_row1_col1, #T_0ff7e_row2_col2, #T_0ff7e_row3_col2, #T_0ff7e_row4_col2, #T_0ff7e_row5_col1, #T_0ff7e_row6_col2, #T_0ff7e_row7_col1, #T_0ff7e_row8_col1, #T_0ff7e_row9_col2, #T_0ff7e_row10_col2, #T_0ff7e_row11_col2, #T_0ff7e_row12_col1, #T_0ff7e_row13_col2, #T_0ff7e_row14_col2, #T_0ff7e_row15_col2, #T_0ff7e_row16_col1, #T_0ff7e_row17_col2, #T_0ff7e_row18_col2, #T_0ff7e_row19_col2, #T_0ff7e_row20_col2, #T_0ff7e_row21_col2, #T_0ff7e_row22_col2, #T_0ff7e_row23_col2, #T_0ff7e_row24_col2 {
#   background-color: #fda37b;
# }
# #T_0ff7e_row0_col3, #T_0ff7e_row19_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_0ff7e_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 62.5%, transparent 62.5%);
# }
# #T_0ff7e_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 12.1%, transparent 12.1%);
# }
# #T_0ff7e_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 8.1%, transparent 8.1%);
# }
# #T_0ff7e_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 48.2%, transparent 48.2%);
# }
# #T_0ff7e_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 60.1%, transparent 60.1%);
# }
# #T_0ff7e_row1_col0, #T_0ff7e_row8_col0, #T_0ff7e_row9_col0, #T_0ff7e_row11_col0, #T_0ff7e_row13_col0, #T_0ff7e_row14_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_0ff7e_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 93.3%, transparent 93.3%);
# }
# #T_0ff7e_row1_col4, #T_0ff7e_row19_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_0ff7e_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 10.4%, transparent 10.4%);
# }
# #T_0ff7e_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 4.1%, transparent 4.1%);
# }
# #T_0ff7e_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 40.6%, transparent 40.6%);
# }
# #T_0ff7e_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 53.1%, transparent 53.1%);
# }
# #T_0ff7e_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0ff7e_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 60.4%, transparent 60.4%);
# }
# #T_0ff7e_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 33.3%, transparent 33.3%);
# }
# #T_0ff7e_row2_col5, #T_0ff7e_row22_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 8.4%, transparent 8.4%);
# }
# #T_0ff7e_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 9.5%, transparent 9.5%);
# }
# #T_0ff7e_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 15.0%, transparent 15.0%);
# }
# #T_0ff7e_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
# }
# #T_0ff7e_row3_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0ff7e_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 59.7%, transparent 59.7%);
# }
# #T_0ff7e_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 37.9%, transparent 37.9%);
# }
# #T_0ff7e_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 43.3%, transparent 43.3%);
# }
# #T_0ff7e_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 15.1%, transparent 15.1%);
# }
# #T_0ff7e_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 5.9%, transparent 5.9%);
# }
# #T_0ff7e_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 77.5%, transparent 77.5%);
# }
# #T_0ff7e_row4_col0, #T_0ff7e_row5_col0, #T_0ff7e_row21_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_0ff7e_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 59.5%, transparent 59.5%);
# }
# #T_0ff7e_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 35.0%, transparent 35.0%);
# }
# #T_0ff7e_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 5.3%, transparent 5.3%);
# }
# #T_0ff7e_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 6.1%, transparent 6.1%);
# }
# #T_0ff7e_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 23.6%, transparent 23.6%);
# }
# #T_0ff7e_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 69.5%, transparent 69.5%);
# }
# #T_0ff7e_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 45.2%, transparent 45.2%);
# }
# #T_0ff7e_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 45.2%, transparent 45.2%);
# }
# #T_0ff7e_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 96.0%, transparent 96.0%);
# }
# #T_0ff7e_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 44.6%, transparent 44.6%);
# }
# #T_0ff7e_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 23.8%, transparent 23.8%);
# }
# #T_0ff7e_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 42.3%, transparent 42.3%);
# }
# #T_0ff7e_row6_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_0ff7e_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 42.9%, transparent 42.9%);
# }
# #T_0ff7e_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 23.5%, transparent 23.5%);
# }
# #T_0ff7e_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 3.8%, transparent 3.8%);
# }
# #T_0ff7e_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 6.3%, transparent 6.3%);
# }
# #T_0ff7e_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 39.2%, transparent 39.2%);
# }
# #T_0ff7e_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
# }
# #T_0ff7e_row7_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_0ff7e_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 38.1%, transparent 38.1%);
# }
# #T_0ff7e_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 37.7%, transparent 37.7%);
# }
# #T_0ff7e_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 3.0%, transparent 3.0%);
# }
# #T_0ff7e_row7_col6, #T_0ff7e_row14_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 2.8%, transparent 2.8%);
# }
# #T_0ff7e_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 25.6%, transparent 25.6%);
# }
# #T_0ff7e_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 49.5%, transparent 49.5%);
# }
# #T_0ff7e_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 37.5%, transparent 37.5%);
# }
# #T_0ff7e_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 51.1%, transparent 51.1%);
# }
# #T_0ff7e_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 9.6%, transparent 9.6%);
# }
# #T_0ff7e_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 7.0%, transparent 7.0%);
# }
# #T_0ff7e_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 10.8%, transparent 10.8%);
# }
# #T_0ff7e_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 30.6%, transparent 30.6%);
# }
# #T_0ff7e_row9_col3 {
#   width: 10em;

# %%
df_res=mi.plot_eps_history(GOOD,last=20)

# %%
ret=mi.show_beat_ratio(GOOD,last=40,threshold=95,min_qtrs=20)
# Out:
# Tickers list of which beat ratio >= 95% within last 40 quarters
# (data with more than 20 quarter EPSs)
#                                           beat ratio  beat  count
# ticker companyshortname
# TRU    TransUnion                              100.0    24     24
# IQV    IQVIA Holdings Inc.                     100.0    33     33
# MTD    Mettler-Toledo International Inc.       100.0    40     40
# MPWR   Monolithic Power Systems, Inc.           97.5    39     40
# SPGI   S&P Global Inc.                          95.0    38     40

# %% [markdown]
# ## Get stock info of your favorite

# %% [markdown]
# ### Find Tickers with high EPS beat ratio

# %%
# pd.set_option('display.max_rows', df.shape[0]+1)
tickers_nasdaq = si.tickers_nasdaq()
ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_36/4042142324.py in <module>
#       1 # pd.set_option('display.max_rows', df.shape[0]+1)
#       2 tickers_nasdaq = si.tickers_nasdaq()
# ----> 3 ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
#
# AttributeError: module 'mystock_info' has no attribute 'search_good_eps'

# %%
# !pip  install pandas==1.3.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas==1.3.1
#   Downloading pandas-1.3.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 310 kB/s eta 0:00:01    |███████████▏                    | 4.1 MB 4.5 MB/s eta 0:00:02     |███████████████████████▉        | 8.8 MB 4.5 MB/s eta 0:00:01     |███████████████████████████▊    | 10.2 MB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (2021.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.1) (1.16.0)
# Installing collected packages: pandas
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastquant 0.1.6.1 requires pandas==1.1.5, but you have pandas 1.3.1 which is incompatible.
# Successfully installed pandas-1.3.1
# WARNING: You are using pip version 21.2.2; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
