# %% [markdown]
# # EPS analysis

# %% [markdown]
# ## import modules and difine basic modules & functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import yahoo_fin.stock_info as si

# private module
import mystock_info as mi

# %%
import importlib
importlib.reload(mi)
# Out:
# <module 'mystock_info' from '/home/jovyan/yahoo_fin/mystock_info.py'>

# %% [markdown]
# ## Tech companies

# %%
fangam=["FB","AAPL","NFLX","GOOG","AMZN","MSFT"]

###
ant=["ADBE","NVDA","TSLA"]
saas=["CRWD","OKTA","ZS","TTD","TWLO"]
ecommerce=["SHOP","ETSY","FIVN"]

fintech=["SQ","DOCU", "PYPL"]
media=["TWTR","PINS"]
techs=["U","ZM","FVRR","ABNB","ROKU"]
eauto=["F","GM","MGA"]

growth1=ant+saas+ecommerce
growth2=fintech+media+techs+eauto

# %%
E12 = ["FB", "AAPL", "GOOG", "AMZN", "MSFT"] # Trillion
E11 = ["NFLX", "TSLA","ADBE", "NVDA","PYPL", "SHOP", "SQ"] # over 100 Billion
E10_5 = ( # Over 50 Billion
    ["ABNB","SNOW", "ZM"]  #, "GM", "F"
    + ["CRWD", "TWLO","TWTR"]
    + [ "DOCU", "PLTR"]
)
E10_1 = ["ROKU", "OKTA", "DDOG", "EPAM","TTD","U", "MGA","ZS", 
         "ETSY","FIVN", "PINS","UPST","MDB", "HUBS", "NUE"] # over 10 Billion

E9 = ["FVRR"] # over 1 Billion

LIST=E12+E11+E10_5+E10_1+E9
SLIST=E11+E10_5+E10_1+E9

###

# %% [markdown]
# ### PSR distribution and Market Cap

# %%
import importlib
importlib.reload(mi)
df=mi.show_valuation(LIST, table=False, key="Cap")
#df["Market Cap"].sort_values(ascending=False)
# Out:
# The top 5 CAP stocks (2021-09-04)
# <style  type="text/css" >
# #T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow0_col2,#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow1_col2,#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow2_col2,#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow3_col2,#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow4_col2{
#             background-color:  #fda37b;
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 49.9%, transparent 49.9%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow0_col5,#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow0_col6,#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 59.1%, transparent 59.1%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 50.1%, transparent 50.1%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 61.7%, transparent 61.7%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.9%, transparent 64.9%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 51.8%, transparent 51.8%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.5%, transparent 20.5%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow3_col0{
#             background-color:  #77b5d9;
#             color:  #000000;
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 29.5%, transparent 29.5%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 38.6%, transparent 38.6%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow3_col6,#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 44.2%, transparent 44.2%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 22.3%, transparent 22.3%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow4_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 46.1%, transparent 46.1%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
#         }#T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
#         }</style><table id="T_f00b0e22_0d97_11ec_a7cd_872f12bb360b" ><thead>    <tr>        <th class="index_name level0" >info</th>        <th class="col_heading level0 col0" >Market Cap</th>        <th class="col_heading level0 col1" >Previous Close</th>        <th class="col_heading level0 col2" >1y Target Est</th>        <th class="col_heading level0 col3" >Price/Sales (ttm)</th>        <th class="col_heading level0 col4" >PE Ratio (TTM)</th>        <th class="col_heading level0 col5" >Price/Book (mrq)</th>        <th class="col_heading level0 col6" >Return on Equity (ttm)</th>        <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>        <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>        <th class="col_heading level0 col9" >Y!</th>        <th class="col_heading level0 col10" >alpha</th>        <th class="col_heading level0 col11" >TS</th>    </tr>    <tr>        <th class="index_name level0" >ticker</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f00b0e22_0d97_11ec_a7cd_872f12bb360blevel0_row0" class="row_heading level0 row0" >AAPL</th>
#                         <td id="T_f00b0e22_0d97_11ec_a7cd_872f12bb360brow0_col0" class="data row0 col0" >$2.55e+12</td>

# %%
df["Market Cap"].sort_values(ascending=False)
# Out:
# ticker
# AAPL    2.551000e+12
# MSFT    2.263000e+12
# GOOG    1.924000e+12
# AMZN    1.761000e+12
# FB      1.061000e+12
# TSLA    7.348680e+11
# NVDA    5.692480e+11
# PYPL    3.397360e+11
# ADBE    3.175640e+11
# NFLX    2.613660e+11
# SHOP    1.927290e+11
# SQ      1.239990e+11
# ABNB    9.932600e+10
# SNOW    9.179100e+10
# ZM      8.863000e+10
# TWLO    6.505500e+10
# CRWD    6.349000e+10
# DOCU    6.040900e+10
# PLTR    5.203100e+10
# TWTR    5.159700e+10
# ROKU    4.567600e+10
# DDOG    4.280100e+10
# OKTA    4.182100e+10
# ZS      3.937000e+10
# U       3.774700e+10
# TTD     3.743200e+10
# EPAM    3.643500e+10
# PINS    3.590000e+10
# NUE     3.412900e+10
# HUBS    3.309600e+10
# MDB     3.279900e+10
# ETSY    2.789500e+10
# MGA     2.417000e+10
# UPST    1.923100e+10
# FIVN    1.152200e+10
# FVRR    6.592000e+09
# Name: Market Cap, dtype: float64

# %% [markdown]
# ### EPS history

# %%
import importlib
importlib.reload(mi)

#for i in [fangam, growth1, growth2]:
for i in [E12,E11,E10_5,E10_1,E9]:
    
    mi.plot_eps_history(i)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_76/1546579379.py in <module>
#       5 for i in [E12,E11,E10_5,E10_1,E9]:
#       6
# ----> 7     mi.plot_eps_history(i)
#
# ~/yahoo_fin/mystock_info.py in plot_eps_history(tickers, clear_cache, last, largefig, verbose)
#     267         df_ticker=df_ticker.tail(min(last, len(df_ticker)))
#     268
# --> 269         _plot_fig(df_ticker, ax, target =["epsactual", "epsestimate"],
#     270         title=df_ticker["ticker"][0],ylabel="EPS")
#     271
#
# ~/yahoo_fin/mystock_info.py in _plot_fig(df, ax, target, title, ylabel, xticklabels, axhline)
#     216     axhline (float) : draw horizontal line at given values
#     217     """
# --> 218     sns.lineplot(ax=ax, data=df[target], marker="o")
#     219     ax.axhline(linewidth=1, linestyle="-")
#     220     axhline != None and ax.axhline(y=axhline,linewidth=1, linestyle="--", color="red")
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     699         return ax
#     700
# --> 701     p._attach(ax)
#     702
#     703     p.plot(ax, kwargs)
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py in _attach(self, obj, allowed_types, log_scale)
#    1125             # its mapping, meaning that it won't handle unshared axes well either.
#    1126             for ax in ax_list:
# -> 1127                 axis = getattr(ax, f"{var}axis")
#    1128                 seed_data = self.plot_data[var]
#    1129                 if var_type == "categorical":
#
# AttributeError: 'numpy.ndarray' object has no attribute 'xaxis'

# %%
mi.plot_eps_history(E9)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_76/1573492137.py in <module>
# ----> 1 mi.plot_eps_history(E9)
#
# ~/yahoo_fin/mystock_info.py in plot_eps_history(tickers, clear_cache, last, largefig, verbose)
#     267         df_ticker=df_ticker.tail(min(last, len(df_ticker)))
#     268
# --> 269         _plot_fig(df_ticker, ax, target =["epsactual", "epsestimate"],
#     270         title=df_ticker["ticker"][0],ylabel="EPS")
#     271
#
# ~/yahoo_fin/mystock_info.py in _plot_fig(df, ax, target, title, ylabel, xticklabels, axhline)
#     216     axhline (float) : draw horizontal line at given values
#     217     """
# --> 218     sns.lineplot(ax=ax, data=df[target], marker="o")
#     219     ax.axhline(linewidth=1, linestyle="-")
#     220     axhline != None and ax.axhline(y=axhline,linewidth=1, linestyle="--", color="red")
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.8/dist-packages/seaborn/relational.py in lineplot(x, y, hue, size, style, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, units, estimator, ci, n_boot, seed, sort, err_style, err_kws, legend, ax, **kwargs)
#     699         return ax
#     700
# --> 701     p._attach(ax)
#     702
#     703     p.plot(ax, kwargs)
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_core.py in _attach(self, obj, allowed_types, log_scale)
#    1125             # its mapping, meaning that it won't handle unshared axes well either.
#    1126             for ax in ax_list:
# -> 1127                 axis = getattr(ax, f"{var}axis")
#    1128                 seed_data = self.plot_data[var]
#    1129                 if var_type == "categorical":
#
# AttributeError: 'numpy.ndarray' object has no attribute 'xaxis'

# %%
import importlib
importlib.reload(mi)
#mi.show_beat_ratio(LIST, last=20)
for i in [E12,E11,E10_5,E10_1,E9]:
    df_res = mi.show_valuation(i, hist=False, table=True)
# Out:
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow0_col2,#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow1_col2,#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow2_col2,#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow3_col2,#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow4_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow0_col3,#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 61.7%, transparent 61.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 61.7%, transparent 61.7%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 46.1%, transparent 46.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 46.1%, transparent 46.1%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow1_col6,#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #519ccc;
#             color:  #000000;
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.9%, transparent 64.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.9%, transparent 64.9%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 51.8%, transparent 51.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 51.8%, transparent 51.8%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.5%, transparent 20.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.5%, transparent 20.5%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow3_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 49.9%, transparent 49.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 49.9%, transparent 49.9%);
#         }#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow3_col6,#T_eca7ba68_0d98_11ec_a7cd_872f12bb360brow4_col4{
#             width:  10em;
#              height:  80%;
#             b
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #e1edf8;
#             color:  #000000;
#             background-color:  #e1edf8;
#             color:  #000000;
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow0_col2,#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow1_col1,#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow2_col1,#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow3_col1,#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow4_col2,#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow5_col2,#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow6_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow0_col3,#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 20.6%, transparent 20.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 20.6%, transparent 20.6%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 41.7%, transparent 41.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 41.7%, transparent 41.7%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 73.7%, transparent 73.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 73.7%, transparent 73.7%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 39.6%, transparent 39.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 39.6%, transparent 39.6%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 23.2%, transparent 23.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 23.2%, transparent 23.2%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #2676b8;
#             color:  #000000;
#             background-color:  #2676b8;
#             color:  #000000;
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 52.0%, transparent 52.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 52.0%, transparent 52.0%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 21.2%, transparent 21.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 21.2%, transparent 21.2%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 58.7%, transparent 58.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 58.7%, transparent 58.7%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 89.5%, transparent 89.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 89.5%, transparent 89.5%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 47.7%, transparent 47.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 47.7%, transparent 47.7%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 60.1%, transparent 60.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 60.1%, transparent 60.1%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #b0d2e7;
#             color:  #000000;
#             background-color:  #b0d2e7;
#             color:  #000000;
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 44.1%, transparent 44.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 44.1%, transparent 44.1%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 14.9%, transparent 14.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 14.9%, transparent 14.9%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 50.0%, transparent 50.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 50.0%, transparent 50.0%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow2_col6,#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 15.8%, transparent 15.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 15.8%, transparent 15.8%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 80.8%, transparent 80.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 80.8%, transparent 80.8%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow3_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 35.1%, transparent 35.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 35.1%, transparent 35.1%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 63.4%, transparent 63.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 63.4%, transparent 63.4%);
#         }#T_ecf273fa_0d98_11ec_a7cd_872f12bb360brow3_col6{
#             width
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_ed41482c_0d98_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #0e59a2;
#             color:  #f1f1f1;
#             background-color:  #0e59a2;
#             color:  #f1f1f1;
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow0_col2,#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow1_col2,#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow2_col1,#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow3_col2,#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow4_col2,#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow5_col2,#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow6_col2,#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow7_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow0_col3,#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 6.5%, transparent 6.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 6.5%, transparent 6.5%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 51.2%, #e68f8f 51.2%, #e68f8f 72.5%, transparent 72.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 51.2%, #e68f8f 51.2%, #e68f8f 72.5%, transparent 72.5%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.9%, transparent 34.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.9%, transparent 34.9%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 3.1%, transparent 3.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 3.1%, transparent 3.1%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #c7dbef;
#             color:  #000000;
#             background-color:  #c7dbef;
#             color:  #000000;
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.7%, transparent 51.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.7%, transparent 51.7%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 24.5%, transparent 24.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 24.5%, transparent 24.5%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.2%, #e68f8f 55.2%, #e68f8f 72.5%, transparent 72.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 55.2%, #e68f8f 55.2%, #e68f8f 72.5%, transparent 72.5%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 23.3%, transparent 23.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 23.3%, transparent 23.3%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 67.1%, transparent 67.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 67.1%, transparent 67.1%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #f5fafe;
#             color:  #000000;
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 36.3%, transparent 36.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 36.3%, transparent 36.3%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 8.7%, transparent 8.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 8.7%, transparent 8.7%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 72.5%, transparent 72.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 72.5%, transparent 72.5%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 16.4%, transparent 16.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 16.4%, transparent 16.4%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 8.7%, transparent 8.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 8.7%, transparent 8.7%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow3_col0{
#             background-color:  #d3e3f3;
#             color:  #000000;
#             background-color:  #d3e3f3;
#             color:  #000000;
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 31.2%, transparent 31.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 31.2%, transparent 31.2%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.4%, #e68f8f 35.4%, #e68f8f 72.5%, transparent 72.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.4%, #e68f8f 35.4%, #e68f8f 72.5%, transparent 72.5%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 16.6%, transparent 16.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 16.6%, transparent 16.6%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 40.3%, transparent 40.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 40.3%, transparent 40.3%);
#         }#T_ed41482c_0d98_11ec_a7cd_872f12bb360brow4_col0{
#             background-color:  #bcd7eb;
#             color:  #000000;
#             background-color:  #bcd7eb;
#             color:  #000000;
#         }#T_ed4148
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#             background-color:  #1460a8;
#             color:  #f1f1f1;
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow0_col1,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow1_col2,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow2_col1,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow3_col2,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow4_col1,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow5_col1,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow6_col2,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow7_col1,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow8_col2,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow9_col2,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow10_col2,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow11_col2,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow12_col2,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow13_col1,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow14_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow0_col3,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.9%, #e68f8f 14.9%, #e68f8f 46.7%, transparent 46.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 14.9%, #e68f8f 14.9%, #e68f8f 46.7%, transparent 46.7%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 6.6%, transparent 6.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 6.6%, transparent 6.6%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 58.3%, transparent 58.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 58.3%, transparent 58.3%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #08468b;
#             color:  #f1f1f1;
#             background-color:  #08468b;
#             color:  #f1f1f1;
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 85.6%, transparent 85.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 85.6%, transparent 85.6%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 60.5%, transparent 60.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 60.5%, transparent 60.5%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.3%, #e68f8f 43.3%, #e68f8f 46.7%, transparent 46.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 43.3%, #e68f8f 43.3%, #e68f8f 46.7%, transparent 46.7%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 7.5%, transparent 7.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 7.5%, transparent 7.5%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 43.7%, transparent 43.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 43.7%, transparent 43.7%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #4292c6;
#             color:  #000000;
#             background-color:  #4292c6;
#             color:  #000000;
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 71.4%, transparent 71.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 71.4%, transparent 71.4%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.3%, transparent 64.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.3%, transparent 64.3%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 46.7%, transparent 46.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 46.7%, transparent 46.7%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow2_col7,#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow8_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 4.9%, transparent 4.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 4.9%, transparent 4.9%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.0%, #e68f8f 5.0%, #e68f8f 12.6%, transparent 12.6%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 5.0%, #e68f8f 5.0%, #e68f8f 12.6%, transparent 12.6%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow3_col0{
#             background-color:  #084d96;
#             color:  #f1f1f1;
#             background-color:  #084d96;
#             color:  #f1f1f1;
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 62.8%, transparent 62.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 62.8%, transparent 62.8%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 8.7%, transparent 8.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 8.7%, transparent 8.7%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.5%, #e68f8f 37.5%, #e68f8f 46.7%, transparent 46.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 37.5%, #e68f8f 37.5%, #e68f8f 46.7%, transparent 46.7%);
#         }#T_ed97b55e_0d98_11ec_a7cd_872f12bb360brow3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 6.4%, transparent 6.4%);
#             width:  10em;
#              height:  80%;
#             background:
# PSR sorted list (2021-09-04)
# /usr/local/lib/python3.8/dist-packages/pandas/io/formats/style.py:1210: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# /usr/local/lib/python3.8/dist-packages/pandas/io/formats/style.py:1210: RuntimeWarning: All-NaN slice encountered
#   smax = np.nanmax(s.to_numpy()) if vmax is None else vmax
# <style  type="text/css" >
# #T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col3,#T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#e68f8f 100.0%, transparent 100.0%);
#         }#T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
#         }#T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 20.9%, transparent 20.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 20.9%, transparent 20.9%);
#         }</style><table id="T_edd6f192_0d98_11ec_a7cd_872f12bb360b" ><thead>    <tr>        <th class="index_name level0" >info</th>        <th class="col_heading level0 col0" >Market Cap</th>        <th class="col_heading level0 col1" >Previous Close</th>        <th class="col_heading level0 col2" >1y Target Est</th>        <th class="col_heading level0 col3" >Price/Sales (ttm)</th>        <th class="col_heading level0 col4" >PE Ratio (TTM)</th>        <th class="col_heading level0 col5" >Price/Book (mrq)</th>        <th class="col_heading level0 col6" >Return on Equity (ttm)</th>        <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>        <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>        <th class="col_heading level0 col9" >Y!</th>        <th class="col_heading level0 col10" >alpha</th>        <th class="col_heading level0 col11" >TS</th>    </tr>    <tr>        <th class="index_name level0" >ticker</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_edd6f192_0d98_11ec_a7cd_872f12bb360blevel0_row0" class="row_heading level0 row0" >FVRR</th>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col0" class="data row0 col0" >$6.59e+09</td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col1" class="data row0 col1" >$183.1</td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col2" class="data row0 col2" >$215.8</td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col3" class="data row0 col3" >26.2</td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col4" class="data row0 col4" >-</td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col5" class="data row0 col5" >19.3</td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col6" class="data row0 col6" >-12.6%</td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col7" class="data row0 col7" >59.7%</td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col8" class="data row0 col8" >12.6%</td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/FVRR">Y</a></td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/FVRR">a</a></td>
#                         <td id="T_edd6f192_0d98_11ec_a7cd_872f12bb360brow0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=FVRR">TS</a></td>
#             </tr>
#     </tbody></table>

# %%
import importlib
importlib.reload(mi)
#df_res = mi.show_valuation(LIST, hist=False, table=True)
df_res = mi.show_valuation(SLIST, hist=False, table=True, key="PSR")
# Out:
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #e0ecf8;
#             color:  #000000;
#             background-color:  #e0ecf8;
#             color:  #000000;
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow3_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow4_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow5_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow6_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow7_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow8_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow9_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow10_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow11_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow12_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow13_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow14_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow15_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow16_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow17_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow18_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow19_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow20_col1,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow21_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow22_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow23_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow24_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow25_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow26_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow27_col2,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow28_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col3,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow10_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 6.5%, transparent 6.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 6.5%, transparent 6.5%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.1%, #e68f8f 35.1%, #e68f8f 49.7%, transparent 49.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 35.1%, #e68f8f 35.1%, #e68f8f 49.7%, transparent 49.7%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.9%, transparent 34.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 34.9%, transparent 34.9%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #7eb8ef 12.6%, #7eb8ef 15.2%, transparent 15.2%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #7eb8ef 12.6%, #7eb8ef 15.2%, transparent 15.2%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col0,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col0,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow6_col0{
#             background-color:  #eef5fc;
#             color:  #000000;
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 60.7%, transparent 60.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 60.7%, transparent 60.7%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 27.0%, transparent 27.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 27.0%, transparent 27.0%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.6%, #e68f8f 19.6%, #e68f8f 49.7%, transparent 49.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 19.6%, #e68f8f 19.6%, #e68f8f 49.7%, transparent 49.7%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 19.9%, transparent 19.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 19.9%, transparent 19.9%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 58.3%, transparent 58.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 58.3%, transparent 58.3%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.9%, transparent 51.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.9%, transparent 51.9%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col5,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow20_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 16.3%, transparent 16.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 16.3%, transparent 16.3%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.5%, #e68f8f 46.5%, #e68f8f 49.7%, transparent 49.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 46.5%, #e68f8f 46.5%, #e68f8f 49.7%, transparent 49.7%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col7,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow12_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 22.4%, transparent 22.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#f4d18b 22.4%, transparent 22.4%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 43.7%, transparent 43.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 43.7%, transparent 43.7%);
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow3_col0,#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow12_col0{
#             background-color:  #e7f1fa;
#             color:  #000000;
#             background-color:  #e7f1fa;
#             color:  #000000;
#         }#T_2a56f8e0_0d6e_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.7%, transparent 51.7%);
#             wid

# %% [markdown]
# ### FANGAMのみ大きく出してみる

# %%
mi.plot_eps(fangam,largefig=True)
mi.search_good_eps(fangam, last=200)

# %% [markdown]
# ## Health/Bio

# %%
H_E11 = [
    "PFE",
    "DHR",
    "MRNA",
    "BMY",
    "AMGN",
    "BNTX",
]
H_E10 = [
    "ANTM",
    "VEEV",
    "BIIB",
    "A",
    "RPRX",
]
H_E9 = [
    "INOV",
    "PGNY",
    "INMD",
    "DOCS"
]
health = H_E11 + H_E10 + H_E9

# %%
import importlib
importlib.reload(mi)
# EPS history
df_res=mi.plot_eps_history(health,last=20)

# %%
import importlib
importlib.reload(mi)

df_res=mi.show_valuation(health,table=True)
#df_cap=mi.show_valuation(health,table=True,hist=False,key="Cap")
# Out:
# PSR sorted list (2021-09-04)
# <style  type="text/css" >
# #T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow0_col0{
#             background-color:  #edf4fc;
#             color:  #000000;
#             background-color:  #edf4fc;
#             color:  #000000;
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow0_col1,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow1_col2,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow2_col1,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow3_col1,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow4_col2,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow5_col2,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow6_col1,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow7_col1,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow8_col1,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow9_col2,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow10_col2,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow11_col1,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow12_col2,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow13_col2,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow14_col2{
#             background-color:  #fda37b;
#             background-color:  #fda37b;
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow0_col3,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow0_col5,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow0_col7,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 1.0%, transparent 1.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 1.0%, transparent 1.0%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 75.5%, transparent 75.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 75.5%, transparent 75.5%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow1_col0{
#             background-color:  #d6e5f4;
#             color:  #000000;
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 41.5%, transparent 41.5%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 41.5%, transparent 41.5%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 37.9%, transparent 37.9%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 37.9%, transparent 37.9%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 78.7%, transparent 78.7%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 78.7%, transparent 78.7%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 20.8%, transparent 20.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 20.8%, transparent 20.8%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow1_col7,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow8_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.4%, transparent 0.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.4%, transparent 0.4%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 78.1%, transparent 78.1%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 78.1%, transparent 78.1%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow2_col0{
#             background-color:  #3f8fc5;
#             color:  #000000;
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 32.0%, transparent 32.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 32.0%, transparent 32.0%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 15.4%, transparent 15.4%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 15.4%, transparent 15.4%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 99.3%, transparent 99.3%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 99.3%, transparent 99.3%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 57.8%, transparent 57.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 57.8%, transparent 57.8%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 50.8%, transparent 50.8%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 50.8%, transparent 50.8%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow2_col8,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow5_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 100.0%, transparent 100.0%);
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 100.0%, transparent 100.0%);
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow3_col0,#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow4_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_c83c22c8_0d97_11ec_a7cd_872f12bb360brow3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 23.7%, transparent 23.7%);
#             width:  10em;
#              height:  80%;
#             background:  lin

# %% [markdown]
# # VUGとIWFの組入銘柄（570銘柄）の優良銘柄

# %%
GOOD=["ADP","AKAM","AZO","BC","BRO","CRL","CPRT","DHR","EFX","FB","FND","IQV","LPX","MKSI","MMC","MPWR","MSFT","MTD","NVDA","ORLY","ROL","SCCO","SPGI","TPX","TRU"]
df_res = mi.show_valuation(GOOD, hist=True, table=True, key="PSR")
# Out:
# PSR sorted list (2021-08-23)
# <style type="text/css">
# #T_0ff7e_row0_col0 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_0ff7e_row0_col2, #T_0ff7e_row1_col1, #T_0ff7e_row2_col2, #T_0ff7e_row3_col2, #T_0ff7e_row4_col2, #T_0ff7e_row5_col1, #T_0ff7e_row6_col2, #T_0ff7e_row7_col1, #T_0ff7e_row8_col1, #T_0ff7e_row9_col2, #T_0ff7e_row10_col2, #T_0ff7e_row11_col2, #T_0ff7e_row12_col1, #T_0ff7e_row13_col2, #T_0ff7e_row14_col2, #T_0ff7e_row15_col2, #T_0ff7e_row16_col1, #T_0ff7e_row17_col2, #T_0ff7e_row18_col2, #T_0ff7e_row19_col2, #T_0ff7e_row20_col2, #T_0ff7e_row21_col2, #T_0ff7e_row22_col2, #T_0ff7e_row23_col2, #T_0ff7e_row24_col2 {
#   background-color: #fda37b;
# }
# #T_0ff7e_row0_col3, #T_0ff7e_row19_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_0ff7e_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 62.5%, transparent 62.5%);
# }
# #T_0ff7e_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 12.1%, transparent 12.1%);
# }
# #T_0ff7e_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 8.1%, transparent 8.1%);
# }
# #T_0ff7e_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 48.2%, transparent 48.2%);
# }
# #T_0ff7e_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 60.1%, transparent 60.1%);
# }
# #T_0ff7e_row1_col0, #T_0ff7e_row8_col0, #T_0ff7e_row9_col0, #T_0ff7e_row11_col0, #T_0ff7e_row13_col0, #T_0ff7e_row14_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_0ff7e_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 93.3%, transparent 93.3%);
# }
# #T_0ff7e_row1_col4, #T_0ff7e_row19_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_0ff7e_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 10.4%, transparent 10.4%);
# }
# #T_0ff7e_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 4.1%, transparent 4.1%);
# }
# #T_0ff7e_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 40.6%, transparent 40.6%);
# }
# #T_0ff7e_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 53.1%, transparent 53.1%);
# }
# #T_0ff7e_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0ff7e_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 60.4%, transparent 60.4%);
# }
# #T_0ff7e_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 33.3%, transparent 33.3%);
# }
# #T_0ff7e_row2_col5, #T_0ff7e_row22_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 8.4%, transparent 8.4%);
# }
# #T_0ff7e_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 9.5%, transparent 9.5%);
# }
# #T_0ff7e_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 15.0%, transparent 15.0%);
# }
# #T_0ff7e_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
# }
# #T_0ff7e_row3_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0ff7e_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 59.7%, transparent 59.7%);
# }
# #T_0ff7e_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 37.9%, transparent 37.9%);
# }
# #T_0ff7e_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 43.3%, transparent 43.3%);
# }
# #T_0ff7e_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 15.1%, transparent 15.1%);
# }
# #T_0ff7e_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 5.9%, transparent 5.9%);
# }
# #T_0ff7e_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 77.5%, transparent 77.5%);
# }
# #T_0ff7e_row4_col0, #T_0ff7e_row5_col0, #T_0ff7e_row21_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_0ff7e_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 59.5%, transparent 59.5%);
# }
# #T_0ff7e_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 35.0%, transparent 35.0%);
# }
# #T_0ff7e_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 5.3%, transparent 5.3%);
# }
# #T_0ff7e_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 6.1%, transparent 6.1%);
# }
# #T_0ff7e_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 23.6%, transparent 23.6%);
# }
# #T_0ff7e_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 69.5%, transparent 69.5%);
# }
# #T_0ff7e_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 45.2%, transparent 45.2%);
# }
# #T_0ff7e_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 45.2%, transparent 45.2%);
# }
# #T_0ff7e_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 96.0%, transparent 96.0%);
# }
# #T_0ff7e_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 44.6%, transparent 44.6%);
# }
# #T_0ff7e_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 23.8%, transparent 23.8%);
# }
# #T_0ff7e_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 42.3%, transparent 42.3%);
# }
# #T_0ff7e_row6_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_0ff7e_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 42.9%, transparent 42.9%);
# }
# #T_0ff7e_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 23.5%, transparent 23.5%);
# }
# #T_0ff7e_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 3.8%, transparent 3.8%);
# }
# #T_0ff7e_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 6.3%, transparent 6.3%);
# }
# #T_0ff7e_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 39.2%, transparent 39.2%);
# }
# #T_0ff7e_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
# }
# #T_0ff7e_row7_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_0ff7e_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 38.1%, transparent 38.1%);
# }
# #T_0ff7e_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 37.7%, transparent 37.7%);
# }
# #T_0ff7e_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 3.0%, transparent 3.0%);
# }
# #T_0ff7e_row7_col6, #T_0ff7e_row14_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 2.8%, transparent 2.8%);
# }
# #T_0ff7e_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 25.6%, transparent 25.6%);
# }
# #T_0ff7e_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 49.5%, transparent 49.5%);
# }
# #T_0ff7e_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 37.5%, transparent 37.5%);
# }
# #T_0ff7e_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 51.1%, transparent 51.1%);
# }
# #T_0ff7e_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 9.6%, transparent 9.6%);
# }
# #T_0ff7e_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 7.0%, transparent 7.0%);
# }
# #T_0ff7e_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 10.8%, transparent 10.8%);
# }
# #T_0ff7e_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 30.6%, transparent 30.6%);
# }
# #T_0ff7e_row9_col3 {
#   width: 10em;

# %%
df_res=mi.plot_eps_history(GOOD,last=20)

# %%
ret=mi.show_beat_ratio(GOOD,last=40,threshold=95,min_qtrs=20)
# Out:
# Tickers list of which beat ratio >= 95% within last 40 quarters
# (data with more than 20 quarter EPSs)
#                                           beat ratio  beat  count
# ticker companyshortname
# TRU    TransUnion                              100.0    24     24
# IQV    IQVIA Holdings Inc.                     100.0    33     33
# MTD    Mettler-Toledo International Inc.       100.0    40     40
# MPWR   Monolithic Power Systems, Inc.           97.5    39     40
# SPGI   S&P Global Inc.                          95.0    38     40

# %% [markdown]
# ## Get stock info of your favorite

# %% [markdown]
# ### Find Tickers with high EPS beat ratio

# %%
# pd.set_option('display.max_rows', df.shape[0]+1)
tickers_nasdaq = si.tickers_nasdaq()
ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_36/4042142324.py in <module>
#       1 # pd.set_option('display.max_rows', df.shape[0]+1)
#       2 tickers_nasdaq = si.tickers_nasdaq()
# ----> 3 ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
#
# AttributeError: module 'mystock_info' has no attribute 'search_good_eps'

# %%
# !pip  install pandas==1.3.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas==1.3.1
#   Downloading pandas-1.3.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 310 kB/s eta 0:00:01    |███████████▏                    | 4.1 MB 4.5 MB/s eta 0:00:02     |███████████████████████▉        | 8.8 MB 4.5 MB/s eta 0:00:01     |███████████████████████████▊    | 10.2 MB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (2021.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.1) (1.16.0)
# Installing collected packages: pandas
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastquant 0.1.6.1 requires pandas==1.1.5, but you have pandas 1.3.1 which is incompatible.
# Successfully installed pandas-1.3.1
# WARNING: You are using pip version 21.2.2; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
