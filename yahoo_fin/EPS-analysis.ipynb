# %% [markdown]
# # EPS analysis

# %% [markdown]
# ## import modules and difine basic modules & functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import yahoo_fin.stock_info as si

# private module
import mystock_info as mi

# %%
import importlib
importlib.reload(mi)
# Out:
# <module 'mystock_info' from '/home/jovyan/yahoo_fin/mystock_info.py'>

# %% [markdown]
# ## Tech companies

# %%
fangam=["FB","AAPL","NFLX","GOOG","AMZN","MSFT"]

###
ant=["ADBE","NVDA","TSLA"]
saas=["CRWD","OKTA","ZS","TTD","TWLO"]
ecommerce=["SHOP","ETSY","FIVN"]

fintech=["SQ","DOCU", "PYPL"]
media=["TWTR","PINS"]
techs=["U","ZM","FVRR","ABNB","ROKU"]
eauto=["F","GM","MGA"]

growth1=ant+saas+ecommerce
growth2=fintech+media+techs+eauto

# %%
E12 = ["FB", "AAPL", "GOOG", "AMZN", "MSFT"] #Billions
E11 = ["NFLX", "TSLA","ADBE", "NVDA", "SHOP", "SQ", "ZM"] # over 100 million
E10_5 = ( # Over 50 million
    ["ABNB", "GM", "F"] 
    + ["CRWD", "TWLO","TWTR"]
    + [ "DOCU"]
)
E10_1 = ["ROKU","OKTA", "EPAM","U", "MGA","ZS", "ETSY","FIVN", "PINS"] # over 10 million

E9 = ["FVRR","FSLY",  "TTD"] # over 1 million

LIST=E12+E11+E10_5+E10_1+E9
###

# %% [markdown]
# ### PSR distribution and Market Cap

# %%
import importlib
importlib.reload(mi)
df=mi.show_valuation(LIST, table=False, key="Cap")
df["Market Cap"]
# Out:
# The top 5 CAP stocks (2021-08-13)
# <style  type="text/css" >
# #T_d170c212_fc40_11eb_a7fc_0242ac110002row0_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row0_col2,#T_d170c212_fc40_11eb_a7fc_0242ac110002row1_col2,#T_d170c212_fc40_11eb_a7fc_0242ac110002row2_col1,#T_d170c212_fc40_11eb_a7fc_0242ac110002row3_col2,#T_d170c212_fc40_11eb_a7fc_0242ac110002row4_col2{
#             background-color:  #f4c17b;
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 50.8%, transparent 50.8%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row0_col5,#T_d170c212_fc40_11eb_a7fc_0242ac110002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 59.1%, transparent 59.1%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aecde1 67.2%, transparent 67.2%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 67.7%, transparent 67.7%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row1_col0{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 63.0%, transparent 63.0%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 34.6%, transparent 34.6%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aecde1 98.0%, transparent 98.0%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 97.8%, transparent 97.8%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row2_col0{
#             background-color:  #56a0ce;
#             color:  #000000;
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.1%, transparent 64.1%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 52.3%, transparent 52.3%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.3%, transparent 20.3%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 100.0%, transparent 100.0%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aecde1 76.8%, transparent 76.8%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 66.9%, transparent 66.9%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row3_col0{
#             background-color:  #81badb;
#             color:  #000000;
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 28.9%, transparent 28.9%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 37.8%, transparent 37.8%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 44.2%, transparent 44.2%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aecde1 17.9%, transparent 17.9%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 15.7%, transparent 15.7%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row4_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 47.0%, transparent 47.0%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.4%, transparent 19.4%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 90.3%, transparent 90.3%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#aecde1 100.0%, transparent 100.0%);
#         }#T_d170c212_fc40_11eb_a7fc_0242ac110002row4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 100.0%, transparent 100.0%);
#         }</style><table id="T_d170c212_fc40_11eb_a7fc_0242ac110002" ><thead>    <tr>        <th class="index_name level0" >info</th>        <th class="col_heading level0 col0" >Market Cap</th>        <th class="col_heading level0 col1" >Previous Close</th>        <th class="col_heading level0 col2" >1y Target Est</th>        <th class="col_heading level0 col3" >Price/Sales (ttm)</th>        <th class="col_heading level0 col4" >PE Ratio (TTM)</th>        <th class="col_heading level0 col5" >Price/Book (mrq)</th>        <th class="col_heading level0 col6" >Quarterly Revenue Growth (yoy)</th>        <th class="col_heading level0 col7" >Profit Margin</th>        <th class="col_heading level0 col8" >Operating Margin (ttm)</th>    </tr>    <tr>        <th class="index_name level0" >ticker</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d170c212_fc40_11eb_a7fc_0242ac110002level0_row0" class="row_heading level0 row0" >AAPL</th>
#                         <td id="T_d170c212_fc40_11eb_a7fc_0242ac110002row0_col0" class="data row0 col0" >
# ticker
# AAPL    2.464000e+12
# MSFT    2.188000e+12
# GOOG    1.837000e+12
# AMZN    1.668000e+12
# FB      1.025000e+12
# TSLA    7.158300e+11
# NVDA    4.994210e+11
# ADBE    3.036840e+11
# NFLX    2.286540e+11
# SHOP    1.860530e+11
# SQ      1.238240e+11
# ZM      1.068590e+11
# ABNB    9.172100e+10
# GM      7.843600e+10
# TWLO    6.508800e+10
# DOCU    5.794400e+10
# CRWD    5.578100e+10
# F       5.504800e+10
# TWTR    5.214800e+10
# ROKU    4.858200e+10
# TTD     3.962000e+10
# OKTA    3.639700e+10
# PINS    3.613100e+10
# U       3.550300e+10
# EPAM    3.461100e+10
# ZS      3.365500e+10
# MGA     2.573800e+10
# ETSY    2.410800e+10
# FIVN    1.293300e+10
# FVRR    6.185000e+09
# FSLY    4.983000e+09
# Name: Market Cap, dtype: float64

# %%
df.head()
# Out:
# info      Market Cap  Previous Close  1y Target Est  Price/Sales (ttm)  \
# ticker
# AAPL    2.464000e+12          148.89         159.34               7.10
# MSFT    2.188000e+12          289.81         298.92              13.01
# GOOG    1.837000e+12         2767.79        2625.00               8.34
# AMZN    1.668000e+12         3303.50        4241.33               3.76
# FB      1.025000e+12          362.65         386.47               9.78
#
# info    PE Ratio (TTM)  Price/Book (mrq)  Quarterly Revenue Growth (yoy)  \
# ticker
# AAPL             29.18             38.39                            36.4
# MSFT             36.17             15.41                            21.3
# GOOG             30.02              7.78                            61.6
# AMZN             57.39             14.52                            27.2
# FB               27.00              7.43                            55.6
#
# info    Profit Margin  Operating Margin (ttm)
# ticker
# AAPL            25.00                   28.79
# MSFT            36.45                   41.60
# GOOG            28.57                   28.45
# AMZN             6.64                    6.68
# FB              37.18                   42.52

# %% [markdown]
# ### EPS history

# %%
# import importlib
# importlib.reload(mi)

#for i in [fangam, growth1, growth2]:
for i in [E12,E11,E10_5,E10_1,E9]:
    
    mi.plot_eps_history(i)
# Out:
# ntick: 5, nrow: 2, ncol: 4
# ntick: 7, nrow: 2, ncol: 4
# ntick: 7, nrow: 2, ncol: 4
# ntick: 9, nrow: 3, ncol: 4
# ntick: 3, nrow: 1, ncol: 4

# %%
import importlib
importlib.reload(mi)
mi.show_beat_ratio(LIST, last=20)
for i in [E12,E11,E10_5,E10_1,E9]:
    df_res = mi.show_valuation(i, hist=False, table=True)
# Out:
# Tickers list of which beat ratio >= 80% within last 20 quarters
# (data with more than 4 quarter EPSs)
#                                         beat ratio  beat  count
# ticker companyshortname
# AAPL   Apple Inc.                       100.000000    20     20
# FIVN   Five9, Inc.                      100.000000    20     20
# ZM     Zoom Video Communications, Inc.  100.000000     9      9
# U      Unity Software Inc.              100.000000     4      4
# TTD    The Trade Desk, Inc.             100.000000    20     20
# OKTA   Okta, Inc.                       100.000000    17     17
# MSFT   Microsoft Corporation            100.000000    20     20
# ZS     Zscaler, Inc.                    100.000000    13     13
# CRWD   CrowdStrike Holdings, Inc.       100.000000     9      9
# ADBE   Adobe Inc.                        95.000000    19     20
# GM     General Motors Company            95.000000    19     20
# SQ     Square, Inc.                      95.000000    19     20
# NVDA   NVIDIA Corporation                95.000000    19     20
# SHOP   Shopify Inc.                      95.000000    19     20
# DOCU   DocuSign, Inc.                    92.307692    12     13
# TWLO   Twilio Inc.                       90.000000    18     20
# FVRR   Fiverr International Ltd.         88.888889     8      9
# ROKU   Roku, Inc.                        87.500000    14     16
# TWTR   Twitter, Inc.                     85.000000    17     20
# EPAM   EPAM Systems, Inc.                85.000000    17     20
# MGA    Magna International Inc.          80.000000    16     20
# PINS   Pinterest, Inc.                   80.000000     8     10
# PSR sorted list (2021-08-13)
# <style  type="text/css" >
# #T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col0{
#             background-color:  #1562a9;
#             color:  #f1f1f1;
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col2,#T_6149904c_fc4d_11eb_a7fc_0242ac110002row1_col2,#T_6149904c_fc4d_11eb_a7fc_0242ac110002row2_col1,#T_6149904c_fc4d_11eb_a7fc_0242ac110002row3_col2,#T_6149904c_fc4d_11eb_a7fc_0242ac110002row4_col2{
#             background-color:  #f4c17b;
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col3,#T_6149904c_fc4d_11eb_a7fc_0242ac110002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 63.0%, transparent 63.0%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 34.6%, transparent 34.6%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 96.9%, transparent 96.9%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row1_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 47.0%, transparent 47.0%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.4%, transparent 19.4%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 90.3%, transparent 90.3%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 100.0%, transparent 100.0%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row2_col0{
#             background-color:  #56a0ce;
#             color:  #000000;
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.1%, transparent 64.1%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 52.3%, transparent 52.3%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.3%, transparent 20.3%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 100.0%, transparent 100.0%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 77.9%, transparent 77.9%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row3_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 50.8%, transparent 50.8%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 59.1%, transparent 59.1%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 63.8%, transparent 63.8%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row4_col0{
#             background-color:  #81badb;
#             color:  #000000;
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 28.9%, transparent 28.9%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 37.8%, transparent 37.8%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 44.2%, transparent 44.2%);
#         }#T_6149904c_fc4d_11eb_a7fc_0242ac110002row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 28.4%, transparent 28.4%);
#         }</style><table id="T_6149904c_fc4d_11eb_a7fc_0242ac110002" ><thead>    <tr>        <th class="index_name level0" >info</th>        <th class="col_heading level0 col0" >Market Cap</th>        <th class="col_heading level0 col1" >Previous Close</th>        <th class="col_heading level0 col2" >1y Target Est</th>        <th class="col_heading level0 col3" >Price/Sales (ttm)</th>        <th class="col_heading level0 col4" >PE Ratio (TTM)</th>        <th class="col_heading level0 col5" >Price/Book (mrq)</th>        <th class="col_heading level0 col6" >Quarterly Revenue Growth (yoy)</th>        <th class="col_heading level0 col7" >Operating Cash Flow Margin(ttm)</th>    </tr>    <tr>        <th class="index_name level0" >ticker</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6149904c_fc4d_11eb_a7fc_0242ac110002level0_row0" class="row_heading level0 row0" >MSFT</th>
#                         <td id="T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col0" class="data row0 col0" >2.19e+12</td>
#                         <td id="T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col1" class="data row0 col1" >289.8</td>
#                         <td id="T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col2" class="data row0 col2" >298.9</td>
#                         <td id="T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col3" class="data row0 col3" >13.0</td>
#                         <td id="T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col4" class="data row0 col4" >36.2</td>
#                         <td id="T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col5" class="data row0 col5" >15.4</td>
#                         <td id="T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col6" class="data row0 col6" >21.3%</td>
#                         <td id="T_6149904c_fc4d_11eb_a7fc_0242ac110002row0_col7" class="data row0 col7" >45.7%</td>
#             </tr>
#             <tr>
#                         <th id="T_6149904c_fc4d_11eb_a7fc_0242ac110002level0_row1" class="row_heading level0 row1" >FB</th>
#                         <td id="T_6149904c_fc4d_11eb_a7fc_0242ac110002row1_c
# PSR sorted list (2021-08-13)
# <style  type="text/css" >
# #T_6173c236_fc4d_11eb_a7fc_0242ac110002row0_col0{
#             background-color:  #ddeaf7;
#             color:  #000000;
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row0_col2,#T_6173c236_fc4d_11eb_a7fc_0242ac110002row1_col2,#T_6173c236_fc4d_11eb_a7fc_0242ac110002row2_col2,#T_6173c236_fc4d_11eb_a7fc_0242ac110002row3_col1,#T_6173c236_fc4d_11eb_a7fc_0242ac110002row4_col1,#T_6173c236_fc4d_11eb_a7fc_0242ac110002row5_col2,#T_6173c236_fc4d_11eb_a7fc_0242ac110002row6_col2{
#             background-color:  #f4c17b;
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row0_col3,#T_6173c236_fc4d_11eb_a7fc_0242ac110002row6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 20.1%, transparent 20.1%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 29.6%, transparent 29.6%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 26.1%, transparent 26.1%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row1_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 67.5%, transparent 67.5%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 32.6%, transparent 32.6%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 55.1%, transparent 55.1%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 100.0%, transparent 100.0%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 100.0%, transparent 100.0%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row2_col0{
#             background-color:  #3c8cc3;
#             color:  #000000;
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 53.7%, transparent 53.7%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.9%, transparent 24.9%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 58.0%, transparent 58.0%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 43.8%, transparent 43.8%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 66.1%, transparent 66.1%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row3_col0{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 43.7%, transparent 43.7%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 14.5%, transparent 14.5%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 47.9%, transparent 47.9%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 11.8%, transparent 11.8%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 90.9%, transparent 90.9%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row4_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 35.4%, transparent 35.4%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 62.5%, transparent 62.5%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 51.3%, transparent 51.3%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 41.1%, transparent 41.1%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row5_col0{
#             background-color:  #d0e1f2;
#             color:  #000000;
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 17.2%, transparent 17.2%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 14.0%, transparent 14.0%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 36.0%, transparent 36.0%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row5_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 10.1%, transparent 10.1%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row5_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 12.5%, transparent 12.5%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row6_col0{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 16.1%, transparent 16.1%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 63.8%, transparent 63.8%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row6_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 74.9%, transparent 74.9%);
#         }#T_6173c236_fc4d_11eb_a7fc_0242ac110002row6_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 9.8%, transparent 9.8%);
#         }</style><table id="T_6173c236_fc4d
# PSR sorted list (2021-08-13)
# <style  type="text/css" >
# #T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row0_col0{
#             background-color:  #e5eff9;
#             color:  #000000;
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row0_col2,#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row1_col1,#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row2_col2,#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row3_col2,#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row4_col1,#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row5_col2,#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row6_col2{
#             background-color:  #f4c17b;
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row0_col3,#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 27.6%, transparent 27.6%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 67.7%, transparent 67.7%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 100.0%, transparent 100.0%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row1_col0{
#             background-color:  #dae8f6;
#             color:  #000000;
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 63.9%, transparent 63.9%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 55.9%, transparent 55.9%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 56.4%, transparent 56.4%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row2_col0{
#             background-color:  #aed1e7;
#             color:  #000000;
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 51.7%, transparent 51.7%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 2.5%, transparent 2.5%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 64.6%, transparent 64.6%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 4.9%, transparent 4.9%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row3_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 48.0%, transparent 48.0%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 12.0%, transparent 12.0%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 5.2%, transparent 5.2%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 31.3%, transparent 31.3%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row4_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 21.0%, transparent 21.0%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 2.8%, transparent 2.8%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 71.6%, transparent 71.6%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 73.1%, transparent 73.1%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row5_col0{
#             background-color:  #3787c0;
#             color:  #000000;
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 1.0%, transparent 1.0%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 4.5%, transparent 4.5%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row5_col5,#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row6_col3,#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 0.7%, transparent 0.7%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row5_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 100.0%, transparent 100.0%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row5_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 46.5%, transparent 46.5%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row6_col0{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 11.6%, transparent 11.6%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row6_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 36.8%, transparent 36.8%);
#         }#T_61a38b7e_fc4d_11eb_a7fc_0242ac110002row6_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 37.7%, transparent 37.7%);
#         }</style><table id="T_61a38b7e_fc4d_11eb_a7fc_0242ac110002" ><thead>    <tr>        <th class="index_name level0" >info</th>        <th class="col_heading level0 col0" >Market Cap</th>        <th class="col_heading level0 col1" >Previous Close</th>        <th class="col_heading level0 col2" >1y Target Est</th>        <th class="col_heading level0 col3" >Price/Sales (ttm)</th>        <th class="col_heading level0 col4" >PE Ratio (TTM)</th>        <th class="col_heading level0 col5" >Price/Book (mrq)</th>        <th class="col_heading level0 col6" >Quarterly Revenue Growth (yoy)</th>        <th class="col_heading level0 col7" >Operating Cash Flow Margin(ttm)</th>    </tr>    <tr>        <th class="index_name level0" >ticker</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_61a38b7e_fc4d_11eb_a7fc_0242ac110002level
# PSR sorted list (2021-08-13)
# <style  type="text/css" >
# #T_61d1914a_fc4d_11eb_a7fc_0242ac110002row0_col0{
#             background-color:  #519ccc;
#             color:  #000000;
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row0_col1,#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row1_col2,#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row2_col1,#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row3_col2,#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row4_col2,#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row5_col2,#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row6_col1,#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row7_col2,#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row8_col2{
#             background-color:  #f4c17b;
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row0_col3,#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 83.3%, transparent 83.3%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 47.7%, transparent 47.7%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 96.5%, transparent 96.5%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row1_col0{
#             background-color:  #3989c1;
#             color:  #000000;
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 72.0%, transparent 72.0%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 58.1%, transparent 58.1%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 29.8%, transparent 29.8%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 49.5%, transparent 49.5%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row2_col0{
#             background-color:  #3f8fc5;
#             color:  #000000;
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 68.3%, transparent 68.3%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 22.2%, transparent 22.2%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 38.7%, transparent 38.7%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row2_col7{
#             width:  10em;
#              height:  80%;
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row3_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 44.3%, transparent 44.3%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 35.3%, transparent 35.3%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 39.7%, transparent 39.7%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row4_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 37.4%, transparent 37.4%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 95.0%, transparent 95.0%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 23.8%, transparent 23.8%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 65.0%, transparent 65.0%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 28.2%, transparent 28.2%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row5_col0{
#             background-color:  #3b8bc2;
#             color:  #000000;
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 28.8%, transparent 28.8%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row5_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row5_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 18.1%, transparent 18.1%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row5_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 100.0%, transparent 100.0%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row5_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 52.4%, transparent 52.4%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row6_col0{
#             background-color:  #4896c8;
#             color:  #000000;
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row6_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.4%, transparent 20.4%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row6_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 40.5%, transparent 40.5%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.7%, transparent 19.7%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row6_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 31.5%, transparent 31.5%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row6_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 42.2%, transparent 42.2%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row7_col0{
#             background-color:  #b2d2e8;
#             color:  #000000;
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row7_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 20.1%, transparent 20.1%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row7_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row7_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 57.1%, transparent 57.1%);
#         }#T_61d1914a_fc4d_11eb_a7fc_0242ac110002row7_col6{
#             width:  10em;
# PSR sorted list (2021-08-13)
# <style  type="text/css" >
# #T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col0{
#             background-color:  #08306b;
#             color:  #f1f1f1;
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col1,#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col2,#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col2{
#             background-color:  #f4c17b;
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col3,#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 100.0%, transparent 100.0%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 100.0%, transparent 100.0%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col0{
#             background-color:  #f1f7fd;
#             color:  #000000;
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 64.1%, transparent 64.1%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 55.0%, transparent 55.0%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 59.2%, transparent 59.2%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 38.3%, transparent 38.3%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 40.3%, transparent 40.3%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 14.6%, transparent 14.6%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 13.8%, transparent 13.8%);
#         }#T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col7{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002" ><thead>    <tr>        <th class="index_name level0" >info</th>        <th class="col_heading level0 col0" >Market Cap</th>        <th class="col_heading level0 col1" >Previous Close</th>        <th class="col_heading level0 col2" >1y Target Est</th>        <th class="col_heading level0 col3" >Price/Sales (ttm)</th>        <th class="col_heading level0 col4" >PE Ratio (TTM)</th>        <th class="col_heading level0 col5" >Price/Book (mrq)</th>        <th class="col_heading level0 col6" >Quarterly Revenue Growth (yoy)</th>        <th class="col_heading level0 col7" >Operating Cash Flow Margin(ttm)</th>    </tr>    <tr>        <th class="index_name level0" >ticker</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002level0_row0" class="row_heading level0 row0" >TTD</th>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col0" class="data row0 col0" >3.96e+10</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col1" class="data row0 col1" >85.6</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col2" class="data row0 col2" >69.7</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col3" class="data row0 col3" >38.3</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col4" class="data row0 col4" >155.9</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col5" class="data row0 col5" >33.0</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col6" class="data row0 col6" >100.9%</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row0_col7" class="data row0 col7" >32.8%</td>
#             </tr>
#             <tr>
#                         <th id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002level0_row1" class="row_heading level0 row1" >FVRR</th>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col0" class="data row1 col0" >6.18e+09</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col1" class="data row1 col1" >172.1</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col2" class="data row1 col2" >258.9</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col3" class="data row1 col3" >24.6</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col4" class="data row1 col4" >-</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col5" class="data row1 col5" >18.1</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col6" class="data row1 col6" >59.7%</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row1_col7" class="data row1 col7" >12.6%</td>
#             </tr>
#             <tr>
#                         <th id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002level0_row2" class="row_heading level0 row2" >FSLY</th>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col0" class="data row2 col0" >4.98e+09</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col1" class="data row2 col1" >43.0</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col2" class="data row2 col2" >56.2</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col3" class="data row2 col3" >15.4</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col4" class="data row2 col4" >-</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col5" class="data row2 col5" >4.8</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col6" class="data row2 col6" >13.9%</td>
#                         <td id="T_6210ebba_fc4d_11eb_a7fc_0242ac110002row2_col7" class="data row2 col7" >-9.8%</td>
#             </tr>
#     </tbody></table>

# %%
import importlib
importlib.reload(mi)
df_res = mi.show_valuation(LIST, hist=False, table=True)
df_res = mi.show_valuation(LIST, hist=False, table=True, key="QRG")
# Out:
# PSR sorted list (2021-08-13)
# <style  type="text/css" >
# #T_f3660ce4_fc52_11eb_a7fc_0242ac110002row0_col0,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row28_col0{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row0_col1,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row1_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row2_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row3_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row4_col1,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row5_col1,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row6_col1,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row7_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row8_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row9_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row10_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row11_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row12_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row13_col1,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row14_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row15_col1,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row16_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row17_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row18_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row19_col1,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row20_col1,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row21_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row22_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row23_col1,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row24_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row25_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row26_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row27_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row28_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row29_col2,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row30_col2{
#             background-color:  #f4c17b;
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row0_col3,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row6_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 27.8%, transparent 27.8%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 1.8%, #d65f5f 1.8%, #d65f5f 31.3%, transparent 31.3%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 31.1%, transparent 31.1%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 52.3%, transparent 52.3%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row1_col0,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row6_col0,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row30_col0{
#             background-color:  #f3f8fe;
#             color:  #000000;
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 99.9%, transparent 99.9%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row1_col5,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row17_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 27.6%, transparent 27.6%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 20.8%, #d65f5f 20.8%, #d65f5f 31.3%, transparent 31.3%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 36.6%, transparent 36.6%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 67.6%, transparent 67.6%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row2_col0{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 86.4%, transparent 86.4%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 20.1%, transparent 20.1%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 7.7%, transparent 7.7%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.3%, #bcde93 31.3%, #bcde93 49.3%, transparent 49.3%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 29.6%, transparent 29.6%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 23.2%, transparent 23.2%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row3_col0,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row4_col0,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row5_col0,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row16_col0,#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row20_col0{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 72.0%, transparent 72.0%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.4%, transparent 19.4%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.3%, transparent 31.3%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 19.5%, transparent 19.5%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 26.8%, transparent 26.8%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 68.5%, transparent 68.5%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 40.9%, transparent 40.9%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row4_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 13.8%, transparent 13.8%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.3%, #bcde93 31.3%, #bcde93 45.9%, transparent 45.9%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row4_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 52.7%, transparent 52.7%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 54.7%, transparent 54.7%);
#         }#T_f3660ce4_fc52_11eb_a7fc_0242ac110002row5_col3{
# QRG sorted list (2021-08-13)
# <style  type="text/css" >
# #T_f3b2093c_fc52_11eb_a7fc_0242ac110002row0_col0{
#             background-color:  #eff6fc;
#             color:  #000000;
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row0_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row1_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row2_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row3_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row4_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row5_col1,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row6_col1,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row7_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row8_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row9_col1,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row10_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row11_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row12_col1,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row13_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row14_col1,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row15_col1,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row16_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row17_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row18_col1,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row19_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row20_col1,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row21_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row22_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row23_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row24_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row25_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row26_col1,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row27_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row28_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row29_col2,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row30_col2{
#             background-color:  #f4c17b;
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 58.3%, transparent 58.3%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 32.6%, transparent 32.6%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 10.6%, transparent 10.6%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row0_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.3%, #bcde93 31.3%, #bcde93 49.8%, transparent 49.8%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row0_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 100.0%, transparent 100.0%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 88.9%, transparent 88.9%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row1_col0{
#             background-color:  #eef5fc;
#             color:  #000000;
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 13.9%, transparent 13.9%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 63.8%, transparent 63.8%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.3%, #bcde93 31.3%, #bcde93 44.6%, transparent 44.6%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 74.9%, transparent 74.9%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row1_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 8.7%, transparent 8.7%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row2_col0,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row5_col0,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row18_col0,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row20_col0,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row22_col0{
#             background-color:  #f5f9fe;
#             color:  #000000;
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 28.8%, transparent 28.8%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 58.4%, transparent 58.4%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 6.0%, transparent 6.0%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.3%, #bcde93 31.3%, #bcde93 35.3%, transparent 35.3%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row2_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 65.3%, transparent 65.3%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 28.4%, transparent 28.4%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row3_col0,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row14_col0{
#             background-color:  #f5fafe;
#             color:  #000000;
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 1.2%, transparent 1.2%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 3.1%, transparent 3.1%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 0.9%, transparent 0.9%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 31.3%, #bcde93 31.3%, #bcde93 41.6%, transparent 41.6%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 57.7%, transparent 57.7%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row3_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 21.7%, transparent 21.7%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row4_col0{
#             background-color:  #f2f7fd;
#             color:  #000000;
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 1.0%, transparent 1.0%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 1.6%, transparent 1.6%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row4_col5,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row21_col3,#T_f3b2093c_fc52_11eb_a7fc_0242ac110002row21_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 0.7%, transparent 0.7%);
#         }#T_f3b2093c_fc52_11eb_a7fc_0242

# %% [markdown]
# ### FANGAMのみ大きく出してみる

# %%
mi.plot_eps(fangam,largefig=True)
mi.search_good_eps(fangam, last=200)

# %% [markdown]
# ## Health

# %%
H_E11 = [
    "PFE",
    "DHR",
    "MRNA",
    "BMY",
    "AMGN",
    "BNTX",
]
H_E10 = [
    "ANTM",
    "VEEV",
    "BIIB",
    "A",
    "RPRX",
]
H_E9 = [
    "INOV",
    "PGNY",
    "INMD",
    "DOCS"
]
health = H_E11 + H_E10 + H_E9

# %%
import importlib
importlib.reload(mi)
# EPS history
mi.plot_eps_history(health,last=20)
# Out:
# ntick: 15, nrow: 4, ncol: 4
#    ticker companyshortname startdatetime startdatetimetype  epsestimate  \
# 2     PFE      Pfizer Inc.    2021-07-28               TNS         0.97
# 3     PFE      Pfizer Inc.    2021-05-04               TNS         0.77
# 4     PFE      Pfizer Inc.    2021-02-02               TNS         0.48
# 5     PFE      Pfizer Inc.    2020-10-27               TNS         0.71
# 6     PFE      Pfizer Inc.    2020-07-28               TNS         0.66
# ..    ...              ...           ...               ...          ...
# 4    INMD      InMode Ltd.    2020-08-05               TNS        -0.06
# 5    INMD      InMode Ltd.    2020-05-06               TNS         0.33
# 6    INMD      InMode Ltd.    2020-02-18               TNS         0.38
# 7    INMD      InMode Ltd.    2019-11-05               TNS         0.30
# 0    DOCS   Doximity, Inc.    2021-08-10               TNS         0.08
#
#     epsactual  epssurprisepct timeZoneShortName  gmtOffsetMilliSeconds  \
# 2        1.07           10.20               EDT                      0
# 3        0.93           20.31               EDT                      0
# 4        0.42          -13.04               EDT                      0
# 5        0.72            0.84               EDT                      0
# 6        0.78           17.65               EDT                      0
# ..        ...             ...               ...                    ...
# 4        0.24          513.79               EDT                      0
# 5        0.30           -7.69               EDT                      0
# 6        0.46           20.10               EDT                      0
# 7        0.42           40.94               EDT                      0
# 0        0.11           41.03               EDT                      0
#
#    quoteType
# 2     EQUITY
# 3     EQUITY
# 4     EQUITY
# 5     EQUITY
# 6     EQUITY
# ..       ...
# 4     EQUITY
# 5     EQUITY
# 6     EQUITY
# 7     EQUITY
# 0     EQUITY
#
# [750 rows x 10 columns]

# %%
df_res=mi.show_valuation(health,table=True)
#df_cap=mi.show_valuation(health,table=True,hist=False,key="Cap")
# Out:
# PSR sorted list (2021-08-13)
# <style  type="text/css" >
# #T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row0_col0{
#             background-color:  #d6e5f4;
#             color:  #000000;
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row0_col2,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row1_col1,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row2_col1,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row3_col1,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row4_col2,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row5_col2,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row6_col1,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row7_col1,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row8_col1,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row9_col2,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row10_col1,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row11_col2,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row12_col2,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row13_col2,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row14_col1{
#             background-color:  #f4c17b;
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row0_col3,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row1_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 72.7%, transparent 72.7%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row0_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 85.4%, transparent 85.4%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row0_col6,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row8_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 21.3%, transparent 21.3%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row0_col7,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row8_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 0.2%, transparent 0.2%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row0_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 79.9%, transparent 79.9%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row1_col0{
#             background-color:  #529dcc;
#             color:  #000000;
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 71.5%, transparent 71.5%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row1_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 26.4%, transparent 26.4%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row1_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 57.8%, transparent 57.8%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row1_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 50.7%, transparent 50.7%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row1_col8,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row4_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 100.0%, transparent 100.0%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row2_col0,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row5_col0{
#             background-color:  #f7fbff;
#             color:  #000000;
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 56.9%, transparent 56.9%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row2_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 20.7%, transparent 20.7%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row2_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 87.0%, transparent 87.0%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row2_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 34.9%, transparent 34.9%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row2_col7,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row10_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 0.5%, transparent 0.5%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row2_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#3c76af 70.6%, transparent 70.6%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row3_col0{
#             background-color:  #afd1e7;
#             color:  #000000;
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 36.9%, transparent 36.9%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#bcde93 11.7%, transparent 11.7%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row3_col5{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 70.4%, transparent 70.4%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row3_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 100.0%, transparent 100.0%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row3_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 100.0%, transparent 100.0%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row3_col8,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row11_col7{
#             width:  10em;
#              height:  80%;
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row4_col0{
#             background-color:  #e9f2fa;
#             color:  #000000;
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row4_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 34.4%, transparent 34.4%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row4_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 22.2%, transparent 22.2%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row4_col7,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row6_col7,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row12_col7,#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row13_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 0.1%, transparent 0.1%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row5_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#549e3f 33.5%, transparent 33.5%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row5_col6{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 34.1%, transparent 34.1%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row5_col7{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#ed936b 0.4%, transparent 0.4%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row5_col8{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7eb8ef 10.6%, transparent 10.6%);
#         }#T_6f3cc36a_fc55_11eb_a7fc_0242ac110002row6_col0{
#             background-color:  #f6faff;
#             color:  #000

# %% [markdown]
# ## Get stock info of your favorite

# %% [markdown]
# ### Find Tickers with high EPS beat ratio

# %%
# pd.set_option('display.max_rows', df.shape[0]+1)
tickers_nasdaq = si.tickers_nasdaq()
ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_35/4042142324.py in <module>
#       1 # pd.set_option('display.max_rows', df.shape[0]+1)
#       2 tickers_nasdaq = si.tickers_nasdaq()
# ----> 3 ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
#
# AttributeError: module 'mystock_info' has no attribute 'search_good_eps'
