# %% [markdown]
# # EPS analysis

# %% [markdown]
# ## import modules and difine basic modules & functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import yahoo_fin.stock_info as si

# private module
import mystock_info as mi

# %%
import importlib
importlib.reload(mi)
# Out:
# <module 'mystock_info' from '/home/jovyan/yahoo_fin/mystock_info.py'>

# %% [markdown]
# ## Tech companies

# %%
fangam=["FB","AAPL","NFLX","GOOG","AMZN","MSFT"]

###
ant=["ADBE","NVDA","TSLA"]
saas=["CRWD","OKTA","TTD","TWLO"]
ecommerce=["SHOP","ETSY","FIVN"]

fintech=["SQ","DOCU", "PYPL"]
media=["TWTR","PINS"]
techs=["U","ZM","FVRR","ABNB","ROKU"]
eauto=["F","GM"]

jicchama=["DOCS","UPST","DLO","SNOW","PLTR","DDOG","COUR","ABNB","LAW"]

growth1=ant+saas+ecommerce
growth2=fintech+media+techs+eauto

# %%
E12 = ["AAPL", "GOOG", "AMZN", "MSFT","TSLA"] # Trillion
E11 = ["NVDA", "FB","NFLX", "ADBE","PYPL", "SHOP", "ABNB"] # over 100 Billion
E10_5 = ["DDOG","ZM", "SQ", "SNOW"]  #, "GM", "F"  # Over 50 Billion
E10_1 = ["VEEV", "PLTR","TWTR","ROKU", "OKTA", "EPAM", "TTD","U", "MGA",
         "ETSY","PINS","UPST","MDB", "HUBS"] + ["CRWD", "TWLO", "DOCU" ]#,"LCID"]
# over 10 Billion

E9 = ["FIVN",  "MQ", "FVRR","COUR","LAW","SPT", "ONON"] # Under 1 Billion

#NODATA=["DLO"]

LIST=E12+E11+E10_5+E10_1+E9
SLIST=E11+E10_5+E10_1+E9

###

# %%
sorted(LIST)
# Out:
# ['AAPL',
#  'ABNB',
#  'ADBE',
#  'AMZN',
#  'COUR',
#  'CRWD',
#  'DDOG',
#  'DOCU',
#  'EPAM',
#  'ETSY',
#  'FB',
#  'FIVN',
#  'FVRR',
#  'GOOG',
#  'HUBS',
#  'LAW',
#  'MDB',
#  'MGA',
#  'MQ',
#  'MSFT',
#  'NFLX',
#  'NVDA',
#  'OKTA',
#  'ONON',
#  'PINS',
#  'PLTR',
#  'PYPL',
#  'ROKU',
#  'SHOP',
#  'SNOW',
#  'SPT',
#  'SQ',
#  'TSLA',
#  'TTD',
#  'TWLO',
#  'TWTR',
#  'U',
#  'UPST',
#  'VEEV',
#  'ZM']

# %% [markdown]
# ### PSR distribution and Market Cap

# %%
import importlib
importlib.reload(mi)
df=mi.show_valuation(LIST, table=False, key="Cap")
# Out:
# The top 5 CAP stocks (2022-01-08)
# <style type="text/css">
# #T_4bbe7_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_4bbe7_row0_col2, #T_4bbe7_row1_col2, #T_4bbe7_row2_col2, #T_4bbe7_row3_col2, #T_4bbe7_row4_col1 {
#   background-color: #fda37b;
# }
# #T_4bbe7_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 33.5%, transparent 33.5%);
# }
# #T_4bbe7_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 9.2%, transparent 9.2%);
# }
# #T_4bbe7_row0_col5, #T_4bbe7_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_4bbe7_row0_col6, #T_4bbe7_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_4bbe7_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 50.7%, transparent 50.7%);
# }
# #T_4bbe7_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 47.4%, transparent 47.4%);
# }
# #T_4bbe7_row1_col0 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_4bbe7_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 59.8%, transparent 59.8%);
# }
# #T_4bbe7_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 10.5%, transparent 10.5%);
# }
# #T_4bbe7_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 36.3%, transparent 36.3%);
# }
# #T_4bbe7_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 33.4%, transparent 33.4%);
# }
# #T_4bbe7_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 38.7%, transparent 38.7%);
# }
# #T_4bbe7_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 77.5%, transparent 77.5%);
# }
# #T_4bbe7_row2_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_4bbe7_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 34.3%, transparent 34.3%);
# }
# #T_4bbe7_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 7.9%, transparent 7.9%);
# }
# #T_4bbe7_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 17.3%, transparent 17.3%);
# }
# #T_4bbe7_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 20.9%, transparent 20.9%);
# }
# #T_4bbe7_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 72.2%, transparent 72.2%);
# }
# #T_4bbe7_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 62.3%, transparent 62.3%);
# }
# #T_4bbe7_row3_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_4bbe7_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 15.6%, transparent 15.6%);
# }
# #T_4bbe7_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 19.0%, transparent 19.0%);
# }
# #T_4bbe7_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 31.0%, transparent 31.0%);
# }
# #T_4bbe7_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 17.5%, transparent 17.5%);
# }
# #T_4bbe7_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 26.9%, transparent 26.9%);
# }
# #T_4bbe7_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 19.9%, transparent 19.9%);
# }
# #T_4bbe7_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_4bbe7_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 80.9%, transparent 80.9%);
# }
# #T_4bbe7_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 10.6%, transparent 10.6%);
# }
# #T_4bbe7_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_4bbe7_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 35.3%, transparent 35.3%);
# }
# </style>
# <table id="T_4bbe7_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4bbe7_level0_row0" class="row_heading level0 row0" >AAPL</th>
#       <td id="T_4bbe7_row0_col0" class="data row0 col0" >$2.82e+12</td>
#       <td id="T_4bbe7_row0_col1" class="data row0 col1" >$172.0</td>
#       <td id="T_4bbe7_row0_col2" class="data row0 col2" >$174.9</td>
#       <td id="T_4bbe7_row0_col3" class="data row0 col3" >8.3</td>
#       <td id="T_4bbe7_row0_col4" class="data row0 col4" >30.7</td>
#       <td id="T_4bbe7_row0_col5" class="data row0 col5" >46.7</td>
#       <td id="T_4bbe7_row0_col6" class="data row0 col6" >147.4%</td>
#       <td id="T_4bbe7_row0_col7" class="data row0 col7" >28.8%</td>
#       <td id="T_4bbe7_row0_col8" class="data row0 col8" >28.4%</td>
#       <td id="T_4bbe7_row0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/AAPL">Y</a></td>
#       <td id="T_4bbe7_row0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/AAPL">a</a></td>
#       <td id="T_4bbe7_row0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=AAPL">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_4bbe7_level0_row1" class="row_heading level0 row1" >MSFT</th>
#       <td id="T_4bbe7_row1_col0" class="data row1 col0" >$2.36e+12</td>
#       <td id="T_4bbe7_row1_col1" class="data row1 col1" >$313.9</td>
#       <td id="T_4bbe7_row1_col2" class="data row1 col2" >$368.4</td>
#       <td id="T_4bbe7_row1_col3" class="data row1 col3" >14.8</td>
#       <td id="T_4bbe7_row1_col4" class="data row1 col4" >35.1</td>
#       <td id="T_4bbe7_row1_col5" class="data row1 col5" >16.9</td>
#       <td id="T_4bbe7_row1_col6" class="data row1 col6" >49.3%</td>
#       <td id="T_4bbe7_row1_col7" class="data row1 col7" >22.0%</td>
#       <td id="T_4bbe7_row1_col8" class="data row1 col8" >46.5%</td>
#       <td id="T_4bbe7_row1_col9" class="data row1 col9" ><a href="https://finance.yahoo.com/quote/MSFT">Y</a></td>
#       <td id="T_4bbe7_row1_col10" class="data row1 col10" ><a href="https://seekingalpha.com/symbol/MSFT">a</a></td>
#       <td id="T_4bbe7_row1_col11" class="data row1 col11" ><a href="https://jp.tradingview.com/chart/?symbol=MSFT">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_4bbe7_level0_row2" class="row_heading level0 row2" >GOOG</th>
#       <td id="T_4bbe7_row2_col0" class="data row2 col0" >$1.82e+12</td>
#       <td id="T_4bbe7_row2_col1" class="data row2 col1" >$2,751.0</td>
#       <td id="T_4bbe7_row2_col2" class="data row2 col2" >$3,366.7</td>
#       <td id="T_4bbe7_row2_col3" class="data row2 col3" >8.5</td>

# %%
df["Market Cap"].sort_values(ascending=False)
# Out:
# ticker
# AAPL    2.825000e+12
# MSFT    2.358000e+12
# GOOG    1.820000e+12
# AMZN    1.649000e+12
# TSLA    1.031000e+12
# FB      9.229600e+11
# NVDA    6.789950e+11
# ADBE    2.429910e+11
# NFLX    2.396640e+11
# PYPL    2.204170e+11
# SHOP    1.433390e+11
# ABNB    1.055060e+11
# SNOW    9.179200e+10
# SQ      6.528900e+10
# ZM      5.113600e+10
# DDOG    4.486500e+10
# CRWD    4.334300e+10
# TWLO    4.105100e+10
# TTD     3.794100e+10
# VEEV    3.559200e+10
# U       3.518000e+10
# PLTR    3.320000e+10
# TWTR    3.172100e+10
# EPAM    3.157500e+10
# OKTA    3.059100e+10
# MDB     2.867900e+10
# DOCU    2.689700e+10
# MGA     2.573200e+10
# ROKU    2.424000e+10
# HUBS    2.408300e+10
# ETSY    2.347400e+10
# PINS    2.114400e+10
# ONON    1.021500e+10
# UPST    9.585000e+09
# FIVN    9.120000e+09
# MQ      8.410000e+09
# SPT     4.049000e+09
# FVRR    3.604000e+09
# COUR    3.264000e+09
# LAW     1.846000e+09
# Name: Market Cap, dtype: float64

# %% [markdown]
# ### EPS history

# %%
import importlib
importlib.reload(mi)

#for i in [fangam, growth1, growth2]:
for i in [E12,E11,E10_5,E10_1,E9]:
#for i in [E12,E11,E10_5,E10_1]:
    mi.plot_eps_history(i)
    mi.show_valuation(i, hist=False, table=True, key="PSR")
# Out:
# PSR sorted list (2022-01-08)
# <style type="text/css">
# #T_e031b_row0_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e031b_row0_col1, #T_e031b_row1_col2, #T_e031b_row2_col2, #T_e031b_row3_col2, #T_e031b_row4_col2 {
#   background-color: #fda37b;
# }
# #T_e031b_row0_col3, #T_e031b_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_e031b_row0_col4, #T_e031b_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_e031b_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 80.9%, transparent 80.9%);
# }
# #T_e031b_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 10.6%, transparent 10.6%);
# }
# #T_e031b_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_e031b_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 35.3%, transparent 35.3%);
# }
# #T_e031b_row1_col0 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_e031b_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 59.8%, transparent 59.8%);
# }
# #T_e031b_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 10.5%, transparent 10.5%);
# }
# #T_e031b_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 36.3%, transparent 36.3%);
# }
# #T_e031b_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 33.4%, transparent 33.4%);
# }
# #T_e031b_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 38.7%, transparent 38.7%);
# }
# #T_e031b_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 77.5%, transparent 77.5%);
# }
# #T_e031b_row2_col0 {
#   background-color: #84bcdb;
#   color: #000000;
# }
# #T_e031b_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 34.3%, transparent 34.3%);
# }
# #T_e031b_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 7.9%, transparent 7.9%);
# }
# #T_e031b_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 17.3%, transparent 17.3%);
# }
# #T_e031b_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 20.9%, transparent 20.9%);
# }
# #T_e031b_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 72.2%, transparent 72.2%);
# }
# #T_e031b_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 62.3%, transparent 62.3%);
# }
# #T_e031b_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e031b_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 33.5%, transparent 33.5%);
# }
# #T_e031b_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 9.2%, transparent 9.2%);
# }
# #T_e031b_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 50.7%, transparent 50.7%);
# }
# #T_e031b_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 47.4%, transparent 47.4%);
# }
# #T_e031b_row4_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_e031b_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 15.6%, transparent 15.6%);
# }
# #T_e031b_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 19.0%, transparent 19.0%);
# }
# #T_e031b_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 31.0%, transparent 31.0%);
# }
# #T_e031b_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 17.5%, transparent 17.5%);
# }
# #T_e031b_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 26.9%, transparent 26.9%);
# }
# #T_e031b_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 19.9%, transparent 19.9%);
# }
# </style>
# <table id="T_e031b_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e031b_level0_row0" class="row_heading level0 row0" >TSLA</th>
#       <td id="T_e031b_row0_col0" class="data row0 col0" >$1.03e+12</td>
#       <td id="T_e031b_row0_col1" class="data row0 col1" >$1,064.7</td>
#       <td id="T_e031b_row0_col2" class="data row0 col2" >$894.0</td>
#       <td id="T_e031b_row0_col3" class="data row0 col3" >24.7</td>
#       <td id="T_e031b_row0_col4" class="data row0 col4" >335.4</td>
#       <td id="T_e031b_row0_col5" class="data row0 col5" >37.8</td>
#       <td id="T_e031b_row0_col6" class="data row0 col6" >15.6%</td>
#       <td id="T_e031b_row0_col7" class="data row0 col7" >56.8%</td>
#       <td id="T_e031b_row0_col8" class="data row0 col8" >21.2%</td>
#       <td id="T_e031b_row0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/TSLA">Y</a></td>
#       <td id="T_e031b_row0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/TSLA">a</a></td>
#       <td id="T_e031b_row0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=TSLA">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_e031b_level0_row1" class="row_heading level0 row1" >MSFT</th>
#       <td id="T_e031b_row1_col0" class="data row1 col0" >$2.36e+12</td>
#       <td id="T_e031b_row1_col1" class="data row1 col1" >$313.9</td>
#       <td id="T_e031b_row1_col2" class="data row1 col2" >$368.4</td>
#       <td id="T_e031b_row1_col3" class="data row1 col3" >14.8</td>
#       <td id="T_e031b_row1_col4" class="data row1 col4" >35.1</td>
#       <td id="T_e031b_row1_col5" class="data row1 col5" >16.9</td>
#       <td id="T_e031b_row1_col6" class="data row1 col6" >49.3%</td>
#       <td id="T_e031b_row1_col7" class="data row1 col7" >22.0%</td>
#       <td id="T_e031b_row1_col8" class="data row1 col8" >46.5%</td>
#       <td id="T_e031b_row1_col9" class="data row1 col9" ><a href="https://finance.yahoo.com/quote/MSFT">Y</a></td>
#       <td id="T_e031b_row1_col10" class="data row1 col10" ><a href="https://seekingalpha.com/symbol/MSFT">a</a></td>
#       <td id="T_e031b_row1_col11" class="data row1 col11" ><a href="https://jp.tradingview.com/chart/?symbol=MSFT">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_e031b_level0_row2" class="row_heading level0 row2" >GOOG</th>
#       <td id="T_e031b_row2_col0" class="data row2 col0" >$1.82e+12</td>
#       <td id="T_e031b_row2_col1" class="data row2 col1" >$2,751.0</td>
#       <td id="T_e031b_row2_col2" class="data row2 col2" >$3,366.7</td>
#       <td id="T_e031b_row2_col3" class="data row2 col3" >8.5</td>
# PSR sorted list (2022-01-08)
# <style type="text/css">
# #T_ef0de_row0_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ef0de_row0_col2, #T_ef0de_row1_col2, #T_ef0de_row2_col2, #T_ef0de_row3_col2, #T_ef0de_row4_col2, #T_ef0de_row5_col2, #T_ef0de_row6_col2 {
#   background-color: #fda37b;
# }
# #T_ef0de_row0_col3, #T_ef0de_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_ef0de_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 50.5%, transparent 50.5%);
# }
# #T_ef0de_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 50.9%, transparent 50.9%);
# }
# #T_ef0de_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 76.5%, #bcde93 76.5%, #bcde93 98.3%, transparent 98.3%);
# }
# #T_ef0de_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 69.6%, transparent 69.6%);
# }
# #T_ef0de_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 19.4%, transparent 19.4%);
# }
# #T_ef0de_row1_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_ef0de_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 71.8%, transparent 71.8%);
# }
# #T_ef0de_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_ef0de_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 76.5%, #bcde93 76.5%, #bcde93 100.0%, transparent 100.0%);
# }
# #T_ef0de_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 75.4%, transparent 75.4%);
# }
# #T_ef0de_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 55.9%, transparent 55.9%);
# }
# #T_ef0de_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ef0de_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 48.4%, transparent 48.4%);
# }
# #T_ef0de_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 81.2%, transparent 81.2%);
# }
# #T_ef0de_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 76.5%, transparent 76.5%);
# }
# #T_ef0de_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_ef0de_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 52.3%, transparent 52.3%);
# }
# #T_ef0de_row3_col0 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_ef0de_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 41.1%, transparent 41.1%);
# }
# #T_ef0de_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 60.7%, transparent 60.7%);
# }
# #T_ef0de_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 58.9%, transparent 58.9%);
# }
# #T_ef0de_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 76.5%, #bcde93 76.5%, #bcde93 95.8%, transparent 95.8%);
# }
# #T_ef0de_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 30.0%, transparent 30.0%);
# }
# #T_ef0de_row4_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_ef0de_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 22.2%, transparent 22.2%);
# }
# #T_ef0de_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 58.1%, transparent 58.1%);
# }
# #T_ef0de_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 55.8%, transparent 55.8%);
# }
# #T_ef0de_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 76.5%, #bcde93 76.5%, #bcde93 98.6%, transparent 98.6%);
# }
# #T_ef0de_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 24.4%, transparent 24.4%);
# }
# #T_ef0de_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 3.8%, transparent 3.8%);
# }
# #T_ef0de_row5_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_ef0de_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 20.8%, transparent 20.8%);
# }
# #T_ef0de_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 53.7%, transparent 53.7%);
# }
# #T_ef0de_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 31.6%, transparent 31.6%);
# }
# #T_ef0de_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 76.5%, #bcde93 76.5%, #bcde93 90.1%, transparent 90.1%);
# }
# #T_ef0de_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 19.8%, transparent 19.8%);
# }
# #T_ef0de_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 40.2%, transparent 40.2%);
# }
# #T_ef0de_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ef0de_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
# }
# #T_ef0de_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 28.3%, transparent 28.3%);
# }
# #T_ef0de_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 21.7%, transparent 21.7%);
# }
# #T_ef0de_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 76.5%, #bcde93 76.5%, #bcde93 94.5%, transparent 94.5%);
# }
# #T_ef0de_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 52.6%, transparent 52.6%);
# }
# #T_ef0de_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 79.6%, transparent 79.6%);
# }
# </style>
# <table id="T_ef0de_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef0de_level0_row0" class="row_heading level0 row0" >SHOP</th>
#       <td id="T_ef0de_row0_col0" class="data row0 col0" >$1.43e+11</td>
#       <td id="T_ef0de_row0_col1" class="data row0 col1" >$1,168.9</td>
#       <td id="T_ef0de_row0_col2" class="data row0 col2" >$2,093.3</td>
#       <td id="T_ef0de_row0_col3" class="data row0 col3" >43.9</td>
#       <td id="T_ef0de_row0_col4" class="data row0 col4" >42.4</td>
#       <td id="T_ef0de_row0_col5" class="data row0 col5" >16.1</td>
#       <td id="T_ef0de_row0_col6" class="data row0 col6" >38.9%</td>
#       <td id="T_ef0de_row0_col7" class="data row0 col7" >46.4%</td>
#       <td id="T_ef0de_row0_col8" class="data row0 col8" >11.6%</td>
#       <td id="T_ef0de_row0_col9" class="data row0 col9" ><a href="ht
# PSR sorted list (2022-01-08)
# <style type="text/css">
# #T_f2c85_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_f2c85_row0_col2, #T_f2c85_row1_col2, #T_f2c85_row2_col2, #T_f2c85_row3_col2 {
#   background-color: #fda37b;
# }
# #T_f2c85_row0_col3, #T_f2c85_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_f2c85_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 39.9%, transparent 39.9%);
# }
# #T_f2c85_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 30.2%, transparent 30.2%);
# }
# #T_f2c85_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_f2c85_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 8.2%, transparent 8.2%);
# }
# #T_f2c85_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_f2c85_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 57.2%, transparent 57.2%);
# }
# #T_f2c85_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 20.8%, #e68f8f 20.8%, #e68f8f 30.2%, transparent 30.2%);
# }
# #T_f2c85_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 68.4%, transparent 68.4%);
# }
# #T_f2c85_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 36.8%, transparent 36.8%);
# }
# #T_f2c85_row2_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_f2c85_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 13.5%, transparent 13.5%);
# }
# #T_f2c85_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 32.1%, transparent 32.1%);
# }
# #T_f2c85_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 19.0%, transparent 19.0%);
# }
# #T_f2c85_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 30.2%, #bcde93 30.2%, #bcde93 100.0%, transparent 100.0%);
# }
# #T_f2c85_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 32.1%, transparent 32.1%);
# }
# #T_f2c85_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 76.7%, transparent 76.7%);
# }
# #T_f2c85_row3_col0 {
#   background-color: #85bcdc;
#   color: #000000;
# }
# #T_f2c85_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 5.5%, transparent 5.5%);
# }
# #T_f2c85_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_f2c85_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 49.7%, transparent 49.7%);
# }
# #T_f2c85_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 30.2%, #bcde93 30.2%, #bcde93 72.6%, transparent 72.6%);
# }
# #T_f2c85_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 24.4%, transparent 24.4%);
# }
# #T_f2c85_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 7.9%, transparent 7.9%);
# }
# </style>
# <table id="T_f2c85_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2c85_level0_row0" class="row_heading level0 row0" >SNOW</th>
#       <td id="T_f2c85_row0_col0" class="data row0 col0" >$9.18e+10</td>
#       <td id="T_f2c85_row0_col1" class="data row0 col1" >$297.1</td>
#       <td id="T_f2c85_row0_col2" class="data row0 col2" >$387.4</td>
#       <td id="T_f2c85_row0_col3" class="data row0 col3" >106.5</td>
#       <td id="T_f2c85_row0_col4" class="data row0 col4" >-</td>
#       <td id="T_f2c85_row0_col5" class="data row0 col5" >22.7</td>
#       <td id="T_f2c85_row0_col6" class="data row0 col6" >-15.0%</td>
#       <td id="T_f2c85_row0_col7" class="data row0 col7" >109.5%</td>
#       <td id="T_f2c85_row0_col8" class="data row0 col8" >4.9%</td>
#       <td id="T_f2c85_row0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/SNOW">Y</a></td>
#       <td id="T_f2c85_row0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/SNOW">a</a></td>
#       <td id="T_f2c85_row0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=SNOW">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_f2c85_level0_row1" class="row_heading level0 row1" >DDOG</th>
#       <td id="T_f2c85_row1_col0" class="data row1 col0" >$4.49e+10</td>
#       <td id="T_f2c85_row1_col1" class="data row1 col1" >$143.9</td>
#       <td id="T_f2c85_row1_col2" class="data row1 col2" >$211.4</td>
#       <td id="T_f2c85_row1_col3" class="data row1 col3" >60.9</td>
#       <td id="T_f2c85_row1_col4" class="data row1 col4" >-</td>
#       <td id="T_f2c85_row1_col5" class="data row1 col5" >56.9</td>
#       <td id="T_f2c85_row1_col6" class="data row1 col6" >-4.7%</td>
#       <td id="T_f2c85_row1_col7" class="data row1 col7" >74.9%</td>
#       <td id="T_f2c85_row1_col8" class="data row1 col8" >22.1%</td>
#       <td id="T_f2c85_row1_col9" class="data row1 col9" ><a href="https://finance.yahoo.com/quote/DDOG">Y</a></td>
#       <td id="T_f2c85_row1_col10" class="data row1 col10" ><a href="https://seekingalpha.com/symbol/DDOG">a</a></td>
#       <td id="T_f2c85_row1_col11" class="data row1 col11" ><a href="https://jp.tradingview.com/chart/?symbol=DDOG">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_f2c85_level0_row2" class="row_heading level0 row2" >ZM</th>
#       <td id="T_f2c85_row2_col0" class="data row2 col0" >$5.11e+10</td>
#       <td id="T_f2c85_row2_col1" class="data row2 col1" >$176.3</td>
#       <td id="T_f2c85_row2_col2" class="data row2 col2" >$319.3</td>
#       <td id="T_f2c85_row2_col3" class="data row2 col3" >14.4</td>
#       <td id="T_f2c85_row2_col4" class="data row2 col4" >45.6</td>
#       <td id="T_f2c85_row2_col5" class="data row2 col5" >10.8</td>
#       <td id="T_f2c85_row2_col6" class="data row2 col6" >34.6%</td>
#       <td id="T_f2c85_row2_col7" class="data row2 col7" >35.2%</td>
#       <td id="T_f2c85_row2_col8" class="data row2 col8" >46.0%</td>
#       <td id="T_f2c85_row2_col9" class="data row2 col9" ><a href="https://finance.yahoo.com/quote/ZM">Y</a></td>
#       <td id="T_f2c85_row2_col10" class="data row2 col10" ><a href="https://seekingalpha.com/symbol/ZM">a</a></td>
#       <td id="T_f2c85_row2_col11" class="data row2 col11" ><a href="https://jp.tradingview.com/chart/?symbol=ZM">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_f2c85_level0_row3" class="row_heading level0 row3" >SQ</th>
#       <td id="T_f2c85_row3_col0" class="data row3 col0" >$6.53e+10</td>
#       <td id="T_f2c85_row3_
# PSR sorted list (2022-01-08)
# <style type="text/css">
# #T_52b48_row0_col0 {
#   background-color: #0e59a2;
#   color: #f1f1f1;
# }
# #T_52b48_row0_col2, #T_52b48_row1_col2, #T_52b48_row2_col2, #T_52b48_row3_col2, #T_52b48_row4_col2, #T_52b48_row5_col2, #T_52b48_row6_col2, #T_52b48_row7_col2, #T_52b48_row8_col2, #T_52b48_row9_col2, #T_52b48_row10_col2, #T_52b48_row11_col2, #T_52b48_row12_col2, #T_52b48_row13_col2, #T_52b48_row14_col2, #T_52b48_row15_col2, #T_52b48_row16_col2 {
#   background-color: #fda37b;
# }
# #T_52b48_row0_col3, #T_52b48_row11_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_52b48_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_52b48_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 29.1%, transparent 29.1%);
# }
# #T_52b48_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 52.1%, #bcde93 52.1%, #bcde93 67.9%, transparent 67.9%);
# }
# #T_52b48_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 5.2%, #f4d18b 5.2%, #f4d18b 20.6%, transparent 20.6%);
# }
# #T_52b48_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.6%, #3c76af 8.6%, #3c76af 60.7%, transparent 60.7%);
# }
# #T_52b48_row1_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_52b48_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 98.3%, transparent 98.3%);
# }
# #T_52b48_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 42.8%, transparent 42.8%);
# }
# #T_52b48_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 52.1%, transparent 52.1%);
# }
# #T_52b48_row1_col7, #T_52b48_row12_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 5.2%, #f4d18b 5.2%, #f4d18b 25.0%, transparent 25.0%);
# }
# #T_52b48_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 2.0%, #e68f8f 2.0%, #e68f8f 8.6%, transparent 8.6%);
# }
# #T_52b48_row2_col0 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_52b48_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 94.0%, transparent 94.0%);
# }
# #T_52b48_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 17.2%, transparent 17.2%);
# }
# #T_52b48_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 38.6%, #e68f8f 38.6%, #e68f8f 52.1%, transparent 52.1%);
# }
# #T_52b48_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 5.2%, #f4d18b 5.2%, #f4d18b 21.9%, transparent 21.9%);
# }
# #T_52b48_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 8.6%, transparent 8.6%);
# }
# #T_52b48_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_52b48_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 83.2%, transparent 83.2%);
# }
# #T_52b48_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 40.3%, transparent 40.3%);
# }
# #T_52b48_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 38.0%, #e68f8f 38.0%, #e68f8f 52.1%, transparent 52.1%);
# }
# #T_52b48_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 5.2%, #f4d18b 5.2%, #f4d18b 30.0%, transparent 30.0%);
# }
# #T_52b48_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.6%, #3c76af 8.6%, #3c76af 71.1%, transparent 71.1%);
# }
# #T_52b48_row4_col0 {
#   background-color: #89bedc;
#   color: #000000;
# }
# #T_52b48_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 68.1%, transparent 68.1%);
# }
# #T_52b48_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 34.4%, transparent 34.4%);
# }
# #T_52b48_row4_col6, #T_52b48_row9_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 46.2%, #e68f8f 46.2%, #e68f8f 52.1%, transparent 52.1%);
# }
# #T_52b48_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 5.2%, #f4d18b 5.2%, #f4d18b 24.2%, transparent 24.2%);
# }
# #T_52b48_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.6%, #3c76af 8.6%, #3c76af 35.0%, transparent 35.0%);
# }
# #T_52b48_row5_col0 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_52b48_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 65.9%, transparent 65.9%);
# }
# #T_52b48_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 4.9%, transparent 4.9%);
# }
# #T_52b48_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 39.8%, #e68f8f 39.8%, #e68f8f 52.1%, transparent 52.1%);
# }
# #T_52b48_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 5.2%, #f4d18b 5.2%, #f4d18b 29.2%, transparent 29.2%);
# }
# #T_52b48_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.6%, #7eb8ef 8.6%, #7eb8ef 25.2%, transparent 25.2%);
# }
# #T_52b48_row6_col0 {
#   background-color: #2e7ebc;
#   color: #f1f1f1;
# }
# #T_52b48_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 59.0%, transparent 59.0%);
# }
# #T_52b48_row6_col5, #T_52b48_row13_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 14.2%, transparent 14.2%);
# }
# #T_52b48_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 34.6%, #e68f8f 34.6%, #e68f8f 52.1%, transparent 52.1%);
# }
# #T_52b48_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 5.2%, #f4d18b 5.2%, #f4d18b 19.1%, transparent 19.1%);
# }
# #T_52b48_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.6%, #3c76af 8.6%, #3c76af 32.3%, transparent 32.3%);
# }
# #T_52b48_row7_col0 {
#   background-color: #1c6bb0;
#   color: #f1f1f1;
# }
# #T_52b48_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 58.6%, transparent 58.6%);
# }
# #T_52b48_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 61.8%, transparent 61.8%);
# }
# #T_52b48_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 12.4%, transparent 12.4%);
# }
# #T_52b48_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 52.1%, #bcde93 52.1%, #bcde93 62.7%, transparent 62.7%);
# }
# #T_52b48_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 5.2%, #f4d18b 5.2%, #f4d18b 15.4%, transparent 15.4%);
# }
# #T_52b48_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.6%, #3c76af 8.6%, #3c76af 76.0%, transparent 76.0%);
# }
# #T_52b48_row8_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_52b48_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 50.6%, transparent 50.6%);
# }
# #T_52b48_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 84.0%, transparent 84.0%);
# }
# #T_52b48_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 15.4%, transparent 15.4%);
# }
# #T_52b48_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 52.1%, #bcde93 52.1%, #bcde93 63.2%, transparent 63.2%);
# }
# #T_52b48_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 5.2%, #f4d18b 5.2%, #f4d18b 100.0%, transparent 100.0%);
# }
# #T_52b48_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.6%, #3c76af 8.6%, #3c76af 68.2%, transparent 68.2%);
# }
# #T_52b48_row9_col0 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_52b48_row9_col3 {
# no data for ONON
# PSR sorted list (2022-01-08)
# <style type="text/css">
# #T_8a551_row0_col0 {
#   background-color: #c2d9ee;
#   color: #000000;
# }
# #T_8a551_row0_col2, #T_8a551_row1_col2, #T_8a551_row2_col2, #T_8a551_row3_col2, #T_8a551_row4_col2, #T_8a551_row5_col2, #T_8a551_row6_col2 {
#   background-color: #fda37b;
# }
# #T_8a551_row0_col3, #T_8a551_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_8a551_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 65.6%, transparent 65.6%);
# }
# #T_8a551_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 38.0%, #e68f8f 38.0%, #e68f8f 100.0%, transparent 100.0%);
# }
# #T_8a551_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 67.8%, transparent 67.8%);
# }
# #T_8a551_row0_col8, #T_8a551_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 28.5%, #7eb8ef 28.5%, #7eb8ef 36.9%, transparent 36.9%);
# }
# #T_8a551_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_8a551_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 75.1%, transparent 75.1%);
# }
# #T_8a551_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 15.3%, transparent 15.3%);
# }
# #T_8a551_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 99.3%, transparent 99.3%);
# }
# #T_8a551_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 28.5%, transparent 28.5%);
# }
# #T_8a551_row2_col0 {
#   background-color: #1a68ae;
#   color: #f1f1f1;
# }
# #T_8a551_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 64.4%, transparent 64.4%);
# }
# #T_8a551_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 10.3%, transparent 10.3%);
# }
# #T_8a551_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 82.8%, transparent 82.8%);
# }
# #T_8a551_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 28.5%, #7eb8ef 28.5%, #7eb8ef 34.6%, transparent 34.6%);
# }
# #T_8a551_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_8a551_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 56.4%, transparent 56.4%);
# }
# #T_8a551_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_8a551_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 23.1%, transparent 23.1%);
# }
# #T_8a551_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_8a551_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 26.3%, #e68f8f 26.3%, #e68f8f 28.5%, transparent 28.5%);
# }
# #T_8a551_row4_col0 {
#   background-color: #cee0f2;
#   color: #000000;
# }
# #T_8a551_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 55.3%, transparent 55.3%);
# }
# #T_8a551_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 25.5%, transparent 25.5%);
# }
# #T_8a551_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 35.5%, #e68f8f 35.5%, #e68f8f 100.0%, transparent 100.0%);
# }
# #T_8a551_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 62.1%, transparent 62.1%);
# }
# #T_8a551_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 28.5%, #7eb8ef 28.5%, #7eb8ef 43.5%, transparent 43.5%);
# }
# #T_8a551_row5_col0 {
#   background-color: #09529d;
#   color: #f1f1f1;
# }
# #T_8a551_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 53.4%, transparent 53.4%);
# }
# #T_8a551_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 100.0%, transparent 100.0%);
# }
# #T_8a551_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 55.6%, transparent 55.6%);
# }
# #T_8a551_row6_col0 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_8a551_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 32.1%, transparent 32.1%);
# }
# #T_8a551_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 9.1%, transparent 9.1%);
# }
# #T_8a551_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 48.7%, transparent 48.7%);
# }
# #T_8a551_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 23.3%, #e68f8f 23.3%, #e68f8f 28.5%, transparent 28.5%);
# }
# </style>
# <table id="T_8a551_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8a551_level0_row0" class="row_heading level0 row0" >SPT</th>
#       <td id="T_8a551_row0_col0" class="data row0 col0" >$4.05e+09</td>
#       <td id="T_8a551_row0_col1" class="data row0 col1" >$74.3</td>
#       <td id="T_8a551_row0_col2" class="data row0 col2" >$152.0</td>
#       <td id="T_8a551_row0_col3" class="data row0 col3" >29.4</td>
#       <td id="T_8a551_row0_col4" class="data row0 col4" >-</td>
#       <td id="T_8a551_row0_col5" class="data row0 col5" >34.4</td>
#       <td id="T_8a551_row0_col6" class="data row0 col6" >-16.2%</td>
#       <td id="T_8a551_row0_col7" class="data row0 col7" >45.8%</td>
#       <td id="T_8a551_row0_col8" class="data row0 col8" >7.1%</td>
#       <td id="T_8a551_row0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/SPT">Y</a></td>
#       <td id="T_8a551_row0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/SPT">a</a></td>
#       <td id="T_8a551_row0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=SPT">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_8a551_level0_row1" class="row_heading level0 row1" >LAW</th>
#       <td id="T_8a551_row1_col0" class="data row1 col0" >$1.85e+09</td>
#       <td id="T_8a551_row1_col1" class="data row1 col1" >$29.9</td>
#       <td id="T_8a551_row1_col2" class="data row1 col2" >$67.5</td>
#       <td id="T_8a551_row1_col3" class="data row1 col3" >22.1</td>
#       <td id="T_8a551_row1_col4" class="data row1 col4" >-</td>
#       <td id="T_8a551_row1_col5" class="data row1 col5" >8.0</td>
#       <td id="T_8a551_row1_col6" class="data row1 col6" >-</td>
#       <td id="T_8a551_row1_col7" class="data row1 col7" >67.1%</td>
#       <td id="T_8a551_row1_col8" class="data row1 col8" >-23.9%</td>
#       <td id="T_8a551_row1_col9" class="data row1 col9" ><a href="https://fi

# %%
ret=mi.plot_eps_history(jicchama)

# %% [markdown]
# ### FANGAMのみ大きく出してみる

# %%
mi.plot_eps(fangam,largefig=True)
mi.search_good_eps(fangam, last=200)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_36/584648147.py in <module>
# ----> 1 mi.plot_eps(fangam,largefig=True)
#       2 mi.search_good_eps(fangam, last=200)
#
# AttributeError: module 'mystock_info' has no attribute 'plot_eps'

# %% [markdown]
# ## Energy

# %%
ENE=["STNG","HLX","FANG","PXD","AR","XOM","SLB","TNP","EURN","CVX"]
df_res=mi.plot_eps_history(ENE,last=20)

# %%
df_res=mi.show_valuation(ENE,table=True)

# %% [markdown]
# ## Health/Bio

# %%
H_E11 = [
    "PFE",
    "DHR",
    "MRNA",
    "BMY",
    "AMGN",
    "BNTX",
]
H_E10 = [
    "ANTM",
    "VEEV",
    "BIIB",
    "A",
    "RPRX",
]
H_E9 = [
    "INOV",
    "PGNY",
    "RGEN",
    "INMD",
    "DOCS",
    "MRK"
]
health = H_E11 + H_E10 + H_E9

# %%
import importlib
importlib.reload(mi)
# EPS history
df_res=mi.plot_eps_history(health,last=20)

# %%
import importlib
importlib.reload(mi)

df_res=mi.show_valuation(health,table=True)
#df_cap=mi.show_valuation(health,table=True,hist=False,key="Cap")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_35/1554294065.py in <module>
#       2 importlib.reload(mi)
#       3
# ----> 4 df_res=mi.show_valuation(health,table=True)
#       5 #df_cap=mi.show_valuation(health,table=True,hist=False,key="Cap")
#
# ~/yahoo_fin/mystock_info.py in show_valuation(tickers, clear_cache, hist, table, key, ascending, verbose)
#     386     key=key.upper()
#     387
# --> 388     df = get_valuation(tickers, clear_cache=clear_cache, verbose=verbose)
#     389
#     390     PSR = col_name(df, "Price/Sales")
#
# ~/yahoo_fin/mystock_info.py in get_valuation(tickers, clear_cache, verbose)
#     359     and combine the results.
#     360     """
# --> 361     df = get_data(fn=_get_valuation,tickers=tickers,clear_cache=clear_cache,verbose=verbose)
#     362     tmp=df.info
#     363     df = df.pivot(index="ticker", columns="info", values="values")
#
# ~/yahoo_fin/mystock_info.py in get_data(fn, tickers, **kwargs)
#     132     for ticker in tickers:
#     133         ticker = ticker.upper()
# --> 134         tmp = fn(ticker=ticker, **kwargs)
#     135         if tmp is not None and len(tmp) != 0:
#     136             tmp=tmp.loc[:,~tmp.columns.duplicated()]# sometimes downloaded df has duplicated columns
#
# ~/yahoo_fin/mystock_info.py in _get_valuation(ticker, clear_cache, verbose)
#     304     df_st = si.get_stats(ticker).set_axis(["info", "values"], axis=1)
#     305     df_st = df_st[df_st["info"] != 'Beta (5Y Monthly)']
# --> 306     df_val = si.get_stats_valuation(ticker).set_axis(["info", "values"], axis=1)
#     307     if len(df_st) == 0 or len(df_val) == 0:
#     308         print("no stats data for {}".format(ticker))
#
# /usr/local/lib/python3.8/dist-packages/yahoo_fin/stock_info.py in get_stats_valuation(ticker, headers)
#     360
#     361
# --> 362     table = tables[0].reset_index(drop = True)
#     363
#     364     return table
#
# IndexError: list index out of range

# %% [markdown]
# ## バリュー株

# %%
MINE=["RIO","VALE"]

VALUE=["AOS","CTAS","COST","EURN","HD","KO","LOW","NUE","UNP","TGT","XMTR","W"]#,"HIMS"]
df_res=mi.show_valuation(VALUE,table=True)
# Out:
# PSR sorted list (2021-12-23)
# <style type="text/css">
# #T_9068f_row0_col0, #T_9068f_row3_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_9068f_row0_col2, #T_9068f_row1_col2, #T_9068f_row2_col2, #T_9068f_row3_col2, #T_9068f_row4_col1, #T_9068f_row5_col1, #T_9068f_row6_col1, #T_9068f_row7_col2, #T_9068f_row8_col1, #T_9068f_row9_col1, #T_9068f_row10_col1, #T_9068f_row11_col2 {
#   background-color: #fda37b;
# }
# #T_9068f_row0_col3, #T_9068f_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_9068f_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 1.4%, transparent 1.4%);
# }
# #T_9068f_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 35.0%, #f4d18b 35.0%, #f4d18b 55.9%, transparent 55.9%);
# }
# #T_9068f_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 27.1%, transparent 27.1%);
# }
# #T_9068f_row1_col0 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_9068f_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 71.6%, transparent 71.6%);
# }
# #T_9068f_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 46.4%, transparent 46.4%);
# }
# #T_9068f_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 2.7%, transparent 2.7%);
# }
# #T_9068f_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 1.2%, #bcde93 1.2%, #bcde93 4.3%, transparent 4.3%);
# }
# #T_9068f_row1_col7, #T_9068f_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 35.0%, #f4d18b 35.0%, #f4d18b 42.9%, transparent 42.9%);
# }
# #T_9068f_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 27.1%, #3c76af 27.1%, #3c76af 79.0%, transparent 79.0%);
# }
# #T_9068f_row2_col0 {
#   background-color: #4997c9;
#   color: #f1f1f1;
# }
# #T_9068f_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 59.4%, transparent 59.4%);
# }
# #T_9068f_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 61.7%, transparent 61.7%);
# }
# #T_9068f_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 2.6%, transparent 2.6%);
# }
# #T_9068f_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 1.2%, #bcde93 1.2%, #bcde93 4.1%, transparent 4.1%);
# }
# #T_9068f_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 35.0%, #f4d18b 35.0%, #f4d18b 59.8%, transparent 59.8%);
# }
# #T_9068f_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 27.1%, #3c76af 27.1%, #3c76af 69.1%, transparent 69.1%);
# }
# #T_9068f_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 37.5%, transparent 37.5%);
# }
# #T_9068f_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 0.2%, transparent 0.2%);
# }
# #T_9068f_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 1.2%, transparent 1.2%);
# }
# #T_9068f_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 35.0%, transparent 35.0%);
# }
# #T_9068f_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 27.1%, #3c76af 27.1%, #3c76af 64.4%, transparent 64.4%);
# }
# #T_9068f_row4_col0 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_9068f_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 37.0%, transparent 37.0%);
# }
# #T_9068f_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 50.0%, transparent 50.0%);
# }
# #T_9068f_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 1.7%, transparent 1.7%);
# }
# #T_9068f_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 1.2%, #bcde93 1.2%, #bcde93 3.2%, transparent 3.2%);
# }
# #T_9068f_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 35.0%, #f4d18b 35.0%, #f4d18b 47.1%, transparent 47.1%);
# }
# #T_9068f_row4_col8, #T_9068f_row9_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 27.1%, #3c76af 27.1%, #3c76af 49.0%, transparent 49.0%);
# }
# #T_9068f_row5_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_9068f_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 27.6%, transparent 27.6%);
# }
# #T_9068f_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 50.5%, transparent 50.5%);
# }
# #T_9068f_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 1.2%, #bcde93 1.2%, #bcde93 100.0%, transparent 100.0%);
# }
# #T_9068f_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 35.0%, #f4d18b 35.0%, #f4d18b 40.8%, transparent 40.8%);
# }
# #T_9068f_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 27.1%, #7eb8ef 27.1%, #7eb8ef 39.3%, transparent 39.3%);
# }
# #T_9068f_row6_col0 {
#   background-color: #4f9bcb;
#   color: #f1f1f1;
# }
# #T_9068f_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 11.7%, transparent 11.7%);
# }
# #T_9068f_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_9068f_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 3.4%, transparent 3.4%);
# }
# #T_9068f_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 1.2%, #bcde93 1.2%, #bcde93 3.4%, transparent 3.4%);
# }
# #T_9068f_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 35.0%, #f4d18b 35.0%, #f4d18b 45.4%, transparent 45.4%);
# }
# #T_9068f_row7_col0 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_9068f_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 10.6%, transparent 10.6%);
# }
# #T_9068f_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 28.6%, transparent 28.6%);
# }
# #T_9068f_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 2.0%, transparent 2.0%);
# }
# #T_9068f_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 1.2%, #bcde93 1.2%, #bcde93 5.2%, transparent 5.2%);
# }
# #T_9068f_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 27.1%, #7eb8ef 27.1%, #7eb8ef 37.8%, transparent 37.8%);
# }
# #T_9068f_row8_col0 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_9068f_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 10.0%, transparent 10.0%);
# }
# #T_9068f_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 12.7%, transparent 12.7%);
# }
# #T_9068f_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 0.6%, transparent 0.6%);
# }
# #T_9068f_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 1.2%, #bcde93 1.2%, #bcde93 4.5%, transparent 4.5%);
# }
# #T_9068f_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 35.0%, #f4d18b 35.0%, #f4d18b 100.0%, transparent 100.0%);
# }
# #T_9068f_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 27.1%, #7eb8ef 27.1%, #7eb8ef 43.0%, transparent 43.0%);
# }
# #T_9068f_row9_col0 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_9068f_row9_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 74.1%, transparent 74.1%);
# }
# #T_9068f_row9_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 1.2%, #bcde93 1.2%, #bcde93 3.8%, transparent 3.8%);
# }
# #T_9068f_row9_col7 {
#   width: 10em;
#   height: 80%;
#   backgroun

# %% [markdown]
# # VUGとIWFの組入銘柄（570銘柄）の優良銘柄

# %%
GOOD=["ADP","AKAM","AZO","BC","BRO","CRL","CPRT","DHR","EFX","FB","FND","IQV","LPX","MKSI","MMC","MPWR","MSFT","MTD","NVDA","ORLY","ROL","SCCO","SPGI","TPX","TRU"]
df_res = mi.show_valuation(GOOD, hist=True, table=True, key="PSR")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_35/2620936525.py in <module>
#       1 GOOD=["ADP","AKAM","AZO","BC","BRO","CRL","CPRT","DHR","EFX","FB","FND","IQV","LPX","MKSI","MMC","MPWR","MSFT","MTD","NVDA","ORLY","ROL","SCCO","SPGI","TPX","TRU"]
# ----> 2 df_res = mi.show_valuation(GOOD, hist=True, table=True, key="PSR")
#
# ~/yahoo_fin/mystock_info.py in show_valuation(tickers, clear_cache, hist, table, key, ascending, verbose)
#     386     key=key.upper()
#     387
# --> 388     df = get_valuation(tickers, clear_cache=clear_cache, verbose=verbose)
#     389
#     390     PSR = col_name(df, "Price/Sales")
#
# ~/yahoo_fin/mystock_info.py in get_valuation(tickers, clear_cache, verbose)
#     359     and combine the results.
#     360     """
# --> 361     df = get_data(fn=_get_valuation,tickers=tickers,clear_cache=clear_cache,verbose=verbose)
#     362     tmp=df.info
#     363     df = df.pivot(index="ticker", columns="info", values="values")
#
# ~/yahoo_fin/mystock_info.py in get_data(fn, tickers, **kwargs)
#     132     for ticker in tickers:
#     133         ticker = ticker.upper()
# --> 134         tmp = fn(ticker=ticker, **kwargs)
#     135         if tmp is not None and len(tmp) != 0:
#     136             tmp=tmp.loc[:,~tmp.columns.duplicated()]# sometimes downloaded df has duplicated columns
#
# ~/yahoo_fin/mystock_info.py in _get_valuation(ticker, clear_cache, verbose)
#     304     df_st = si.get_stats(ticker).set_axis(["info", "values"], axis=1)
#     305     df_st = df_st[df_st["info"] != 'Beta (5Y Monthly)']
# --> 306     df_val = si.get_stats_valuation(ticker).set_axis(["info", "values"], axis=1)
#     307     if len(df_st) == 0 or len(df_val) == 0:
#     308         print("no stats data for {}".format(ticker))
#
# /usr/local/lib/python3.8/dist-packages/yahoo_fin/stock_info.py in get_stats_valuation(ticker, headers)
#     360
#     361
# --> 362     table = tables[0].reset_index(drop = True)
#     363
#     364     return table
#
# IndexError: list index out of range

# %%
df_res=mi.plot_eps_history(GOOD,last=20)

# %%
ret=mi.show_beat_ratio(GOOD,last=40,threshold=95,min_qtrs=20)

# %% [markdown]
# ## Get stock info of your favorite

# %% [markdown]
# ### Find Tickers with high EPS beat ratio

# %%
# pd.set_option('display.max_rows', df.shape[0]+1)
tickers_nasdaq = si.tickers_nasdaq()
ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)

# %%
# !pip  install pandas==1.3.1
