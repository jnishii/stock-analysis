# %% [markdown]
# # EPS analysis

# %% [markdown]
# ## import modules and difine basic modules & functions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import yahoo_fin.stock_info as si

# private module
import mystock_info as mi

# %%
#!pip install dataframe_image

# %%
import importlib
importlib.reload(mi)
# Out:
# <module 'mystock_info' from '/home/jovyan/yahoo_fin/mystock_info.py'>

# %% [markdown]
# ## Tech companies

# %%
fangam=["FB","AAPL","NFLX","GOOG","AMZN","MSFT"]

###
ant=["ADBE","NVDA","TSLA"]
saas=["CRWD","OKTA","ZS","TTD","TWLO"]
ecommerce=["SHOP","ETSY","FIVN"]

fintech=["SQ","DOCU", "PYPL"]
media=["TWTR","PINS"]
techs=["U","ZM","FVRR","ABNB","ROKU"]
eauto=["F","GM","MGA"]

growth1=ant+saas+ecommerce
growth2=fintech+media+techs+eauto

# %%
E12 = ["FB", "AAPL", "GOOG", "AMZN", "MSFT"] # Trillion
E11 = ["NFLX", "TSLA","ADBE", "NVDA","PYPL", "SHOP", "SQ", "ZM"] # over 100 Billion
E10_5 = ( # Over 50 Billion
    ["ABNB", "GM", "F"] 
    + ["CRWD", "TWLO","TWTR"]
    + [ "DOCU"]
)
E10_1 = ["ROKU", "PLTR","OKTA", "EPAM","U", "MGA","ZS", "ETSY","FIVN", "PINS", "HUBS"] # over 10 Billion

E9 = ["FVRR","FSLY", "TTD"] # over 1 Billion

LIST=E12+E11+E10_5+E10_1+E9
###

# %% [markdown]
# ### PSR distribution and Market Cap

# %%
import importlib
importlib.reload(mi)
df=mi.show_valuation(LIST, table=False, key="Cap")
df["Market Cap"]
# Out:
# The top 5 CAP stocks (2021-08-20)
# <style type="text/css">
# #T_0a0e6_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0a0e6_row0_col2, #T_0a0e6_row1_col2, #T_0a0e6_row2_col1, #T_0a0e6_row3_col2, #T_0a0e6_row4_col2 {
#   background-color: #fda37b;
# }
# #T_0a0e6_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
# }
# #T_0a0e6_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 50.8%, transparent 50.8%);
# }
# #T_0a0e6_row0_col5, #T_0a0e6_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_0a0e6_row0_col6, #T_0a0e6_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_0a0e6_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 59.1%, transparent 59.1%);
# }
# #T_0a0e6_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 50.1%, transparent 50.1%);
# }
# #T_0a0e6_row1_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_0a0e6_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 63.0%, transparent 63.0%);
# }
# #T_0a0e6_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
# }
# #T_0a0e6_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
# }
# #T_0a0e6_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
# }
# #T_0a0e6_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
# }
# #T_0a0e6_row2_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_0a0e6_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 64.1%, transparent 64.1%);
# }
# #T_0a0e6_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 52.3%, transparent 52.3%);
# }
# #T_0a0e6_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 20.3%, transparent 20.3%);
# }
# #T_0a0e6_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
# }
# #T_0a0e6_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_0a0e6_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
# }
# #T_0a0e6_row3_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_0a0e6_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 28.9%, transparent 28.9%);
# }
# #T_0a0e6_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 37.8%, transparent 37.8%);
# }
# #T_0a0e6_row3_col6, #T_0a0e6_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
# }
# #T_0a0e6_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 44.2%, transparent 44.2%);
# }
# #T_0a0e6_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 22.3%, transparent 22.3%);
# }
# #T_0a0e6_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0a0e6_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
# }
# #T_0a0e6_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 47.0%, transparent 47.0%);
# }
# #T_0a0e6_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 19.4%, transparent 19.4%);
# }
# #T_0a0e6_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
# }
# #T_0a0e6_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
# }
# </style>
# <table id="T_0a0e6_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a0e6_level0_row0" class="row_heading level0 row0" >AAPL</th>
#       <td id="T_0a0e6_row0_col0" class="data row0 col0" >$2.46e+12</td>
#       <td id="T_0a0e6_row0_col1" class="data row0 col1" >$148.9</td>
#       <td id="T_0a0e6_row0_col2" class="data row0 col2" >$159.3</td>
#       <td id="T_0a0e6_row0_col3" class="data row0 col3" >7.1</td>
#       <td id="T_0a0e6_row0_col4" class="data row0 col4" >29.2</td>
#       <td id="T_0a0e6_row0_col5" class="data row0 col5" >38.4</td>
#       <td id="T_0a0e6_row0_col6" class="data row0 col6" >127.1%</td>
#       <td id="T_0a0e6_row0_col7" class="data row0 col7" >36.4%</td>
#       <td id="T_0a0e6_row0_col8" class="data row0 col8" >30.1%</td>
#       <td id="T_0a0e6_row0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/AAPL">Y</a></td>
#       <td id="T_0a0e6_row0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/AAPL">a</a></td>
#       <td id="T_0a0e6_row0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=AAPL">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_0a0e6_level0_row1" class="row_heading level0 row1" >MSFT</th>
#       <td id="T_0a0e6_row1_col0" class="data row1 col0" >$2.19e+12</td>
#       <td id="T_0a0e6_row1_col1" class="data row1 col1" >$289.8</td>
#       <td id="T_0a0e6_row1_col2" class="data row1 col2" >$298.9</td>
#       <td id="T_0a0e6_row1_col3" class="data row1 col3" >13.0</td>
#       <td id="T_0a0e6_row1_col4" class="data row1 col4" >36.2</td>
#       <td id="T_0a0e6_row1_col5" class="data row1 col5" >15.4</td>
#       <td id="T_0a0e6_row1_col6" class="data row1 col6" >47.1%</td>
#       <td id="T_0a0e6_row1_col7" class="data row1 col7" >21.3%</td>
#       <td id="T_0a0e6_row1_col8" class="data row1 col8" >45.7%</td>
#       <td id="T_0a0e6_row1_col9" class="data row1 col9" ><a href="https://finance.yahoo.com/quote/MSFT">Y</a></td>
#       <td id="T_0a0e6_row1_col10" class="data row1 col10" ><a href="https://seekingalpha.com/symbol/MSFT">a</a></td>
#       <td id="T_0a0e6_row1_col11" class="data row1 col11" ><a href="https://jp.tradingview.com/chart/?symbol=MSFT">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_0a0e6_level0_row2" class="row_heading level0 row2" >GOOG</th>
#       <td id="T_0a0e6_row2_col0" class="data row2 col0" >$1.84e+12</td>
#       <td id="T_0a0e6_row2_col1" class="data row2 col1" >$2,767.8</td>
#       <td id="T_0a0e6_row2_col2" class="data row2 col2" >$2,625.0</td>
#       <td id="T_0a0e6_row2_col3" class="data row2 col3" >8.3</td>
#       <td id="T_0a0e6_row2_col4" class="data row2 col4" >30.0</td>
#       <td id="T_0a0e6_row2_col5" cla
# ticker
# AAPL    2.464000e+12
# MSFT    2.188000e+12
# GOOG    1.837000e+12
# AMZN    1.668000e+12
# FB      1.025000e+12
# TSLA    7.158300e+11
# NVDA    4.994210e+11
# PYPL    3.164000e+11
# ADBE    3.036840e+11
# NFLX    2.286540e+11
# SHOP    1.860530e+11
# SQ      1.238240e+11
# ZM      1.068590e+11
# ABNB    9.172100e+10
# GM      7.843600e+10
# TWLO    6.508800e+10
# DOCU    5.794400e+10
# CRWD    5.578100e+10
# F       5.504800e+10
# TWTR    4.992100e+10
# PLTR    4.863300e+10
# ROKU    4.858200e+10
# TTD     3.962000e+10
# OKTA    3.639700e+10
# PINS    3.613100e+10
# U       3.550300e+10
# EPAM    3.461100e+10
# ZS      3.365500e+10
# HUBS    3.046300e+10
# MGA     2.573800e+10
# ETSY    2.410800e+10
# FIVN    1.293300e+10
# FVRR    6.185000e+09
# FSLY    4.983000e+09
# Name: Market Cap, dtype: float64

# %%
df.head()
# Out:
# info      Market Cap  Previous Close  1y Target Est  Price/Sales (ttm)  \
# ticker
# AAPL    2.464000e+12          148.89         159.34               7.10
# MSFT    2.188000e+12          289.81         298.92              13.01
# GOOG    1.837000e+12         2767.79        2625.00               8.34
# AMZN    1.668000e+12         3303.50        4241.33               3.76
# FB      1.025000e+12          362.65         386.47               9.78
#
# info    PE Ratio (TTM)  Price/Book (mrq)  Return on Equity (ttm)  \
# ticker
# AAPL             29.18             38.39                  127.13
# MSFT             36.17             15.41                   47.08
# GOOG             30.02              7.78                   28.29
# AMZN             57.39             14.52                   31.23
# FB               27.00              7.43                   31.33
#
# info    Quarterly Revenue Growth (yoy)  Operating Cash Flow Margin(ttm)  \
# ticker
# AAPL                              36.4                         0.300755
# MSFT                              21.3                         0.456541
# GOOG                              61.6                         0.367095
# AMZN                              27.2                         0.133815
# FB                                55.6                         0.471037
#
# info                                        Y!  \
# ticker
# AAPL    Y#https://finance.yahoo.com/quote/AAPL
# MSFT    Y#https://finance.yahoo.com/quote/MSFT
# GOOG    Y#https://finance.yahoo.com/quote/GOOG
# AMZN    Y#https://finance.yahoo.com/quote/AMZN
# FB        Y#https://finance.yahoo.com/quote/FB
#
# info                                     alpha  \
# ticker
# AAPL    a#https://seekingalpha.com/symbol/AAPL
# MSFT    a#https://seekingalpha.com/symbol/MSFT
# GOOG    a#https://seekingalpha.com/symbol/GOOG
# AMZN    a#https://seekingalpha.com/symbol/AMZN
# FB        a#https://seekingalpha.com/symbol/FB
#
# info                                                  TS
# ticker
# AAPL    TS#https://jp.tradingview.com/chart/?symbol=AAPL
# MSFT    TS#https://jp.tradingview.com/chart/?symbol=MSFT
# GOOG    TS#https://jp.tradingview.com/chart/?symbol=GOOG
# AMZN    TS#https://jp.tradingview.com/chart/?symbol=AMZN
# FB        TS#https://jp.tradingview.com/chart/?symbol=FB

# %% [markdown]
# ### EPS history

# %%
print(type(E12))
E12.sort()
print(E12)
print(E12.sort())
# Out:
# <class 'list'>
# ['AAPL', 'AMZN', 'FB', 'GOOG', 'MSFT']
# None

# %%
import importlib
importlib.reload(mi)

#for i in [fangam, growth1, growth2]:
for i in [E12,E11,E10_5,E10_1,E9]:
    
    mi.plot_eps_history(i)

# %%
import importlib
importlib.reload(mi)
#mi.show_beat_ratio(LIST, last=20)
for i in [E12,E11,E10_5,E10_1,E9]:
    df_res = mi.show_valuation(i, hist=False, table=True)
# Out:
# PSR sorted list (2021-08-20)
# <style type="text/css">
# #T_0befd_row0_col0 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_0befd_row0_col2, #T_0befd_row1_col2, #T_0befd_row2_col1, #T_0befd_row3_col2, #T_0befd_row4_col2 {
#   background-color: #fda37b;
# }
# #T_0befd_row0_col3, #T_0befd_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_0befd_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 63.0%, transparent 63.0%);
# }
# #T_0befd_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
# }
# #T_0befd_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 37.0%, transparent 37.0%);
# }
# #T_0befd_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 34.6%, transparent 34.6%);
# }
# #T_0befd_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
# }
# #T_0befd_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_0befd_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 75.2%, transparent 75.2%);
# }
# #T_0befd_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 47.0%, transparent 47.0%);
# }
# #T_0befd_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 19.4%, transparent 19.4%);
# }
# #T_0befd_row1_col6, #T_0befd_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
# }
# #T_0befd_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 90.3%, transparent 90.3%);
# }
# #T_0befd_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
# }
# #T_0befd_row2_col0 {
#   background-color: #56a0ce;
#   color: #f1f1f1;
# }
# #T_0befd_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 64.1%, transparent 64.1%);
# }
# #T_0befd_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 52.3%, transparent 52.3%);
# }
# #T_0befd_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 20.3%, transparent 20.3%);
# }
# #T_0befd_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 22.3%, transparent 22.3%);
# }
# #T_0befd_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_0befd_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 61.2%, transparent 61.2%);
# }
# #T_0befd_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0befd_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 54.6%, transparent 54.6%);
# }
# #T_0befd_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 50.8%, transparent 50.8%);
# }
# #T_0befd_row3_col6, #T_0befd_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_0befd_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 59.1%, transparent 59.1%);
# }
# #T_0befd_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 50.1%, transparent 50.1%);
# }
# #T_0befd_row4_col0 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_0befd_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 28.9%, transparent 28.9%);
# }
# #T_0befd_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 37.8%, transparent 37.8%);
# }
# #T_0befd_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 44.2%, transparent 44.2%);
# }
# #T_0befd_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 22.3%, transparent 22.3%);
# }
# </style>
# <table id="T_0befd_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0befd_level0_row0" class="row_heading level0 row0" >MSFT</th>
#       <td id="T_0befd_row0_col0" class="data row0 col0" >$2.19e+12</td>
#       <td id="T_0befd_row0_col1" class="data row0 col1" >$289.8</td>
#       <td id="T_0befd_row0_col2" class="data row0 col2" >$298.9</td>
#       <td id="T_0befd_row0_col3" class="data row0 col3" >13.0</td>
#       <td id="T_0befd_row0_col4" class="data row0 col4" >36.2</td>
#       <td id="T_0befd_row0_col5" class="data row0 col5" >15.4</td>
#       <td id="T_0befd_row0_col6" class="data row0 col6" >47.1%</td>
#       <td id="T_0befd_row0_col7" class="data row0 col7" >21.3%</td>
#       <td id="T_0befd_row0_col8" class="data row0 col8" >45.7%</td>
#       <td id="T_0befd_row0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/MSFT">Y</a></td>
#       <td id="T_0befd_row0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/MSFT">a</a></td>
#       <td id="T_0befd_row0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=MSFT">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_0befd_level0_row1" class="row_heading level0 row1" >FB</th>
#       <td id="T_0befd_row1_col0" class="data row1 col0" >$1.02e+12</td>
#       <td id="T_0befd_row1_col1" class="data row1 col1" >$362.6</td>
#       <td id="T_0befd_row1_col2" class="data row1 col2" >$386.5</td>
#       <td id="T_0befd_row1_col3" class="data row1 col3" >9.8</td>
#       <td id="T_0befd_row1_col4" class="data row1 col4" >27.0</td>
#       <td id="T_0befd_row1_col5" class="data row1 col5" >7.4</td>
#       <td id="T_0befd_row1_col6" class="data row1 col6" >31.3%</td>
#       <td id="T_0befd_row1_col7" class="data row1 col7" >55.6%</td>
#       <td id="T_0befd_row1_col8" class="data row1 col8" >47.1%</td>
#       <td id="T_0befd_row1_col9" class="data row1 col9" ><a href="https://finance.yahoo.com/quote/FB">Y</a></td>
#       <td id="T_0befd_row1_col10" class="data row1 col10" ><a href="https://seekingalpha.com/symbol/FB">a</a></td>
#       <td id="T_0befd_row1_col11" class="data row1 col11" ><a href="https://jp.tradingview.com/chart/?symbol=FB">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_0befd_level0_row2" class="row_heading level0 row2" >GOOG</th>
#       <td id="T_0befd_row2_col0" class="data row2 col0" >$1.84e+12</td>
#       <td id="T_0befd_row2_col1" class="data row2 col1" >$2,767.8</td>
#       <td id="T_0befd_row2_col2" class="data row2 col2" >$2,625.0</td>
#       <td id="T_0befd_row2_col3" class="data row2 col3" >8.3</td>
#       <td id="T_0befd_row2_col4" class="data row2 col4" >30.0</td>
#       <td id="T_0befd_row2_col5" class="data r
# PSR sorted list (2021-08-20)
# <style type="text/css">
# #T_248ee_row0_col0 {
#   background-color: #ddeaf7;
#   color: #000000;
# }
# #T_248ee_row0_col2, #T_248ee_row1_col2, #T_248ee_row2_col2, #T_248ee_row3_col1, #T_248ee_row4_col1, #T_248ee_row5_col2, #T_248ee_row6_col2, #T_248ee_row7_col2 {
#   background-color: #fda37b;
# }
# #T_248ee_row0_col3, #T_248ee_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_248ee_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 20.1%, transparent 20.1%);
# }
# #T_248ee_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 40.1%, transparent 40.1%);
# }
# #T_248ee_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 73.7%, transparent 73.7%);
# }
# #T_248ee_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 29.6%, transparent 29.6%);
# }
# #T_248ee_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 23.2%, transparent 23.2%);
# }
# #T_248ee_row1_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_248ee_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 67.5%, transparent 67.5%);
# }
# #T_248ee_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 32.6%, transparent 32.6%);
# }
# #T_248ee_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 55.1%, transparent 55.1%);
# }
# #T_248ee_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 75.9%, transparent 75.9%);
# }
# #T_248ee_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_248ee_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 88.9%, transparent 88.9%);
# }
# #T_248ee_row2_col0 {
#   background-color: #3f8fc5;
#   color: #f1f1f1;
# }
# #T_248ee_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 46.7%, transparent 46.7%);
# }
# #T_248ee_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 18.6%, transparent 18.6%);
# }
# #T_248ee_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 50.9%, transparent 50.9%);
# }
# #T_248ee_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 89.5%, transparent 89.5%);
# }
# #T_248ee_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 35.7%, transparent 35.7%);
# }
# #T_248ee_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 60.1%, transparent 60.1%);
# }
# #T_248ee_row3_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_248ee_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 43.7%, transparent 43.7%);
# }
# #T_248ee_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 14.5%, transparent 14.5%);
# }
# #T_248ee_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 47.9%, transparent 47.9%);
# }
# #T_248ee_row3_col6, #T_248ee_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_248ee_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 11.8%, transparent 11.8%);
# }
# #T_248ee_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 80.8%, transparent 80.8%);
# }
# #T_248ee_row4_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_248ee_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 35.4%, transparent 35.4%);
# }
# #T_248ee_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 62.5%, transparent 62.5%);
# }
# #T_248ee_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 27.2%, transparent 27.2%);
# }
# #T_248ee_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 51.3%, transparent 51.3%);
# }
# #T_248ee_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 36.6%, transparent 36.6%);
# }
# #T_248ee_row5_col0 {
#   background-color: #a8cee4;
#   color: #000000;
# }
# #T_248ee_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 27.5%, transparent 27.5%);
# }
# #T_248ee_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 17.2%, transparent 17.2%);
# }
# #T_248ee_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 33.0%, transparent 33.0%);
# }
# #T_248ee_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 55.9%, transparent 55.9%);
# }
# #T_248ee_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 9.7%, transparent 9.7%);
# }
# #T_248ee_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 40.0%, transparent 40.0%);
# }
# #T_248ee_row6_col0 {
#   background-color: #d0e1f2;
#   color: #000000;
# }
# #T_248ee_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 17.2%, transparent 17.2%);
# }
# #T_248ee_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 14.0%, transparent 14.0%);
# }
# #T_248ee_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 36.0%, transparent 36.0%);
# }
# #T_248ee_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 83.9%, transparent 83.9%);
# }
# #T_248ee_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 10.1%, transparent 10.1%);
# }
# #T_248ee_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 11.1%, transparent 11.1%);
# }
# #T_248ee_row7_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_248ee_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 16.1%, transparent 16.1%);
# }
# #T_248ee_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 63.8%, transparent 63.8%);
# }
# #T_248ee_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 54.5%, transparent 54.5%);
# }
# #T_248ee_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 74.9%, transparent 74.9%);
# }
# #T_248ee_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 8.7%, transparent 8.7%);
# }
# </style>
# <table id="T_248ee_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# PSR sorted list (2021-08-20)
# <style type="text/css">
# #T_ce915_row0_col0 {
#   background-color: #dce9f6;
#   color: #000000;
# }
# #T_ce915_row0_col2, #T_ce915_row1_col1, #T_ce915_row2_col2, #T_ce915_row3_col2, #T_ce915_row4_col2, #T_ce915_row5_col2, #T_ce915_row6_col2 {
#   background-color: #fda37b;
# }
# #T_ce915_row0_col3, #T_ce915_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_ce915_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 27.6%, transparent 27.6%);
# }
# #T_ce915_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 43.2%, #e68f8f 43.2%, #e68f8f 68.1%, transparent 68.1%);
# }
# #T_ce915_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 67.7%, transparent 67.7%);
# }
# #T_ce915_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 67.6%, transparent 67.6%);
# }
# #T_ce915_row1_col0 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_ce915_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 63.9%, transparent 63.9%);
# }
# #T_ce915_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 68.1%, transparent 68.1%);
# }
# #T_ce915_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 55.9%, transparent 55.9%);
# }
# #T_ce915_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 38.2%, transparent 38.2%);
# }
# #T_ce915_row2_col0 {
#   background-color: #a3cce3;
#   color: #000000;
# }
# #T_ce915_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 51.7%, transparent 51.7%);
# }
# #T_ce915_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 2.5%, transparent 2.5%);
# }
# #T_ce915_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 55.7%, #e68f8f 55.7%, #e68f8f 68.1%, transparent 68.1%);
# }
# #T_ce915_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 64.6%, transparent 64.6%);
# }
# #T_ce915_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 3.3%, transparent 3.3%);
# }
# #T_ce915_row3_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_ce915_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 48.0%, transparent 48.0%);
# }
# #T_ce915_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 12.0%, transparent 12.0%);
# }
# #T_ce915_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 5.2%, transparent 5.2%);
# }
# #T_ce915_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#7eb8ef 21.2%, transparent 21.2%);
# }
# #T_ce915_row4_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_ce915_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 20.1%, transparent 20.1%);
# }
# #T_ce915_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_ce915_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 2.7%, transparent 2.7%);
# }
# #T_ce915_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 68.1%, #bcde93 68.1%, #bcde93 74.5%, transparent 74.5%);
# }
# #T_ce915_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 71.6%, transparent 71.6%);
# }
# #T_ce915_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 49.4%, transparent 49.4%);
# }
# #T_ce915_row5_col0 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_ce915_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 1.0%, transparent 1.0%);
# }
# #T_ce915_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 4.7%, transparent 4.7%);
# }
# #T_ce915_row5_col5, #T_ce915_row6_col3, #T_ce915_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 0.7%, transparent 0.7%);
# }
# #T_ce915_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 68.1%, #bcde93 68.1%, #bcde93 100.0%, transparent 100.0%);
# }
# #T_ce915_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_ce915_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 31.4%, transparent 31.4%);
# }
# #T_ce915_row6_col0 {
#   background-color: #dfebf7;
#   color: #000000;
# }
# #T_ce915_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 12.1%, transparent 12.1%);
# }
# #T_ce915_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 68.1%, #bcde93 68.1%, #bcde93 81.5%, transparent 81.5%);
# }
# #T_ce915_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 36.8%, transparent 36.8%);
# }
# #T_ce915_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 25.5%, transparent 25.5%);
# }
# </style>
# <table id="T_ce915_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ce915_level0_row0" class="row_heading level0 row0" >CRWD</th>
#       <td id="T_ce915_row0_col0" class="data row0 col0" >$5.58e+10</td>
#       <td id="T_ce915_row0_col1" class="data row0 col1" >$245.8</td>
#       <td id="T_ce915_row0_col2" class="data row0 col2" >$269.8</td>
#       <td id="T_ce915_row0_col3" class="data row0 col3" >55.8</td>
#       <td id="T_ce915_row0_col4" class="data row0 col4" >-</td>
#       <td id="T_ce915_row0_col5" class="data row0 col5" >65.7</td>
#       <td id="T_ce915_row0_col6" class="data row0 col6" >-19.4%</td>
#       <td id="T_ce915_row0_col7" class="data row0 col7" >70.1%</td>
#       <td id="T_ce915_row0_col8" class="data row0 col8" >40.6%</td>
#       <td id="T_ce915_row0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/CRWD">Y</a></td>
#       <td id="T_ce915_row0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/CRWD">a</a></td>
#       <td id="T_ce915_row0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=CRWD">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_ce915_level0_row1" class="row_heading level0 row1" >DOCU</th>
#       <td id="T_ce915_row1_col0" class="data row1 col0" >$5.79e+10</td>
#       <td id="T_ce915_row1_col1" class="data row1 col1" >$295.5</td>
#       <td id="T_ce915_row1_col2" class="data row1 col2" >$281.2</td>
#       <td id="T_ce915_row1_col3" cl
# PSR sorted list (2021-08-20)
# <style type="text/css">
# #T_e1aae_row0_col0 {
#   background-color: #519ccc;
#   color: #f1f1f1;
# }
# #T_e1aae_row0_col1, #T_e1aae_row1_col2, #T_e1aae_row2_col1, #T_e1aae_row3_col1, #T_e1aae_row4_col2, #T_e1aae_row5_col2, #T_e1aae_row6_col2, #T_e1aae_row7_col2, #T_e1aae_row8_col1, #T_e1aae_row9_col2, #T_e1aae_row10_col2 {
#   background-color: #fda37b;
# }
# #T_e1aae_row0_col3, #T_e1aae_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_e1aae_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 83.3%, transparent 83.3%);
# }
# #T_e1aae_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 19.6%, #e68f8f 19.6%, #e68f8f 49.7%, transparent 49.7%);
# }
# #T_e1aae_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 47.7%, transparent 47.7%);
# }
# #T_e1aae_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 58.3%, transparent 58.3%);
# }
# #T_e1aae_row1_col0 {
#   background-color: #3989c1;
#   color: #f1f1f1;
# }
# #T_e1aae_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 72.0%, transparent 72.0%);
# }
# #T_e1aae_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 58.1%, transparent 58.1%);
# }
# #T_e1aae_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 17.8%, #e68f8f 17.8%, #e68f8f 49.7%, transparent 49.7%);
# }
# #T_e1aae_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 29.8%, transparent 29.8%);
# }
# #T_e1aae_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 36.0%, transparent 36.0%);
# }
# #T_e1aae_row2_col0 {
#   background-color: #4090c5;
#   color: #f1f1f1;
# }
# #T_e1aae_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 68.3%, transparent 68.3%);
# }
# #T_e1aae_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 22.2%, transparent 22.2%);
# }
# #T_e1aae_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 29.3%, #e68f8f 29.3%, #e68f8f 49.7%, transparent 49.7%);
# }
# #T_e1aae_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 38.7%, transparent 38.7%);
# }
# #T_e1aae_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 12.6%, transparent 12.6%);
# }
# #T_e1aae_row3_col0, #T_e1aae_row6_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_e1aae_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 65.5%, transparent 65.5%);
# }
# #T_e1aae_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 29.3%, transparent 29.3%);
# }
# #T_e1aae_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 49.7%, transparent 49.7%);
# }
# #T_e1aae_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 39.3%, transparent 39.3%);
# }
# #T_e1aae_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.6%, #7eb8ef 12.6%, #7eb8ef 20.2%, transparent 20.2%);
# }
# #T_e1aae_row4_col0 {
#   background-color: #6fb0d7;
#   color: #f1f1f1;
# }
# #T_e1aae_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 50.8%, transparent 50.8%);
# }
# #T_e1aae_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 47.4%, transparent 47.4%);
# }
# #T_e1aae_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 43.5%, #e68f8f 43.5%, #e68f8f 49.7%, transparent 49.7%);
# }
# #T_e1aae_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 42.1%, transparent 42.1%);
# }
# #T_e1aae_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 39.9%, transparent 39.9%);
# }
# #T_e1aae_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_e1aae_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 44.3%, transparent 44.3%);
# }
# #T_e1aae_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 37.2%, #e68f8f 37.2%, #e68f8f 49.7%, transparent 49.7%);
# }
# #T_e1aae_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 35.3%, transparent 35.3%);
# }
# #T_e1aae_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.6%, #7eb8ef 12.6%, #7eb8ef 31.4%, transparent 31.4%);
# }
# #T_e1aae_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 37.4%, transparent 37.4%);
# }
# #T_e1aae_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 95.0%, transparent 95.0%);
# }
# #T_e1aae_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 23.8%, transparent 23.8%);
# }
# #T_e1aae_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 49.7%, #bcde93 49.7%, #bcde93 56.8%, transparent 56.8%);
# }
# #T_e1aae_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 65.0%, transparent 65.0%);
# }
# #T_e1aae_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.6%, #7eb8ef 12.6%, #7eb8ef 25.9%, transparent 25.9%);
# }
# #T_e1aae_row7_col0 {
#   background-color: #3b8bc2;
#   color: #f1f1f1;
# }
# #T_e1aae_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 28.8%, transparent 28.8%);
# }
# #T_e1aae_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_e1aae_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 18.1%, transparent 18.1%);
# }
# #T_e1aae_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 49.7%, #bcde93 49.7%, #bcde93 53.7%, transparent 53.7%);
# }
# #T_e1aae_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_e1aae_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.6%, #3c76af 12.6%, #3c76af 37.4%, transparent 37.4%);
# }
# #T_e1aae_row8_col0 {
#   background-color: #4896c8;
#   color: #f1f1f1;
# }
# #T_e1aae_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 20.4%, transparent 20.4%);
# }
# #T_e1aae_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 40.5%, transparent 40.5%);
# }
# #T_e1aae_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 19.7%, transparent 19.7%);
# }
# #T_e1aae_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 49.7%, #bcde93 49.7%, #bcde93 60.8%, transparent 60.8%);
# }
# #T_e1aae_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 31.5%, transparent 31.5%);
# }
# #T_e1aae_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 12.6%, #7eb8ef 12.6%, #7eb8ef 32.5%, transparent 32.5%);
# }
# #T_e1aae_row9_col0 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_e1aae_row9_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 20.1%, transparent 20.1%);
# }
# #T_e1aae_row9_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 24.6%, transparent 24.6%);
# }
# #T_e1aae_row9_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 57.1%, transparent 57.1%);
# }
# #T_e1aae_row9_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 49.7%, #bcde93 49.7%, #bcde93 100.0%, transparent 100.0%);
# }
# #T_e1aae_row9_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 18.7%, transparent 18.7%);
# }
# #T
# PSR sorted list (2021-08-20)
# <style type="text/css">
# #T_cc17e_row0_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cc17e_row0_col1, #T_cc17e_row1_col2, #T_cc17e_row2_col2 {
#   background-color: #fda37b;
# }
# #T_cc17e_row0_col3, #T_cc17e_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_cc17e_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_cc17e_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 45.8%, #bcde93 45.8%, #bcde93 100.0%, transparent 100.0%);
# }
# #T_cc17e_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_cc17e_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 61.1%, transparent 61.1%);
# }
# #T_cc17e_row1_col0 {
#   background-color: #f1f7fd;
#   color: #000000;
# }
# #T_cc17e_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 64.1%, transparent 64.1%);
# }
# #T_cc17e_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 55.0%, transparent 55.0%);
# }
# #T_cc17e_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 20.4%, #e68f8f 20.4%, #e68f8f 45.8%, transparent 45.8%);
# }
# #T_cc17e_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 59.2%, transparent 59.2%);
# }
# #T_cc17e_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #7eb8ef 14.1%, #7eb8ef 32.1%, transparent 32.1%);
# }
# #T_cc17e_row2_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cc17e_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 40.3%, transparent 40.3%);
# }
# #T_cc17e_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 14.6%, transparent 14.6%);
# }
# #T_cc17e_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 45.8%, transparent 45.8%);
# }
# #T_cc17e_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 13.8%, transparent 13.8%);
# }
# #T_cc17e_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 14.1%, transparent 14.1%);
# }
# </style>
# <table id="T_cc17e_">
#   <thead>
#     <tr>
#       <th class="index_name level0" >info</th>
#       <th class="col_heading level0 col0" >Market Cap</th>
#       <th class="col_heading level0 col1" >Previous Close</th>
#       <th class="col_heading level0 col2" >1y Target Est</th>
#       <th class="col_heading level0 col3" >Price/Sales (ttm)</th>
#       <th class="col_heading level0 col4" >PE Ratio (TTM)</th>
#       <th class="col_heading level0 col5" >Price/Book (mrq)</th>
#       <th class="col_heading level0 col6" >Return on Equity (ttm)</th>
#       <th class="col_heading level0 col7" >Quarterly Revenue Growth (yoy)</th>
#       <th class="col_heading level0 col8" >Operating Cash Flow Margin(ttm)</th>
#       <th class="col_heading level0 col9" >Y!</th>
#       <th class="col_heading level0 col10" >alpha</th>
#       <th class="col_heading level0 col11" >TS</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >ticker</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc17e_level0_row0" class="row_heading level0 row0" >TTD</th>
#       <td id="T_cc17e_row0_col0" class="data row0 col0" >$3.96e+10</td>
#       <td id="T_cc17e_row0_col1" class="data row0 col1" >$85.6</td>
#       <td id="T_cc17e_row0_col2" class="data row0 col2" >$69.7</td>
#       <td id="T_cc17e_row0_col3" class="data row0 col3" >38.3</td>
#       <td id="T_cc17e_row0_col4" class="data row0 col4" >155.9</td>
#       <td id="T_cc17e_row0_col5" class="data row0 col5" >33.0</td>
#       <td id="T_cc17e_row0_col6" class="data row0 col6" >26.9%</td>
#       <td id="T_cc17e_row0_col7" class="data row0 col7" >100.9%</td>
#       <td id="T_cc17e_row0_col8" class="data row0 col8" >32.8%</td>
#       <td id="T_cc17e_row0_col9" class="data row0 col9" ><a href="https://finance.yahoo.com/quote/TTD">Y</a></td>
#       <td id="T_cc17e_row0_col10" class="data row0 col10" ><a href="https://seekingalpha.com/symbol/TTD">a</a></td>
#       <td id="T_cc17e_row0_col11" class="data row0 col11" ><a href="https://jp.tradingview.com/chart/?symbol=TTD">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_cc17e_level0_row1" class="row_heading level0 row1" >FVRR</th>
#       <td id="T_cc17e_row1_col0" class="data row1 col0" >$6.18e+09</td>
#       <td id="T_cc17e_row1_col1" class="data row1 col1" >$172.1</td>
#       <td id="T_cc17e_row1_col2" class="data row1 col2" >$258.9</td>
#       <td id="T_cc17e_row1_col3" class="data row1 col3" >24.6</td>
#       <td id="T_cc17e_row1_col4" class="data row1 col4" >-</td>
#       <td id="T_cc17e_row1_col5" class="data row1 col5" >18.1</td>
#       <td id="T_cc17e_row1_col6" class="data row1 col6" >-12.6%</td>
#       <td id="T_cc17e_row1_col7" class="data row1 col7" >59.7%</td>
#       <td id="T_cc17e_row1_col8" class="data row1 col8" >12.6%</td>
#       <td id="T_cc17e_row1_col9" class="data row1 col9" ><a href="https://finance.yahoo.com/quote/FVRR">Y</a></td>
#       <td id="T_cc17e_row1_col10" class="data row1 col10" ><a href="https://seekingalpha.com/symbol/FVRR">a</a></td>
#       <td id="T_cc17e_row1_col11" class="data row1 col11" ><a href="https://jp.tradingview.com/chart/?symbol=FVRR">TS</a></td>
#     </tr>
#     <tr>
#       <th id="T_cc17e_level0_row2" class="row_heading level0 row2" >FSLY</th>
#       <td id="T_cc17e_row2_col0" class="data row2 col0" >$4.98e+09</td>
#       <td id="T_cc17e_row2_col1" class="data row2 col1" >$43.0</td>
#       <td id="T_cc17e_row2_col2" class="data row2 col2" >$56.2</td>
#       <td id="T_cc17e_row2_col3" class="data row2 col3" >15.4</td>
#       <td id="T_cc17e_row2_col4" class="data row2 col4" >-</td>
#       <td id="T_cc17e_row2_col5" class="data row2 col5" >4.8</td>
#       <td id="T_cc17e_row2_col6" class="data row2 col6" >-22.7%</td>
#       <td id="T_cc17e_row2_col7" class="data row2 col7" >13.9%</td>
#       <td id="T_cc17e_row2_col8" class="data row2 col8" >-9.8%</td>
#       <td id="T_cc17e_row2_col9" class="data row2 col9" ><a href="https://finance.yahoo.com/quote/FSLY">Y</a></td>
#       <td id="T_cc17e_row2_col10" class="data row2 col10" ><a href="https://seekingalpha.com/symbol/FSLY">a</a></td>
#       <td id="T_cc17e_row2_col11" class="data row2 col11" ><a href="https://jp.tradingview.com/chart/?symbol=FSLY">TS</a></td>
#     </tr>
#   </tbody>
# </table>

# %%
import importlib
importlib.reload(mi)
#df_res = mi.show_valuation(LIST, hist=False, table=True)
df_res = mi.show_valuation(LIST, hist=False, table=True, key="QRG")
# Out:
# QRG sorted list (2021-08-20)
# <style type="text/css">
# #T_ed730_row0_col0 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_ed730_row0_col2, #T_ed730_row1_col2, #T_ed730_row2_col2, #T_ed730_row3_col2, #T_ed730_row4_col2, #T_ed730_row5_col1, #T_ed730_row6_col1, #T_ed730_row7_col2, #T_ed730_row8_col2, #T_ed730_row9_col2, #T_ed730_row10_col2, #T_ed730_row11_col2, #T_ed730_row12_col1, #T_ed730_row13_col2, #T_ed730_row14_col1, #T_ed730_row15_col1, #T_ed730_row16_col2, #T_ed730_row17_col2, #T_ed730_row18_col2, #T_ed730_row19_col1, #T_ed730_row20_col1, #T_ed730_row21_col2, #T_ed730_row22_col1, #T_ed730_row23_col2, #T_ed730_row24_col2, #T_ed730_row25_col2, #T_ed730_row26_col2, #T_ed730_row27_col2, #T_ed730_row28_col1, #T_ed730_row29_col2, #T_ed730_row30_col2, #T_ed730_row31_col2, #T_ed730_row32_col2, #T_ed730_row33_col2 {
#   background-color: #fda37b;
# }
# #T_ed730_row0_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 58.3%, transparent 58.3%);
# }
# #T_ed730_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 32.6%, transparent 32.6%);
# }
# #T_ed730_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 10.6%, transparent 10.6%);
# }
# #T_ed730_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 57.3%, transparent 57.3%);
# }
# #T_ed730_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 100.0%, transparent 100.0%);
# }
# #T_ed730_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 90.5%, transparent 90.5%);
# }
# #T_ed730_row1_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_ed730_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 13.9%, transparent 13.9%);
# }
# #T_ed730_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 63.8%, transparent 63.8%);
# }
# #T_ed730_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 19.3%, transparent 19.3%);
# }
# #T_ed730_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 52.8%, transparent 52.8%);
# }
# #T_ed730_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 74.9%, transparent 74.9%);
# }
# #T_ed730_row1_col8, #T_ed730_row19_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #7eb8ef 14.1%, #7eb8ef 21.6%, transparent 21.6%);
# }
# #T_ed730_row2_col0, #T_ed730_row5_col0, #T_ed730_row20_col0, #T_ed730_row22_col0, #T_ed730_row24_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_ed730_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 28.8%, transparent 28.8%);
# }
# #T_ed730_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 58.4%, transparent 58.4%);
# }
# #T_ed730_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 6.0%, transparent 6.0%);
# }
# #T_ed730_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 44.9%, transparent 44.9%);
# }
# #T_ed730_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 65.3%, transparent 65.3%);
# }
# #T_ed730_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 38.5%, transparent 38.5%);
# }
# #T_ed730_row3_col0, #T_ed730_row14_col0, #T_ed730_row18_col0 {
#   background-color: #f5fafe;
#   color: #000000;
# }
# #T_ed730_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 1.2%, transparent 1.2%);
# }
# #T_ed730_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 3.1%, transparent 3.1%);
# }
# #T_ed730_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 0.9%, transparent 0.9%);
# }
# #T_ed730_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 50.3%, transparent 50.3%);
# }
# #T_ed730_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 57.7%, transparent 57.7%);
# }
# #T_ed730_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #7eb8ef 14.1%, #7eb8ef 32.7%, transparent 32.7%);
# }
# #T_ed730_row4_col0 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_ed730_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 1.0%, transparent 1.0%);
# }
# #T_ed730_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 1.6%, transparent 1.6%);
# }
# #T_ed730_row4_col5, #T_ed730_row23_col3, #T_ed730_row23_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 0.7%, transparent 0.7%);
# }
# #T_ed730_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 53.0%, transparent 53.0%);
# }
# #T_ed730_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 54.1%, transparent 54.1%);
# }
# #T_ed730_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 41.1%, transparent 41.1%);
# }
# #T_ed730_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 68.5%, transparent 68.5%);
# }
# #T_ed730_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 40.9%, transparent 40.9%);
# }
# #T_ed730_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 13.8%, transparent 13.8%);
# }
# #T_ed730_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 53.9%, transparent 53.9%);
# }
# #T_ed730_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 52.7%, transparent 52.7%);
# }
# #T_ed730_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 61.1%, transparent 61.1%);
# }
# #T_ed730_row6_col0 {
#   background-color: #b9d6ea;
#   color: #000000;
# }
# #T_ed730_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 30.6%, transparent 30.6%);
# }
# #T_ed730_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_ed730_row6_col5, #T_ed730_row33_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 12.0%, transparent 12.0%);
# }
# #T_ed730_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 47.2%, transparent 47.2%);
# }
# #T_ed730_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 51.3%, transparent 51.3%);
# }
# #T_ed730_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #3c76af 14.1%, #3c76af 45.5%, transparent 45.5%);
# }
# #T_ed730_row7_col0, #T_ed730_row8_col0, #T_ed730_row19_col0 {
#   background-color: #f4f9fe;
#   color: #000000;
# }
# #T_ed730_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 37.4%, transparent 37.4%);
# }
# #T_ed730_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 55.5%, transparent 55.5%);
# }
# #T_ed730_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 8.0%, transparent 8.0%);
# }
# #T_ed730_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 41.5%, #bcde93 41.5%, #bcde93 47.4%, transparent 47.4%);
# }
# #T_ed730_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 42.4%, transparent 42.4%);
# }
# #T_ed730_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 14.1%, #7eb8ef 14.1%, #7eb8ef 27.2%, transparent 27.2%);
# }

# %% [markdown]
# ### FANGAMのみ大きく出してみる

# %%
mi.plot_eps(fangam,largefig=True)
mi.search_good_eps(fangam, last=200)

# %% [markdown]
# ## Health

# %%
H_E11 = [
    "PFE",
    "DHR",
    "MRNA",
    "BMY",
    "AMGN",
    "BNTX",
]
H_E10 = [
    "ANTM",
    "VEEV",
    "BIIB",
    "A",
    "RPRX",
]
H_E9 = [
    "INOV",
    "PGNY",
    "INMD",
    "DOCS"
]
health = H_E11 + H_E10 + H_E9

# %%
import importlib
importlib.reload(mi)
# EPS history
df_res=mi.plot_eps_history(health,last=20)

# %%
import importlib
importlib.reload(mi)

df_res=mi.show_valuation(health,table=True)
#df_cap=mi.show_valuation(health,table=True,hist=False,key="Cap")
# Out:
# PSR sorted list (2021-08-17)
# <style type="text/css">
# #T_5f99f_row0_col0 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_5f99f_row0_col2, #T_5f99f_row1_col1, #T_5f99f_row2_col1, #T_5f99f_row3_col1, #T_5f99f_row4_col2, #T_5f99f_row5_col2, #T_5f99f_row6_col1, #T_5f99f_row7_col1, #T_5f99f_row8_col1, #T_5f99f_row9_col2, #T_5f99f_row10_col1, #T_5f99f_row11_col2, #T_5f99f_row12_col2, #T_5f99f_row13_col2, #T_5f99f_row14_col1 {
#   background-color: #fda37b;
# }
# #T_5f99f_row0_col3, #T_5f99f_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_5f99f_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 72.7%, transparent 72.7%);
# }
# #T_5f99f_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 85.4%, transparent 85.4%);
# }
# #T_5f99f_row0_col6, #T_5f99f_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 21.3%, transparent 21.3%);
# }
# #T_5f99f_row0_col7, #T_5f99f_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.4%, transparent 0.4%);
# }
# #T_5f99f_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 81.3%, transparent 81.3%);
# }
# #T_5f99f_row1_col0 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_5f99f_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 71.5%, transparent 71.5%);
# }
# #T_5f99f_row1_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 26.4%, transparent 26.4%);
# }
# #T_5f99f_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 57.8%, transparent 57.8%);
# }
# #T_5f99f_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 50.8%, transparent 50.8%);
# }
# #T_5f99f_row1_col8, #T_5f99f_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 100.0%, transparent 100.0%);
# }
# #T_5f99f_row2_col0, #T_5f99f_row5_col0 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_5f99f_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 56.9%, transparent 56.9%);
# }
# #T_5f99f_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 20.7%, transparent 20.7%);
# }
# #T_5f99f_row2_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 87.0%, transparent 87.0%);
# }
# #T_5f99f_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 34.9%, transparent 34.9%);
# }
# #T_5f99f_row2_col7, #T_5f99f_row10_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.7%, transparent 0.7%);
# }
# #T_5f99f_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 72.6%, transparent 72.6%);
# }
# #T_5f99f_row3_col0 {
#   background-color: #afd1e7;
#   color: #000000;
# }
# #T_5f99f_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 36.9%, transparent 36.9%);
# }
# #T_5f99f_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 11.7%, transparent 11.7%);
# }
# #T_5f99f_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 70.4%, transparent 70.4%);
# }
# #T_5f99f_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 100.0%, transparent 100.0%);
# }
# #T_5f99f_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 100.0%, transparent 100.0%);
# }
# #T_5f99f_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#e68f8f 7.1%, transparent 7.1%);
# }
# #T_5f99f_row4_col0 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_5f99f_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 34.4%, transparent 34.4%);
# }
# #T_5f99f_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 22.2%, transparent 22.2%);
# }
# #T_5f99f_row4_col7, #T_5f99f_row6_col7, #T_5f99f_row12_col7, #T_5f99f_row13_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.3%, transparent 0.3%);
# }
# #T_5f99f_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 33.5%, transparent 33.5%);
# }
# #T_5f99f_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 34.1%, transparent 34.1%);
# }
# #T_5f99f_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.6%, transparent 0.6%);
# }
# #T_5f99f_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #7eb8ef 7.1%, #7eb8ef 16.9%, transparent 16.9%);
# }
# #T_5f99f_row6_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_5f99f_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 27.2%, transparent 27.2%);
# }
# #T_5f99f_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_5f99f_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 34.5%, transparent 34.5%);
# }
# #T_5f99f_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 11.4%, transparent 11.4%);
# }
# #T_5f99f_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 44.0%, transparent 44.0%);
# }
# #T_5f99f_row7_col0 {
#   background-color: #115ca5;
#   color: #f1f1f1;
# }
# #T_5f99f_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 26.7%, transparent 26.7%);
# }
# #T_5f99f_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 24.0%, transparent 24.0%);
# }
# #T_5f99f_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 24.2%, transparent 24.2%);
# }
# #T_5f99f_row7_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 17.7%, transparent 17.7%);
# }
# #T_5f99f_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 0.2%, #f4d18b 0.2%, #f4d18b 0.5%, transparent 0.5%);
# }
# #T_5f99f_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 53.1%, transparent 53.1%);
# }
# #T_5f99f_row8_col0 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_5f99f_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 26.4%, transparent 26.4%);
# }
# #T_5f99f_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 35.0%, transparent 35.0%);
# }
# #T_5f99f_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 42.6%, transparent 42.6%);
# }
# #T_5f99f_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 7.1%, #3c76af 7.1%, #3c76af 43.8%, transparent 43.8%);
# }
# #T_5f99f_row9_col0 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_5f99f_row9_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 16.4%, transparent 16.4%);
# }
# #T_5f99f_row9_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 13.5%, transparent 13.5%);
# }
# #T_5f99f_row9_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 68.1%, transparent 68.1%);
# }
# #T_5f99f_row9_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg, transparent 8.1%, #bcde93 8.1%, #bcde93 49.8%, transparent 49.

# %% [markdown]
# # VUGとIWFの組入銘柄（570銘柄）の優良銘柄

# %%
GOOD=["ADP","AKAM","AZO","BC","BRO","CRL","CPRT","DHR","EFX","FB","FND","IQV","LPX","MKSI","MMC","MPWR","MSFT","MTD","NVDA","ORLY","ROL","SCCO","SPGI","TPX","TRU"]
df_res = mi.show_valuation(GOOD, hist=True, table=True, key="PSR")
# Out:
# PSR sorted list (2021-08-23)
# <style type="text/css">
# #T_0ff7e_row0_col0 {
#   background-color: #cde0f1;
#   color: #000000;
# }
# #T_0ff7e_row0_col2, #T_0ff7e_row1_col1, #T_0ff7e_row2_col2, #T_0ff7e_row3_col2, #T_0ff7e_row4_col2, #T_0ff7e_row5_col1, #T_0ff7e_row6_col2, #T_0ff7e_row7_col1, #T_0ff7e_row8_col1, #T_0ff7e_row9_col2, #T_0ff7e_row10_col2, #T_0ff7e_row11_col2, #T_0ff7e_row12_col1, #T_0ff7e_row13_col2, #T_0ff7e_row14_col2, #T_0ff7e_row15_col2, #T_0ff7e_row16_col1, #T_0ff7e_row17_col2, #T_0ff7e_row18_col2, #T_0ff7e_row19_col2, #T_0ff7e_row20_col2, #T_0ff7e_row21_col2, #T_0ff7e_row22_col2, #T_0ff7e_row23_col2, #T_0ff7e_row24_col2 {
#   background-color: #fda37b;
# }
# #T_0ff7e_row0_col3, #T_0ff7e_row19_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 100.0%, transparent 100.0%);
# }
# #T_0ff7e_row0_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 62.5%, transparent 62.5%);
# }
# #T_0ff7e_row0_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 12.1%, transparent 12.1%);
# }
# #T_0ff7e_row0_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 8.1%, transparent 8.1%);
# }
# #T_0ff7e_row0_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 48.2%, transparent 48.2%);
# }
# #T_0ff7e_row0_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 60.1%, transparent 60.1%);
# }
# #T_0ff7e_row1_col0, #T_0ff7e_row8_col0, #T_0ff7e_row9_col0, #T_0ff7e_row11_col0, #T_0ff7e_row13_col0, #T_0ff7e_row14_col0 {
#   background-color: #f6faff;
#   color: #000000;
# }
# #T_0ff7e_row1_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 93.3%, transparent 93.3%);
# }
# #T_0ff7e_row1_col4, #T_0ff7e_row19_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 100.0%, transparent 100.0%);
# }
# #T_0ff7e_row1_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 10.4%, transparent 10.4%);
# }
# #T_0ff7e_row1_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 4.1%, transparent 4.1%);
# }
# #T_0ff7e_row1_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 40.6%, transparent 40.6%);
# }
# #T_0ff7e_row1_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 53.1%, transparent 53.1%);
# }
# #T_0ff7e_row2_col0 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_0ff7e_row2_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 60.4%, transparent 60.4%);
# }
# #T_0ff7e_row2_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 33.3%, transparent 33.3%);
# }
# #T_0ff7e_row2_col5, #T_0ff7e_row22_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 8.4%, transparent 8.4%);
# }
# #T_0ff7e_row2_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 9.5%, transparent 9.5%);
# }
# #T_0ff7e_row2_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 15.0%, transparent 15.0%);
# }
# #T_0ff7e_row2_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 76.1%, transparent 76.1%);
# }
# #T_0ff7e_row3_col0 {
#   background-color: #eef5fc;
#   color: #000000;
# }
# #T_0ff7e_row3_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 59.7%, transparent 59.7%);
# }
# #T_0ff7e_row3_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 37.9%, transparent 37.9%);
# }
# #T_0ff7e_row3_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 43.3%, transparent 43.3%);
# }
# #T_0ff7e_row3_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 15.1%, transparent 15.1%);
# }
# #T_0ff7e_row3_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 5.9%, transparent 5.9%);
# }
# #T_0ff7e_row3_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 77.5%, transparent 77.5%);
# }
# #T_0ff7e_row4_col0, #T_0ff7e_row5_col0, #T_0ff7e_row21_col0 {
#   background-color: #f5f9fe;
#   color: #000000;
# }
# #T_0ff7e_row4_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 59.5%, transparent 59.5%);
# }
# #T_0ff7e_row4_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 35.0%, transparent 35.0%);
# }
# #T_0ff7e_row4_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 5.3%, transparent 5.3%);
# }
# #T_0ff7e_row4_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 6.1%, transparent 6.1%);
# }
# #T_0ff7e_row4_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 23.6%, transparent 23.6%);
# }
# #T_0ff7e_row4_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 69.5%, transparent 69.5%);
# }
# #T_0ff7e_row5_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 45.2%, transparent 45.2%);
# }
# #T_0ff7e_row5_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 45.2%, transparent 45.2%);
# }
# #T_0ff7e_row5_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 96.0%, transparent 96.0%);
# }
# #T_0ff7e_row5_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 44.6%, transparent 44.6%);
# }
# #T_0ff7e_row5_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 23.8%, transparent 23.8%);
# }
# #T_0ff7e_row5_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 42.3%, transparent 42.3%);
# }
# #T_0ff7e_row6_col0 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_0ff7e_row6_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 42.9%, transparent 42.9%);
# }
# #T_0ff7e_row6_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 23.5%, transparent 23.5%);
# }
# #T_0ff7e_row6_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 3.8%, transparent 3.8%);
# }
# #T_0ff7e_row6_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 6.3%, transparent 6.3%);
# }
# #T_0ff7e_row6_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 39.2%, transparent 39.2%);
# }
# #T_0ff7e_row6_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 78.5%, transparent 78.5%);
# }
# #T_0ff7e_row7_col0 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_0ff7e_row7_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 38.1%, transparent 38.1%);
# }
# #T_0ff7e_row7_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 37.7%, transparent 37.7%);
# }
# #T_0ff7e_row7_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 3.0%, transparent 3.0%);
# }
# #T_0ff7e_row7_col6, #T_0ff7e_row14_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 2.8%, transparent 2.8%);
# }
# #T_0ff7e_row7_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 25.6%, transparent 25.6%);
# }
# #T_0ff7e_row7_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 49.5%, transparent 49.5%);
# }
# #T_0ff7e_row8_col3 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 37.5%, transparent 37.5%);
# }
# #T_0ff7e_row8_col4 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 51.1%, transparent 51.1%);
# }
# #T_0ff7e_row8_col5 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#549e3f 9.6%, transparent 9.6%);
# }
# #T_0ff7e_row8_col6 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#bcde93 7.0%, transparent 7.0%);
# }
# #T_0ff7e_row8_col7 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#f4d18b 10.8%, transparent 10.8%);
# }
# #T_0ff7e_row8_col8 {
#   width: 10em;
#   height: 80%;
#   background: linear-gradient(90deg,#3c76af 30.6%, transparent 30.6%);
# }
# #T_0ff7e_row9_col3 {
#   width: 10em;

# %%
df_res=mi.plot_eps_history(GOOD,last=20)

# %%
ret=mi.show_beat_ratio(GOOD,last=40,threshold=95,min_qtrs=20)
# Out:
# Tickers list of which beat ratio >= 95% within last 40 quarters
# (data with more than 20 quarter EPSs)
#                                           beat ratio  beat  count
# ticker companyshortname
# TRU    TransUnion                              100.0    24     24
# IQV    IQVIA Holdings Inc.                     100.0    33     33
# MTD    Mettler-Toledo International Inc.       100.0    40     40
# MPWR   Monolithic Power Systems, Inc.           97.5    39     40
# SPGI   S&P Global Inc.                          95.0    38     40

# %% [markdown]
# ## Get stock info of your favorite

# %% [markdown]
# ### Find Tickers with high EPS beat ratio

# %%
# pd.set_option('display.max_rows', df.shape[0]+1)
tickers_nasdaq = si.tickers_nasdaq()
ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_36/4042142324.py in <module>
#       1 # pd.set_option('display.max_rows', df.shape[0]+1)
#       2 tickers_nasdaq = si.tickers_nasdaq()
# ----> 3 ret=mi.search_good_eps(tickers_nasdaq[:10],last=40,threshold=95,min_qtrs=20)
#
# AttributeError: module 'mystock_info' has no attribute 'search_good_eps'

# %%
# !pip  install pandas==1.3.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pandas==1.3.1
#   Downloading pandas-1.3.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.7 MB)
#      |████████████████████████████████| 11.7 MB 310 kB/s eta 0:00:01    |███████████▏                    | 4.1 MB 4.5 MB/s eta 0:00:02     |███████████████████████▉        | 8.8 MB 4.5 MB/s eta 0:00:01     |███████████████████████████▊    | 10.2 MB 4.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (1.21.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas==1.3.1) (2021.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.8/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.1) (1.16.0)
# Installing collected packages: pandas
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# fastquant 0.1.6.1 requires pandas==1.1.5, but you have pandas 1.3.1 which is incompatible.
# Successfully installed pandas-1.3.1
# WARNING: You are using pip version 21.2.2; however, version 21.2.4 is available.
# You should consider upgrading via the '/usr/bin/python -m pip install --upgrade pip' command.
