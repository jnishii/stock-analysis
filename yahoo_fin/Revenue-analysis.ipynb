# %% [markdown]
# # Revenue

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import yahoo_fin.stock_info as si

# private module to use yahoo_fin
import mystock_info as mi

## reload private module
import importlib
importlib.reload(mi)
# Out:
# <module 'mystock_info' from '/home/jovyan/yahoo_fin/mystock_info.py'>

# %%
Tera = ["FB", "AAPL", "GOOG", "AMZN", "MSFT"]
B500 = ["NFLX", "TSLA"]
B100 = ["ADBE", "NVDA", "SHOP", "SQ", "ZM"]
B50 = (
    ["CRWD", "TWLO","TWTR"]
    + [ "DOCU", "ROKU", "ABNB"]
    + ["GM", "F"]
)
B10 = ["U", "MGA","ZS","OKTA",  "TTD", "ETSY","FIVN", "PINS"]
B = ["FVRR"]

LIST=Tera+B500+B100+B50+B10+B
###

# %%
df_psr = mi.get_financial_data(LIST, clear_cache=7)
df_psr_sorted = mi.plot_financials(df_psr, hist=False, table=True, key="PSR")
# Out:
# PSR sorted list (<function today at 0x7ff52d2fc820>)
# info   Market Cap  Previous Close  1y Target Est  Price/Sales (ttm)  \
# Ticker
# CRWD      60.734B          263.04         269.75              60.78
# SHOP     204.758B         1594.09        1515.09              59.38
# ZS        32.702B          235.59         240.62              54.33
# OKTA      39.473B          249.71         277.91              43.69
# TTD       38.609B           74.11          69.71              43.13
# FVRR       8.631B          232.91         258.88              38.59
# DOCU      60.107B          308.00         281.17              36.99
# TWLO      70.778B          405.51         464.88              35.62
# U         29.478B          104.20         123.05              35.08
# ZM       106.678B          361.39         415.48              32.53
# ROKU      62.711B          420.65         450.50              30.86
# FIVN      12.941B          193.23         206.63              27.09
# ...

# %%
ret = mi.get_revenue(fangam, clear_cache=1, verbose=False)
mi.plot_revenue(ret)

# %%
health1 = [
    "A",
    "AMGN",
    "ANTM",
    "BMY",
    "BNTX",
    "BIIB",
    "DHR",

]
health2 = [
    "MRNA",
    "PGNY",
    "PFE",
    "RPRX",
    "VEEV",
    "INOV"
]

for i in [health1, health2]:
    ret = mi.get_revenue(i, clear_cache=1, verbose=False)
    mi.plot_revenue(ret)
