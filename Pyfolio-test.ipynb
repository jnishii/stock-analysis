# %% [markdown]
# # Pyfolio
# work on docker-zipline-reloaded
#
# ## リンク
# - [pyfolioを使ってみる
# ](https://qiita.com/mrsn28/items/445553c24861b9930682)

# %%
import pyfolio as pf
# %matplotlib inline

# silence warnings
import warnings
warnings.filterwarnings('ignore')

# %%
stock_rets = pf.utils.get_symbol_rets('FB')

# %%
display(stock_rets)
# Out:
# Date
# 2012-05-21 00:00:00+00:00   -0.109861
# 2012-05-22 00:00:00+00:00   -0.089039
# 2012-05-23 00:00:00+00:00    0.032258
# 2012-05-24 00:00:00+00:00    0.032187
# 2012-05-25 00:00:00+00:00   -0.033909
#                                ...
# 2021-06-28 00:00:00+00:00    0.041802
# 2021-06-29 00:00:00+00:00   -0.010544
# 2021-06-30 00:00:00+00:00   -0.011879
# 2021-07-01 00:00:00+00:00    0.019211
# 2021-07-02 00:00:00+00:00    0.000875
# Name: FB, Length: 2295, dtype: float64

# %%
#pf.create_returns_tear_sheet(stock_rets, live_start_date='2015-12-1')
pf.create_returns_tear_sheet(stock_rets)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2012-05-21</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-07-02</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>109</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>27.712%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>827.805%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>37.077%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.84</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.52</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-53.623%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.18</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.28</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>0.94</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>18.46</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.06</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-4.547%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>47.90</td>
#       <td>2012-05-21</td>
#       <td>2012-09-04</td>
#       <td>2013-07-25</td>
#       <td>309</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>42.96</td>
#       <td>2018-07-25</td>
#       <td>2018-12-24</td>
#       <td>2020-01-09</td>
#       <td>382</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>34.59</td>
#       <td>2020-01-29</td>
#       <td>2020-03-16</td>
#       <td>2020-05-20</td>
#       <td>81</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>22.06</td>
#       <td>2014-03-10</td>
#       <td>2014-04-28</td>
#       <td>2014-07-24</td>
#       <td>99</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>21.17</td>
#       <td>2018-02-01</td>
#       <td>2018-03-27</td>
#       <td>2018-06-01</td>
#       <td>87</td>
#     </tr>
#   </tbody>
# </table>
